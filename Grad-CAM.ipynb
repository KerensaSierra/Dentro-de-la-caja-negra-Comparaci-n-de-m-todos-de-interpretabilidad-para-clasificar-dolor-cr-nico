# %%
import os
import sys
sys.path.append("C:/Users/PC-EIAD209/Desktop/AnaKei/NIPD-AI")
#sys.path.append("C:\\Users\\"+os.getlogin()+"\\OneDrive - Instituto Tecnologico y de Estudios Superiores de Monterrey\\PainClassifier")
from my_data_generator_final import *

# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.io as sio
import os
from tensorflow.keras.utils import plot_model
from sklearn.model_selection import train_test_split
import h5py
import warnings
from sklearn.metrics import roc_auc_score, roc_curve
from sklearn.metrics import precision_recall_fscore_support as score, precision_score, recall_score, f1_score
from sklearn.metrics import confusion_matrix
from datetime import datetime
import scipy as sp
from sklearn.preprocessing import LabelBinarizer
from sklearn.metrics import auc, roc_curve
from itertools import cycle
from sklearn.metrics import RocCurveDisplay
from sklearn.utils import resample
import tensorflow as tf
from tensorflow.keras.layers import Input, Dense, Reshape, Conv3D, MaxPooling3D, Flatten, Dropout, GlobalAveragePooling3D, concatenate, BatchNormalization
from tensorflow.keras.models import Model
from tensorflow.keras.utils import to_categorical
from sklearn.model_selection import StratifiedKFold
import seaborn as sns
import imageio_ffmpeg
from tensorflow.keras.applications.vgg16 import VGG16


#from keras.regularizers import l2
import cv2
#from keras import initializers
#from keras.layers import LeakyReLU
#from keras.layers import BatchNormalization
import tensorflow as tf
#from keras import losses
import matplotlib as mpl
import imageio_ffmpeg
#nuevo
from tensorflow.keras.regularizers import l2
from tensorflow.keras import initializers, losses
from tensorflow.keras.layers import LeakyReLU, BatchNormalization


from tensorflow.keras.optimizers import SGD
import wandb
from wandb.integration.keras import WandbCallback
import gc
#from numba import cuda   nota: no se usa
from tensorflow.keras.optimizers.schedules import ExponentialDecay

# %%
from tf_keras_vis.saliency import Saliency
from tf_keras_vis.utils import normalize
from tf_keras_vis.utils.scores import CategoricalScore
from tf_keras_vis.utils.model_modifiers import ReplaceToLinear
from hirescam import HiResCAM

# %%
import wandb
from wandb.integration.keras import keras

old_from_keras = getattr(wandb.Graph, "from_keras", None)

def safe_from_keras(model, *args, **kwargs):
    print("W&B Graph visualization desactivada (inbound_layers incompatibles con Keras 3.x).")
    return None  # evita que se intente generar el grafo

if old_from_keras is not None:
    wandb.Graph.from_keras = safe_from_keras

# %%
import wandb
from wandb.integration.keras import WandbCallback
import keras

wandb.keras = None  # Desactiva funciones viejas de grafo

class SafeWandbCallback(WandbCallback):
    """Versión segura de WandbCallback compatible con Keras moderno."""
    def __init__(self, *args, **kwargs):
        super().__init__(*args, **kwargs)
        self._model = None  # ← previene el AttributeError

    def set_model(self, model):
        try:
            self._model = model  # almacena referencia sin conflicto
            super().set_model(model)
        except Exception as e:
            print(f"Se omitió un error interno de W&B-Keras: {e}")

# %%
physical_devices = tf.config.list_physical_devices('GPU')
try:
  tf.config.experimental.set_memory_growth(physical_devices[0], True)
except:
  # Invalid device or cannot modify virtual devices once initialized.
  pass

# %%
# Mixed precision training

from tensorflow.keras import mixed_precision
mixed_precision.set_global_policy('float32')

#DirectML no se lleva com mixedfloat16
#mixed_precision.set_global_policy('mixed_float16')

# %%
def VGG16_3D(blocks):
        
    inputs = Input(shape=(42, 65, 29), name='input_layer')
    x = Reshape(target_shape=[42, 65, 29, 1], name='input_x_3d_volumes')(inputs)

    if blocks == 1:
        print("entra al 1")
        #batch_norm
        x = BatchNormalization()(x)
        # 1st Conv Block
        x = Conv3D(filters =64, kernel_size =3, padding ='same', activation='relu',kernel_regularizer='l2')(x)
        x = Conv3D(filters =64, kernel_size =3, padding ='same', activation='relu',kernel_regularizer='l2')(x)
        x = MaxPooling3D(pool_size =2, strides =2, padding ='same')(x)
        x = tf.keras.layers.GlobalAveragePooling3D()(x)
        x = tf.keras.layers.Dropout(0.5)(x)
        
    elif blocks == 2:
        print("entra al 2")
        #batch_norm
        x = BatchNormalization()(x)
        # 1st Conv Block
        x = Conv3D(filters =64, kernel_size =3, padding ='same', activation='relu',kernel_regularizer='l2')(x)
        x = Conv3D(filters =64, kernel_size =3, padding ='same', activation='relu',kernel_regularizer='l2')(x)
        x = MaxPooling3D(pool_size =2, strides =2, padding ='same')(x)
        x = tf.keras.layers.Dropout(0.2)(x)
            
        #batch_norm
        x = BatchNormalization()(x)
        # 2nd Conv Block
        x = Conv3D (filters =128, kernel_size =3, padding ='same', activation='relu',kernel_regularizer='l2')(x)
        x = Conv3D (filters =128, kernel_size =3, padding ='same', activation='relu',kernel_regularizer='l2')(x)
        x = MaxPooling3D(pool_size =2, strides =2, padding ='same')(x)
        x = tf.keras.layers.GlobalAveragePooling3D()(x)
        x = tf.keras.layers.Dropout(0.5)(x)
        
    elif blocks == 3:
        print("entra al 3")
        #batch_norm
        x = BatchNormalization()(x)
        # 1st Conv Block
        x = Conv3D(filters =64, kernel_size =3, padding ='same', activation='relu',kernel_regularizer='l2')(x)
        x = Conv3D(filters =64, kernel_size =3, padding ='same', activation='relu',kernel_regularizer='l2')(x)
        x = MaxPooling3D(pool_size =2, strides =2, padding ='same')(x)
        x = tf.keras.layers.Dropout(0.2)(x)
            
        #batch_norm
        x = BatchNormalization()(x)
        # 2nd Conv Block
        x = Conv3D (filters =128, kernel_size =3, padding ='same', activation='relu',kernel_regularizer='l2')(x)
        x = Conv3D (filters =128, kernel_size =3, padding ='same', activation='relu',kernel_regularizer='l2')(x)
        x = MaxPooling3D(pool_size =2, strides =2, padding ='same')(x)
        x = tf.keras.layers.Dropout(0.2)(x)
        
        #batch_norm
        x = BatchNormalization()(x)
        # 3rd Conv block  
        x = Conv3D (filters =256, kernel_size =3, padding ='same', activation='relu',kernel_regularizer='l2')(x) 
        x = Conv3D (filters =256, kernel_size =3, padding ='same', activation='relu',kernel_regularizer='l2')(x) 
        x = Conv3D (filters =256, kernel_size =3, padding ='same', activation='relu',kernel_regularizer='l2')(x) 
        x = MaxPooling3D(pool_size =2, strides =2, padding ='same')(x)
        x = tf.keras.layers.GlobalAveragePooling3D()(x)
        x = tf.keras.layers.Dropout(0.5)(x)
        
    elif blocks == 4:
        print("entra al 4")
        #batch_norm
        x = BatchNormalization()(x)
        # 1st Conv Block
        x = Conv3D(filters =64, kernel_size =3, padding ='same', activation='relu',kernel_regularizer='l2')(x)
        x = Conv3D(filters =64, kernel_size =3, padding ='same', activation='relu',kernel_regularizer='l2')(x)
        x = MaxPooling3D(pool_size =2, strides =2, padding ='same')(x)
        x = tf.keras.layers.Dropout(0.2)(x)
            
        #batch_norm
        x = BatchNormalization()(x)
        # 2nd Conv Block
        x = Conv3D (filters =128, kernel_size =3, padding ='same', activation='relu',kernel_regularizer='l2')(x)
        x = Conv3D (filters =128, kernel_size =3, padding ='same', activation='relu',kernel_regularizer='l2')(x)
        #x = MaxPooling3D(pool_size =2, strides =2, padding ='same')(x)
        x = tf.keras.layers.Dropout(0.2)(x)
        
        #batch_norm
        x = BatchNormalization()(x)
        # 3rd Conv block  
        x = Conv3D (filters =256, kernel_size =3, padding ='same', activation='relu',kernel_regularizer='l2')(x) 
        x = Conv3D (filters =256, kernel_size =3, padding ='same', activation='relu',kernel_regularizer='l2')(x) 
        x = Conv3D (filters =256, kernel_size =3, padding ='same', activation='relu',kernel_regularizer='l2')(x) 
        #x = MaxPooling3D(pool_size =2, strides =2, padding ='same')(x)
        x = tf.keras.layers.Dropout(0.2)(x)
        
        #batch_norm
        x = BatchNormalization()(x)
        # 4th Conv block
        x = Conv3D (filters =512, kernel_size =3, padding ='same', activation='relu',kernel_regularizer='l2')(x)
        x = Conv3D (filters =512, kernel_size =3, padding ='same', activation='relu',kernel_regularizer='l2')(x)
        x = Conv3D (filters =512, kernel_size =3, padding ='same', activation='relu',kernel_regularizer='l2')(x)
        x = MaxPooling3D(pool_size =2, strides =2, padding ='same')(x)
        #x = tf.keras.layers.GlobalAveragePooling3D()(x)
        x = tf.keras.layers.Dropout(0.5)(x)

    elif blocks == 5:
        print("entra al 5")
        #batch_norm
        #x = BatchNormalization()(x)
        # 1st Conv Block
        x = Conv3D(filters =64, kernel_size =3, padding ='same', activation='relu',kernel_regularizer=tf.keras.regularizers.L2(l2=0.001))(x)
        x = Conv3D(filters =64, kernel_size =3, padding ='same', activation='relu',kernel_regularizer=tf.keras.regularizers.L2(l2=0.001))(x)
        x = BatchNormalization()(x)
        x = MaxPooling3D(pool_size =2, strides =2, padding ='same')(x)
        x = tf.keras.layers.Dropout(0.1)(x)
            
        #batch_norm
        #x = BatchNormalization()(x)
        # 2nd Conv Block
        x = Conv3D (filters =128, kernel_size =3, padding ='same', activation='relu',kernel_regularizer=tf.keras.regularizers.L2(l2=0.001))(x)
        x = Conv3D (filters =128, kernel_size =3, padding ='same', activation='relu',kernel_regularizer=tf.keras.regularizers.L2(l2=0.001))(x)
        x = BatchNormalization()(x)
        #x = MaxPooling3D(pool_size =2, strides =1, padding ='same')(x)
        x = tf.keras.layers.Dropout(0.1)(x)
        
        #batch_norm
        #x = BatchNormalization()(x)
        # 3rd Conv block  
        x = Conv3D (filters =256, kernel_size =3, padding ='same', activation='relu',kernel_regularizer=tf.keras.regularizers.L2(l2=0.001))(x) 
        x = Conv3D (filters =256, kernel_size =3, padding ='same', activation='relu',kernel_regularizer=tf.keras.regularizers.L2(l2=0.001))(x) 
        x = Conv3D (filters =256, kernel_size =3, padding ='same', activation='relu',kernel_regularizer=tf.keras.regularizers.L2(l2=0.001))(x) 
        x = BatchNormalization()(x)
        #x = MaxPooling3D(pool_size =2, strides =1, padding ='same')(x)
        x = tf.keras.layers.Dropout(0.1)(x)
        
        #batch_norm
        #x = BatchNormalization()(x)
        # 4th Conv block
        x = Conv3D (filters =512, kernel_size =3, padding ='same', activation='relu',kernel_regularizer=tf.keras.regularizers.L2(l2=0.001))(x)
        x = Conv3D (filters =512, kernel_size =3, padding ='same', activation='relu',kernel_regularizer=tf.keras.regularizers.L2(l2=0.001))(x)
        x = Conv3D (filters =512, kernel_size =3, padding ='same', activation='relu',kernel_regularizer=tf.keras.regularizers.L2(l2=0.001))(x)
        x = BatchNormalization()(x)
        #x = MaxPooling3D(pool_size =2, strides =1, padding ='same')(x)
        x = tf.keras.layers.Dropout(0.1)(x)
    
        #batch_norm
        #x = BatchNormalization()(x)
        # 5th Conv block
        x = Conv3D (filters =512, kernel_size =3, padding ='same', activation='relu',kernel_regularizer=tf.keras.regularizers.L2(l2=0.001))(x)
        x = Conv3D (filters =512, kernel_size =3, padding ='same', activation='relu',kernel_regularizer=tf.keras.regularizers.L2(l2=0.001))(x)
        x = Conv3D (filters =512, kernel_size =3, padding ='same', activation='relu',kernel_regularizer=tf.keras.regularizers.L2(l2=0.001))(x)
        x = BatchNormalization()(x)
        #x = MaxPooling3D(pool_size =2, strides =2, padding ='same')(x)
        x = tf.keras.layers.GlobalAveragePooling3D()(x)
        x = tf.keras.layers.Dropout(0.1)(x)
    
    # Fully connected layers  
    x = Flatten()(x) 
    x = Dense(units = 1024, activation ='relu',kernel_regularizer='l2')(x)
    #x = tf.keras.layers.Dropout(0.5)(x)
    x = Dense(units = 1024, activation ='relu',kernel_regularizer='l2')(x) 
    x = tf.keras.layers.Dropout(0.3)(x)
    output = Dense(units = 2,activation ='softmax',kernel_regularizer='l2')(x)
    
    # creating the model
    VGG_3d_model = Model (inputs=inputs, outputs =output)
    #model.summary()

    return VGG_3d_model

def set_pretrained_weigths(VGG_3d_model):
    #VGG 16 with weights from Imagenet
    pretrained_model = tf.keras.applications.VGG16(
        include_top=False,
        weights="imagenet",
        pooling='avg',
        input_shape = (42, 65, 3)
    )
    
    #conv layers on VGG_3d_model
    layers_conv = []
    for j in range(len(VGG_3d_model.layers)):
        if "conv3d" in str(VGG_3d_model.layers[j]):
            layers_conv.append(j)
    layers_conv_pretrained = []
    for j in range(len(pretrained_model.layers)):
        if "Conv2D" in str(pretrained_model.layers[j]):
            layers_conv_pretrained.append(j)
    
    for i in range(len(layers_conv)):
        if "Conv2D" in str(pretrained_model.layers[layers_conv_pretrained[i]]):
            if i == 0:
                w = pretrained_model.layers[layers_conv_pretrained[i]].get_weights()[0].sum(axis=2, keepdims=True)
            else:
                w = pretrained_model.layers[layers_conv_pretrained[i]].get_weights()[0]
                
            w3d=[]
            
            w = np.reshape(w,(3,3,-1),order='F')
            for j in range(len(w[0,0,:])):
                for k in range(3):
                    w3d.append(w[:,:,j])
            w3d = np.transpose(w3d, (1,2,0))
            
            new_weights = np.reshape(w3d, np.array(VGG_3d_model.layers[layers_conv[i]].get_weights()[0]).shape,order='F')
            new_bias = pretrained_model.layers[layers_conv_pretrained[i]].get_weights()[1]
            
            WnB = []
            WnB.append(new_weights)
            WnB.append(new_bias)
    
            VGG_3d_model.layers[layers_conv[i]].set_weights(WnB)

    del pretrained_model, w, WnB, new_weights, new_bias, w3d

# %%
def confusionmatrix_multiclass(y_test,pred):
    cm = confusion_matrix(y_test, (np.rint(preds)).astype(int) )
    group_names = ['True baseline','False Baseline','False Baseline',   
                   'False week 1','Truec','False Week 1',
                  'False week 7','False week 7','True week 7']
    group_counts = ["{0:0.0f}".format(value) for value in
                    cm.flatten()]
    group_percentages = ["{0:.2%}".format(value) for value in
                         np.ndarray.flatten(cm/(np.sum(cm,axis=1).reshape(3,1)))]
    labels = [f"{v1}\n{v2}\n{v3}" for v1, v2, v3 in
              zip(group_names,group_counts,group_percentages)]
    labels = np.asarray(labels).reshape(3,3)
    sns.heatmap(cm, annot=labels, fmt='', cmap='Blues', xticklabels = ['Baseline','Week 1','Week 7'] ,yticklabels = ['Baseline','Week 1','Week 7'])
    plt.show()

def confusionmatrix(y_test,preds):
    #Construct the Confusion Matrix
    cm = confusion_matrix(y_test, preds)
    group_names = ['True Male','False Male','False Female','True Female']
    group_counts = ["{0:0.0f}".format(value) for value in
                    cm.flatten()]
    group_percentages = ["{0:.2%}".format(value) for value in
                         np.ndarray.flatten(cm/(np.sum(cm,axis=1).reshape(2,1)))]
    labels = [f"{v1}\n{v2}\n{v3}" for v1, v2, v3 in
              zip(group_names,group_counts,group_percentages)]
    labels = np.asarray(labels).reshape(2,2)
    sns.heatmap(cm, annot=labels, fmt='', cmap='Blues', xticklabels = ['MALE','FEMALE'] ,yticklabels = ['MALE','FEMALE'])
    plt.show()
    return sns.heatmap(cm, annot=labels, fmt='', cmap='Blues', xticklabels = ['MALE','FEMALE'] ,yticklabels = ['MALE','FEMALE'])
    
def confusionmatrix_binary(y_test, preds):
    cm = confusion_matrix(y_test, preds)
    group_names = ['True baseline','False baseline','False Week 1','True Week 1']
    group_counts = ["{0:0.0f}".format(value) for value in
                    cm.flatten()]
    group_percentages = ["{0:.2%}".format(value) for value in
                         np.ndarray.flatten(cm/(np.sum(cm,axis=1).reshape(2,1)))]
    labels = [f"{v1}\n{v2}\n{v3}" for v1, v2, v3 in
              zip(group_names,group_counts,group_percentages)]
    labels = np.asarray(labels).reshape(2,2)
    sns.heatmap(cm, annot=labels, fmt='', cmap='Blues', xticklabels = ['MALE','FEMALE'] ,yticklabels = ['MALE','FEMALE'])
    plt.show()

def ROC(probs,y_test): #binary
    #Classification Area under curve
     warnings.filterwarnings('ignore')
             
     auc = roc_auc_score(y_test, probs)
     print('AUC - Test Set: %.2f%%' % (auc*100))
    
     # calculate roc curve
     fpr, tpr, thresholds = roc_curve(y_test, probs)
     # plot no skill
     plt.plot([0, 1], [0, 1], linestyle='--')
     # plot the roc curve for the model
     plt.plot(fpr, tpr, marker='.')
     plt.xlabel('False positive rate')
     plt.ylabel('Sensitivity/ Recall')
     # show the plot
     plt.show()
    
     probs = (np.rint(probs)).astype(int)   
        
     precision = precision_score(y_test, probs)
     print('Precision: %f' % precision)
     # recall: tp / (tp + fn)
     recall = recall_score(y_test, probs)
     print('Recall: %f' % recall)
     # f1: tp / (tp + fp + fn)
     f1 = f1_score(y_test, probs)
     print('F1 score: %f' % f1)
        
def ROC_multiclass(model, y_test, n_class):
    #y_test: array size (# of subjects, ) with classes 
    #pretrained model to be evaluated 
    
    label_binarizer = LabelBinarizer().fit(y_test)
    y_onehot_test = label_binarizer.transform(y_test)
    y_onehot_test.shape  # (n_samples, n_classes)

    y_score = model.predict(X_test) # y_score is onehot
    
    # store the fpr, tpr, and roc_auc for all averaging strategies
    fpr, tpr, roc_auc = dict(), dict(), dict()
    # Compute micro-average ROC curve and ROC area
    fpr["micro"], tpr["micro"], _ = roc_curve(y_onehot_test.ravel(), y_score.ravel())
    roc_auc["micro"] = auc(fpr["micro"], tpr["micro"])

    print(f"Micro-averaged One-vs-Rest ROC AUC score:\n{roc_auc['micro']:.2f}")
    
    n_classes = n_class
    
    for i in range(n_classes):
        fpr[i], tpr[i], _ = roc_curve(y_onehot_test[:, i], y_score[:, i])
        roc_auc[i] = auc(fpr[i], tpr[i])

    fpr_grid = np.linspace(0.0, 1.0, 1000)

    # Interpolate all ROC curves at these points
    mean_tpr = np.zeros_like(fpr_grid)

    for i in range(n_classes):
        mean_tpr += np.interp(fpr_grid, fpr[i], tpr[i])  # linear interpolation

    # Average it and compute AUC
    mean_tpr /= n_classes

    fpr["macro"] = fpr_grid
    tpr["macro"] = mean_tpr
    roc_auc["macro"] = auc(fpr["macro"], tpr["macro"])

    print(f"Macro-averaged One-vs-Rest ROC AUC score:\n{roc_auc['macro']:.2f}")
    
    target_names = ['Naive','Week1','Week7']

    fig, ax = plt.subplots(figsize=(6, 6))

    plt.plot(
        fpr["micro"],
        tpr["micro"],
        label=f"micro-average ROC curve (AUC = {roc_auc['micro']:.2f})",
        color="deeppink",
        linestyle=":",
        linewidth=4,
    )

    plt.plot(
        fpr["macro"],
        tpr["macro"],
        label=f"macro-average ROC curve (AUC = {roc_auc['macro']:.2f})",
        color="navy",
        linestyle=":",
        linewidth=4,
    )

    colors = cycle(["aqua", "darkorange", "cornflowerblue"])
    for class_id, color in zip(range(n_classes), colors):
        RocCurveDisplay.from_predictions(
            y_onehot_test[:, class_id],
            y_score[:, class_id],
            name=f"ROC curve for {target_names[class_id]}",
            color=color,
            ax=ax,
            plot_chance_level=(class_id == 2),
        )

    _ = ax.set(
        xlabel="False Positive Rate",
        ylabel="True Positive Rate",
        title="Extension of Receiver Operating Characteristic\nto One-vs-Rest multiclass",
    )
    
# plot diagnostic learning curves
def summarize_diagnostics(histories):
    c = ['b','g','r','c','m','y','k','w']
    ltr = ['fold 1(train)','fold 2(train)','fold 3(train)','fold 4(train)','fold 5(train)']
    lts = ['fold 1(val)','fold 2(val)','fold 3(val)','fold 4(val)','fold 5(val)']
    for i in range(len(histories)):
        # plot loss
        plt.subplot(2, 1, 1)
        plt.title('Cross Entropy Loss')
        plt.plot(histories[i].history['loss'], color=c[i], label=ltr[i], linestyle="-")
        plt.plot(histories[i].history['val_loss'], color=c[i], label=lts[i], linestyle="--")
        # plot accuracy
        plt.subplot(2, 1, 2)
        plt.title('Classification Accuracy')
        plt.plot(histories[i].history['Accuracy'], color=c[i], label=ltr[i], linestyle="-")
        plt.plot(histories[i].history['val_Accuracy'], color=c[i], label=lts[i], linestyle="--")
    plt.legend()
    plt.show()

# summarize model performance
def summarize_performance(scores):
    # print summary
    print('Accuracy: mean=%.3f std=%.3f, n=%d' % (np.mean(scores)*100, np.std(scores)*100, len(scores)))
    # box and whisker plots of results
    plt.boxplot(scores)
    plt.show()

# %%
male = [57, 
        #59,
        60,73,74,93,94,95,96,98,99,100]
female = [49,50,51,52,65,66,77,78,79,80,81,82,
          #83
         ]

y_male = np.ones(len(male))
y_female = np.zeros(len(female))

subjects = np.array(male+female)
labels = np.array(list(y_male)+list(y_female))
sessions = [3]
MRI_type = "func"
functional_type = "dist"

#Pretrained model to re start weights from at every fold
baseModel = VGG16_3D(5)
set_pretrained_weigths(baseModel)

#Model that is going to be train and re started every fold
CNN = VGG16_3D(5)
# Out:
# entra al 5
# entra al 5

# %%
rootpath1 = "C:/Users/L03117947/Downloads/Kerensa/Computadora Prof.Omar/sigma_files/sigma_files/SIGMA_resam_InVivo_Brain_Template_Masked.nii"
img = nib.load(rootpath1)
data_grad_completo = img.get_fdata()
print(data_grad_completo.shape)
#Mascara base
mask_nii = "C:/Users/L03117947/Downloads/Kerensa/Computadora Prof.Omar/sigma_files/sigma_files/SIGMA_resam_InVivo_Brain_Mask.nii"
mask_nii = nib.load(mask_nii)
mask = mask_nii.get_fdata()
mask = mask > 0
# Out:
# (48, 81, 48)

# %%
# 80% train y val y 20% test
sub_trainval, sub_test, y_trainval, y_test = train_test_split(
    subjects, labels, test_size=0.2, random_state=42, stratify=labels
)

n_bootstraps= 1
for boot in range(n_bootstraps): 
    print(f"\n=== Bootstrapping Run {boot+1}/{n_bootstraps} ===")

    boot_subjects, boot_labels = resample(
        sub_trainval, y_trainval, replace=True, random_state=42+boot
    )

    kfold = StratifiedKFold(n_splits=4, shuffle=True, random_state=1)

    scores, histories = list(), list()
    run = 1
    for train_ix, val_ix in kfold.split(boot_subjects, boot_labels):

        sub_train, sub_val = boot_subjects[train_ix], boot_subjects[val_ix]
        y_train, y_val     = boot_labels[train_ix], boot_labels[val_ix]

        sub_test, y_test = sub_test, y_test

        print("Run #",run)

        # Set default values
        config_defaults = {
            "batch": 1,
        }
        # Initialize wandb with a sample project name
        wandb.init(project="Male vs Female(GradCam) coverage", notes="FOLD "+str(run)+".  Evaluacion de male vs female con GradCam ++. lr = 1e-6",dir="C:/Users/103087364/wandb_runs"
                   ,config=config_defaults)

        # Specify the other hyperparameters to the configuration.
        wandb.config.epochs = 10
        wandb.config.sub_batch = 15
        wandb.config.sub_batch_ts = 15
        wandb.config.subjects = subjects
        wandb.config.architecture_name = "VGG16_3D"
        wandb.config.dataset_name = "Male vs Female, GradCam coverage"
        wandb.config.CNN_blocks = 5
        wandb.config.sessions = sessions
        wandb.config.vols_per_session_tr = 570#570
        wandb.config.vols_per_session_ts = 570#570
        wandb.config.initial_learning_rate = 1e-5
        #wandb.config.lr_decay_rate = 0.95
        wandb.config.optimizer = "Adam"
        
        
        val_size = max(2, int(round(0.1 * len(train_ix))))
    
        sub_train, sub_val, y_train, y_val = train_test_split(
            sub_trainval[train_ix], y_trainval[train_ix],
            test_size=val_size,  # test_size se refiere a la validacion
            random_state=42, stratify=y_trainval[train_ix]
        )
        
        CPHclassTrain = FILES_and_LABELS(sub_train, sessions, MRI_type, functional_type)
        CPHclassTest = FILES_and_LABELS(sub_test, sessions, MRI_type, functional_type)
        CPHclassval = FILES_and_LABELS(sub_val, sessions, MRI_type, functional_type)
            
        X_train = CPHclassTrain.get_mask_and_bold()
      
        print("X_train con exito")
        X_test = CPHclassTest.get_mask_and_bold()
        print("X_test con exito")
        X_val = CPHclassval.get_mask_and_bold()
        print("X_val con exito")

        print("sub train:")
        print(np.array(X_train)[:,0])
        print("sub test:")
        print(np.array(X_test)[:,0])
        print("sub val:")
        print(np.array(X_val)[:,0])

        print("# sesiones Train",len(X_train))
        print("# sesiones Test",len(X_test))
        print("# sesiones Val",len(X_val))
        
        traingen = CustomDataGen(X_train, batch_size=wandb.config.batch, subbatch_size=wandb.config.sub_batch,
                                format = "just_brain", vols = wandb.config.vols_per_session_tr,
                                num_class = 2, classes = "sex", augmentation = True, functional_type = "rest")
        traingen.on_epoch_end()
        #Es necesario que la division entre X_test y batch_size tenga un modulo igual a 0. 
        #De otra manera el ultimo batch no lo utiliza al utilizar .predict
        testgen  = CustomDataGen(X_test, batch_size=1,subbatch_size=wandb.config.sub_batch_ts,
                                format = "just_brain", vols= wandb.config.vols_per_session_ts,
                                num_class = 2, classes = "sex",shuffle=False, functional_type = "rest")
        valgen  = CustomDataGen(X_val, batch_size=len(X_val),subbatch_size=15, format = "just_brain",vols=570, augmentation = True, num_class = 2,
                                classes = "sex", functional_type = "rest")
        
        #getting model 3D CNN
        #callback = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=4, min_delta=0.0001)
        print("Starting VGG 16 3D-----------------------------------------------------")
        tf.keras.backend.clear_session()
        gc.collect()

        #transfer learning
        layers = [l for l in CNN.layers]
            
        for i in range(len(baseModel.layers)):
            layers[i].set_weights(baseModel.layers[i].get_weights())
            
        """
        lr_schedule = ExponentialDecay(wandb.config.initial_learning_rate,
                                    decay_steps=int((wandb.config.vols_per_session_tr/wandb.config.sub_batch)*len(X_train)),
                                    decay_rate=wandb.config.lr_decay_rate, staircase=True)
        """
        CNN.compile(loss="categorical_crossentropy", optimizer=tf.keras.optimizers.Adam(learning_rate=wandb.config.initial_learning_rate),
                        metrics=["Accuracy"])

        #checkpoint_filepath =os.getcwd()+"/"+wandb.run.name
        checkpoint_filepath = os.path.join("W:/", f"{wandb.run.name}.h5")
        #'/tmp/ckpt/MalevsFemale(CPH)_3D-VGG16_flips/'+wandb.run.name
        
        model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(filepath=checkpoint_filepath, monitor='val_loss', mode='min',
                                                                save_best_only=True)
        
        start_time = datetime.now()
        
        print("Training")

        print("Starting VGG 16 3D-----------------------------------------------------")
    # --- DEBUG: inspección del generador ---
        history = CNN.fit(traingen, epochs=wandb.config.epochs, validation_data = valgen, shuffle=True, callbacks=[SafeWandbCallback(monitor='val_loss',mode="min",save_model=False),model_checkpoint_callback])         
        end_time = datetime.now()
        print('Duration (CNN): {}'.format(end_time - start_time))

        y_test=[]
        x_vols = []
        for i in range(int(len(X_test)*(wandb.config.vols_per_session_ts/wandb.config.sub_batch_ts))):
            x,y = testgen[i]
            y_test.extend(y)
            x_vols.extend(x)
        y_test = np.argmax(y_test, axis=1)
        print("predicts CNN")
        preds = tf.cast(tf.argmax(CNN.predict(testgen), axis=1), tf.int32)
        #Wrong predicted subjects
        wrong_labeled_subj = mislabeled_subj(y_test, preds, X_test, wandb.config.vols_per_session_ts)

        print("mislabeled subjects:\n",wrong_labeled_subj)
        
        print("evaluating CNN")
        _,acc = CNN.evaluate(testgen, verbose=1)
        
        scores.append(acc)
        histories.append(history)
#---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
        #Interpretability method: GradCam
        all_layers = [layer.name for layer in reversed(CNN.layers) if len(layer.output_shape) == 5 and (layer.__class__.__name__ == 'ReLU' or isinstance(layer, tf.keras.layers.Conv3D))] #Retrieves the names of all relevant 3D layers reversed to follow the order used for Grad-CAM++ processing
        index_male = index_for_gradcam(0,y_test,preds) #Gets the index of the male subject used for the Grad-CAM map
        index_female = index_for_gradcam(1,y_test,preds)
        data_grad = data_grad_completo[3:45, 4:69, 7:36]
        Writer = animation.writers['ffmpeg']
        writer = Writer(fps=15, metadata=dict(artist='Me'), bitrate=1800)

        if index_male != None:
            heatmap_male = make_gradcam_heatmap(np.expand_dims(x_vols[index_male], axis=0), CNN, all_layers[0])
            #Matches the heatmap dimensions to the reference volume by adding or removing axes
            while heatmap_male.ndim < data_grad_completo.ndim:
                heatmap_male = np.expand_dims(heatmap_male, axis=-1)
            if heatmap_male.ndim > data_grad_completo.ndim:
                heatmap_male = np.squeeze(heatmap_male)

            if heatmap_male.shape != data_grad_completo.shape:
                factor_m = np.array(data_grad_completo.shape) / np.array(heatmap_male.shape)
                resized_heatmap_male = zoom(heatmap_male, factor_m, order=1)
            else:
                resized_heatmap_male = heatmap_male.copy()

            resized_heatmap_male = (resized_heatmap_male - resized_heatmap_male.min()) / (resized_heatmap_male.max() - resized_heatmap_male.min() + 1e-8) # Normalizes the heatmap to a 0-1 range for consistent analysis.

            heatmap_norm_male = resized_heatmap_male.astype(np.float32) #Converts to float32 for numerical stability
            thr_male = np.percentile(heatmap_norm_male, 90)  #Computes the threshold corresponding to the top 10% most intense activations
            salient_male = heatmap_norm_male >= thr_male  #Creates a binary mask (only leaves the most intense activations)

            activation_voxels_male = salient_male.sum() #Counts the total activations
            voxels_inside_male = np.logical_and(salient_male, mask).sum() #Counts how many of those activations actually fall inside the brain mask

            coverage_male = voxels_inside_male / activation_voxels_male #Calculates the coverage (voxels inside the brain respect to the total activationes)
            print("Coverage male:", coverage_male)

            #name_ani_male = "GradCam_male(malevsfemale-CPH)-"+wandb.run.name+".mp4"
            #gradcam_male.save(name_ani_male, writer=writer)
            
            #output_dir = "E:"
            #os.makedirs(output_dir, exist_ok=True)
            #name_ani_male = os.path.join(output_dir, "GradCam_male(malevsfemale-CPH)-" + wandb.run.name + ".mp4")
            #gradcam_male.save(name_ani_male, writer=writer)
            
            #GradCam average all conv layers
            #print("GradCam All ConvLayers-male")

            #all_layers_gradcam_male = fuse_layers(all_layers, CNN, x_vols, index_male, emphasize=False)
            #all_layers_animation_male = create_animation(data_grad, 'All_layers_GradCam_male', heatmap=all_layers_gradcam_male) #Cambio requerido, muchos sujetos
            #name_all_male = 'All_layers_GradCam_male'+wandb.run.name+'.mp4'
            #name_all_male = os.path.join(output_dir, "All_layers_GradCam_male" + wandb.run.name + ".mp4")
            #all_layers_animation_male.save(name_all_male, writer=writer)

            #males
            #if not os.path.exists("W:"+"/"+wandb.run.name+"/male"): 
                # if the demo_folder directory is not present  
                # then create it. 
                #os.makedirs("W:"+"/"+wandb.run.name+"/male")
            for i in range(len(x_vols[index_male][0,:,0])):
                plt.imshow(cv2.resize(np.rot90(np.array(data_grad)[:,i,:]),dsize=(126,87)), alpha=0.8, cmap='bone')
                # over the cam output
                #plt.imshow(cv2.resize(np.rot90(resized_heatmap_female[:,i,:]),dsize=(126,87)), alpha=0.4,cmap='jet')
                plt.imshow(cv2.resize(np.rot90(np.where(resized_heatmap_male[:, i, :] > np.percentile(resized_heatmap_male, 90),resized_heatmap_male[:, i, :], np.nan)),dsize=(126, 87)),cmap='Reds',alpha=1.0)
                plt.axis('off')
                # display the image
                
                #name = str(i)+".png" 
                #plt.savefig("W:"+"/"+wandb.run.name+"/female/"+name)
                #plt.show()
           
            
            #np.save("W:"+"/"+wandb.run.name+"/male/Array_GradCam-M", full_grad_male)
            
            #wandb.log({'GradCam_Male-coronal': wandb.Video(name_ani_male),
                #'GradCam_Male_all-layers': wandb.Video(name_all_male),
                #'GradCam-per_frames-male': wandb.Image(grad_cam_per_frames(data_grad,resized_heatmap_male, 150))})
        
        #The same logic applies for the female case.”
        if index_female != None:
            heatmap_female = make_gradcam_heatmap(np.expand_dims(x_vols[index_female], axis=0), CNN, all_layers[0]) 

            while heatmap_female.ndim < data_grad_completo.ndim:
                heatmap_female = np.expand_dims(heatmap_female, axis=-1)

            if heatmap_female.ndim > data_grad_completo.ndim:
                heatmap_female = np.squeeze(heatmap_female)

            if heatmap_female.shape != data_grad_completo.shape:
                factor_f = np.array(data_grad_completo.shape) / np.array(heatmap_female.shape)
                resized_heatmap_female = zoom(heatmap_female, factor_f, order=1)
            else:
                resized_heatmap_female = heatmap_female.copy()

            resized_heatmap_female = (resized_heatmap_female - resized_heatmap_female.min()) / (resized_heatmap_female.max() - resized_heatmap_female.min() + 1e-8)
            
            heatmap_norm = resized_heatmap_female.astype(np.float32)
            thr = np.percentile(heatmap_norm, 90)
            salient = heatmap_norm >= thr

            activation_voxels = salient.sum()
            voxels_inside = np.logical_and(salient, mask).sum()

            coverage_female = voxels_inside / activation_voxels
            print("Coverage female:", coverage_female)
            
            #gradcam_female = create_animation(data_grad, 'Female', heatmap=resized_heatmap_female)
            #name_ani_female = "GradCam_female(malevsfemale-CPH)-"+wandb.run.name+".mp4"
            #gradcam_female.save(name_ani_female, writer=writer)

            #output_dir = "E:"
            #name_ani_female = os.path.join(output_dir, "GradCam_female(malevsfemale-CPH)-" + wandb.run.name + ".mp4")
            #gradcam_female.save(name_ani_female, writer=writer)
            
            #GradCam average all conv layers
            #print("GradCam All ConvLayers-female")
        
            #all_layers_gradcam_female = fuse_layers(all_layers, CNN, x_vols, index_female, emphasize=False)
            #all_layers_animation_female = create_animation(data_grad, 'All_layers_GradCam_female', heatmap=all_layers_gradcam_female)
            #name_all_female = 'All_layers_GradCam_female'+wandb.run.name+'.mp4'
            #name_all_female = os.path.join(output_dir, "All_layers_GradCam_female" + wandb.run.name + ".mp4")
            #all_layers_animation_female.save(name_all_female, writer=writer)
        
            #Save frame by frame of gradcam
            #Females
            #if not os.path.exists("W:"+"/"+wandb.run.name+"/female"): 
                # if the demo_folder directory is not present  
                # then create it. 
                #os.makedirs("W:"+"/"+wandb.run.name+"/female")
            
            for i in range(len(x_vols[index_female][0,:,0])):
                plt.imshow(cv2.resize(np.rot90(np.array(data_grad)[:,i,:]),dsize=(126,87)), alpha=0.8, cmap='bone')
                # over the cam output
                #plt.imshow(cv2.resize(np.rot90(resized_heatmap_female[:,i,:]),dsize=(126,87)), alpha=0.4,cmap='jet')
                plt.imshow(cv2.resize(np.rot90(np.where(resized_heatmap_female[:, i, :] > np.percentile(resized_heatmap_female, 90),resized_heatmap_female[:, i, :], np.nan)),dsize=(126, 87)),cmap='Reds',alpha=1.0)
                plt.axis('off')
                # display the image
                
                #name = str(i)+".png" 
                #plt.savefig("W:"+"/"+wandb.run.name+"/female/"+name)
                #plt.show()
        
            
            #get gradCams with the shape of the original volumes before crop
            

            #full_grad_female = np.zeros((48,81,48))
            #full_grad_female[3:45,4:69,7:36] = resized_heatmap_female
            #np.save("W:"+"/"+wandb.run.name+"/female/Array_GradCam-F", full_grad_female)
            
            #wandb.log({'GradCam-Female-coronal': wandb.Video(name_ani_female),
                #'GradCam-Female_all-layers': wandb.Video(name_all_female),
                #'GradCam-per_frames-female': wandb.Image(grad_cam_per_frames(data_grad,resized_heatmap_female, 150))})
            

        print("CM CNN")
        cm = confusionmatrix(y_test, preds)

        wandb.log({'test_acc': float(acc),
                'time_running': '{}'.format(end_time - start_time),
                'confution_matrix': wandb.Image(cm),
                'mislabeled_subj':wrong_labeled_subj})
        

        run = run + 1
        
    print("histories and scores from VGG 16 M2D") 
    summarize_diagnostics(histories)
    summarize_performance(scores)

    wandb.finish()
# Out:
# === Bootstrapping Run 1/1 ===
# Run # 1
# wandb: Currently logged in as: a01642230 (mansoor35) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# wandb: WARNING Unable to create root directory C:/Users/103087364/wandb_runs
# wandb: WARNING Falling back to temporary directory C:\Users\L03117~1\AppData\Local\Temp.
# Tracking run with wandb version 0.22.0
# Run data is saved locally in <code>C:\Users\L03117~1\AppData\Local\Temp\wandb\run-20251202_112426-q5sjekpi</code>
# Syncing run <strong><a href='https://wandb.ai/mansoor35/Male%20vs%20Female%28GradCam%29%20coverage/runs/q5sjekpi' target="_blank">fearless-capybara-19</a></strong> to <a href='https://wandb.ai/mansoor35/Male%20vs%20Female%28GradCam%29%20coverage' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/mansoor35/Male%20vs%20Female%28GradCam%29%20coverage' target="_blank">https://wandb.ai/mansoor35/Male%20vs%20Female%28GradCam%29%20coverage</a>
#  View run at <a href='https://wandb.ai/mansoor35/Male%20vs%20Female%28GradCam%29%20coverage/runs/q5sjekpi' target="_blank">https://wandb.ai/mansoor35/Male%20vs%20Female%28GradCam%29%20coverage/runs/q5sjekpi</a>
# holaaaa, se metio al mask and bold
# SE METIO AL DISTTTTTTTTTT
# SE METIO AL LOGIN
# sesions:  [3]
# SESION:  3
# ENTRO AL SEGUNDO SUB BATCH
# ENTRO AL SEGUNDO SUB BATCH
# Se metió al 68
# j:  57
# ENTRO AL SEGUNDO SUB BATCH
# ENTRO AL SEGUNDO SUB BATCH
# Se metió al 68
# j:  60
# Se metió al 68
# j:  50
# Se metió al 68
# j:  66
# ENTRO AL SEGUNDO SUB BATCH
# ENTRO AL SEGUNDO SUB BATCH
# ENTRO AL SEGUNDO SUB BATCH
# AHHHHHHHHHHHHHHHHHH [['R:/preprocess_batch-002/commonspace_bold/_scan_info_subject_id082.session03_split_name_sub-082_ses-03_desc-o_T2w/_run_None/sub-082_ses-03_task-dist_desc-oa_bold_autobox_combined.nii.gz', 'R:/preprocess_batch-002_rest/bold_datasink/commonspace_mask/_scan_info_subject_id082.session03_split_name_sub-082_ses-03_desc-o_T2w/_run_None/sub-082_ses-03_task-rest_desc-oa_bold_autobox_EPI_brain_mask.nii.gz'], ['R:/preprocess_batch-002/commonspace_bold/_scan_info_subject_id093.session03_split_name_sub-093_ses-03_desc-o_T2w/_run_None/sub-093_ses-03_task-dist_desc-oa_bold_autobox_combined.nii.gz', 'R:/preprocess_batch-002_rest/bold_datasink/commonspace_mask/_scan_info_subject_id093.session03_split_name_sub-093_ses-03_desc-o_T2w/_run_None/sub-093_ses-03_task-rest_desc-oa_bold_autobox_EPI_brain_mask.nii.gz'], ['R:/preprocess_batch-001/commonspace_bold/_scan_info_subject_id057.session03_split_name_sub-057_ses-03_desc-o_T2w/_run_None/sub-057_ses-03_task-dist_desc-oa_bold_autobox_combined.nii.gz', 'R:/preprocess_batch-001_rest/bold_datasink/commonspace_mask/_scan_info_subject_id057.session03_split_name_sub-057_ses-03_desc-o_T2w/_run_None/sub-057_ses-03_task-rest_desc-oa_bold_autobox_EPI_brain_mask.nii.gz'], ['R:/preprocess_batch-002/commonspace_bold/_scan_info_subject_id081.session03_split_name_sub-081_ses-03_desc-o_T2w/_run_None/sub-081_ses-03_task-dist_desc-oa_bold_autobox_combined.nii.gz', 'R:/preprocess_batch-002_rest/bold_datasink/commonspace_mask/_scan_info_subject_id081.session03_split_name_sub-081_ses-03_desc-o_T2w/_run_None/sub-081_ses-03_task-rest_desc-oa_bold_autobox_EPI_brain_mask.nii.gz'], ['R:/preprocess_batch-002/commonspace_bold/_scan_info_subject_id074.session03_split_name_sub-074_ses-03_desc-o_T2w/_run_None/sub-074_ses-03_task-dist_desc-oa_bold_autobox_combined.nii.gz', 'R:/preprocess_batch-002_rest/bold_datasink/commonspace_mask/_scan_info_subject_id074.session03_split_name_sub-074_ses-03_desc-o_T2w/_run_None/sub-074_ses-03_task-rest_desc-oa_bold_autobox_EPI_brain_mask.nii.gz'], ['R:/preprocess_batch-001/commonspace_bold/_scan_info_subject_id060.session03_split_name_sub-060_ses-03_desc-o_T2w/_run_None/sub-060_ses-03_task-dist_desc-oa_bold_autobox_combined.nii.gz', 'R:/preprocess_batch-001_rest/bold_datasink/commonspace_mask/_scan_info_subject_id060.session03_split_name_sub-060_ses-03_desc-o_T2w/_run_None/sub-060_ses-03_task-rest_desc-oa_bold_autobox_EPI_brain_mask.nii.gz'], ['R:/preprocess_batch-001/commonspace_bold/_scan_info_subject_id050.session03_split_name_sub-050_ses-03_desc-o_T2w/_run_None/sub-050_ses-03_task-dist_desc-oa_bold_autobox_combined.nii.gz', 'R:/preprocess_batch-001_rest/bold_datasink/commonspace_mask/_scan_info_subject_id050.session03_split_name_sub-050_ses-03_desc-o_T2w/_run_None/sub-050_ses-03_task-rest_desc-oa_bold_autobox_EPI_brain_mask.nii.gz'], ['R:/preprocess_batch-001/commonspace_bold/_scan_info_subject_id066.session03_split_name_sub-066_ses-03_desc-o_T2w/_run_None/sub-066_ses-03_task-dist_desc-oa_bold_autobox_combined.nii.gz', 'R:/preprocess_batch-001_rest/bold_datasink/commonspace_mask/_scan_info_subject_id066.session03_split_name_sub-066_ses-03_desc-o_T2w/_run_None/sub-066_ses-03_task-rest_desc-oa_bold_autobox_EPI_brain_mask.nii.gz'], ['R:/preprocess_batch-002/commonspace_bold/_scan_info_subject_id094.session03_split_name_sub-094_ses-03_desc-o_T2w/_run_None/sub-094_ses-03_task-dist_desc-oa_bold_autobox_combined.nii.gz', 'R:/preprocess_batch-002_rest/bold_datasink/commonspace_mask/_scan_info_subject_id094.session03_split_name_sub-094_ses-03_desc-o_T2w/_run_None/sub-094_ses-03_task-rest_desc-oa_bold_autobox_EPI_brain_mask.nii.gz'], ['R:/preprocess_batch-002/commonspace_bold/_scan_info_subject_id098.session03_split_name_sub-098_ses-03_desc-o_T2w/_run_None/sub-098_ses-03_task-dist_desc-oa_bold_autobox_combined.nii.gz', 'R:/preprocess_batch-002_rest/bold_datasink/commonspace_mask/_scan_info_subject_id098.session03_split_name_sub-098_ses-03_desc-o_T2w/_run_None/sub-098_ses-03_task- ...
# X_train con exito
# holaaaa, se metio al mask and bold
# SE METIO AL DISTTTTTTTTTT
# SE METIO AL LOGIN
# sesions:  [3]
# SESION:  3
# ENTRO AL SEGUNDO SUB BATCH
# Se metió al 68
# j:  52
# ENTRO AL SEGUNDO SUB BATCH
# ENTRO AL SEGUNDO SUB BATCH
# ENTRO AL SEGUNDO SUB BATCH
# AHHHHHHHHHHHHHHHHHH [['R:/preprocess_batch-002/commonspace_bold/_scan_info_subject_id100.session03_split_name_sub-100_ses-03_desc-o_T2w/_run_None/sub-100_ses-03_task-dist_desc-oa_bold_autobox_combined.nii.gz', 'R:/preprocess_batch-002_rest/bold_datasink/commonspace_mask/_scan_info_subject_id100.session03_split_name_sub-100_ses-03_desc-o_T2w/_run_None/sub-100_ses-03_task-rest_desc-oa_bold_autobox_EPI_brain_mask.nii.gz'], ['R:/preprocess_batch-001/commonspace_bold/_scan_info_subject_id052.session03_split_name_sub-052_ses-03_desc-o_T2w/_run_None/sub-052_ses-03_task-dist_desc-oa_bold_autobox_combined.nii.gz', 'R:/preprocess_batch-001_rest/bold_datasink/commonspace_mask/_scan_info_subject_id052.session03_split_name_sub-052_ses-03_desc-o_T2w/_run_None/sub-052_ses-03_task-rest_desc-oa_bold_autobox_EPI_brain_mask.nii.gz'], ['R:/preprocess_batch-002/commonspace_bold/_scan_info_subject_id077.session03_split_name_sub-077_ses-03_desc-o_T2w/_run_None/sub-077_ses-03_task-dist_desc-oa_bold_autobox_combined.nii.gz', 'R:/preprocess_batch-002_rest/bold_datasink/commonspace_mask/_scan_info_subject_id077.session03_split_name_sub-077_ses-03_desc-o_T2w/_run_None/sub-077_ses-03_task-rest_desc-oa_bold_autobox_EPI_brain_mask.nii.gz'], ['R:/preprocess_batch-002/commonspace_bold/_scan_info_subject_id078.session03_split_name_sub-078_ses-03_desc-o_T2w/_run_None/sub-078_ses-03_task-dist_desc-oa_bold_autobox_combined.nii.gz', 'R:/preprocess_batch-002_rest/bold_datasink/commonspace_mask/_scan_info_subject_id078.session03_split_name_sub-078_ses-03_desc-o_T2w/_run_None/sub-078_ses-03_task-rest_desc-oa_bold_autobox_EPI_brain_mask.nii.gz'], ['R:/preprocess_batch-002/commonspace_bold/_scan_info_subject_id096.session03_split_name_sub-096_ses-03_desc-o_T2w/_run_None/sub-096_ses-03_task-dist_desc-oa_bold_autobox_combined.nii.gz', 'R:/preprocess_batch-002_rest/bold_datasink/commonspace_mask/_scan_info_subject_id096.session03_split_name_sub-096_ses-03_desc-o_T2w/_run_None/sub-096_ses-03_task-rest_desc-oa_bold_autobox_EPI_brain_mask.nii.gz']]
# X_test con exito
# holaaaa, se metio al mask and bold
# SE METIO AL DISTTTTTTTTTT
# SE METIO AL LOGIN
# sesions:  [3]
# SESION:  3
# Se metió al 68
# j:  51
# ENTRO AL SEGUNDO SUB BATCH
# AHHHHHHHHHHHHHHHHHH [['R:/preprocess_batch-001/commonspace_bold/_scan_info_subject_id051.session03_split_name_sub-051_ses-03_desc-o_T2w/_run_None/sub-051_ses-03_task-dist_desc-oa_bold_autobox_combined.nii.gz', 'R:/preprocess_batch-001_rest/bold_datasink/commonspace_mask/_scan_info_subject_id051.session03_split_name_sub-051_ses-03_desc-o_T2w/_run_None/sub-051_ses-03_task-rest_desc-oa_bold_autobox_EPI_brain_mask.nii.gz'], ['R:/preprocess_batch-002/commonspace_bold/_scan_info_subject_id095.session03_split_name_sub-095_ses-03_desc-o_T2w/_run_None/sub-095_ses-03_task-dist_desc-oa_bold_autobox_combined.nii.gz', 'R:/preprocess_batch-002_rest/bold_datasink/commonspace_mask/_scan_info_subject_id095.session03_split_name_sub-095_ses-03_desc-o_T2w/_run_None/sub-095_ses-03_task-rest_desc-oa_bold_autobox_EPI_brain_mask.nii.gz']]
# X_val con exito
# sub train:
# ['R:/preprocess_batch-002/commonspace_bold/_scan_info_subject_id082.session03_split_name_sub-082_ses-03_desc-o_T2w/_run_None/sub-082_ses-03_task-dist_desc-oa_bold_autobox_combined.nii.gz'
#  'R:/preprocess_batch-002/commonspace_bold/_scan_info_subject_id093.session03_split_name_sub-093_ses-03_desc-o_T2w/_run_None/sub-093_ses-03_task-dist_desc-oa_bold_autobox_combined.nii.gz'
#  'R:/preprocess_batch-001/commonspace_bold/_scan_info_subject_id057.session03_split_name_sub-057_ses-03_desc-o_T2w/_run_None/sub-057_ses-03_task-dist_desc-oa_bold_autobox_combined.nii.gz'
#  'R:/preprocess_batch-002/commonspace_bold/_scan_info_subject_id081.session03_split_name_sub-081_ses-03_desc-o_T2w/_run_None/sub-081_ses-03_task-dist_desc-oa_bold_autobox_combined.nii.gz'
#  'R:/preprocess_batch-002/commonspace_bold/_scan_info_subject_id074.session03_split_name_sub-074_ses-03_desc-o_T2w/_run_None/sub-074_ses-03_task-dist_desc-oa_bold_autobox_combined.nii.gz'
#  'R:/preprocess_batch-001/commonspace_bold/_scan_info_subject_id060.session03_split_name_sub-060_ses-03_desc-o_T2w/_run_None/sub-060_ses-03_task-dist_desc-oa_bold_autobox_combined.nii.gz'
#  'R:/preprocess_batch-001/commonspace_bold/_scan_info_subject_id050.session03_split_name_sub-050_ses-03_desc-o_T2w/_run_None/sub-050_ses-03_task-dist_desc-oa_bold_autobox_combined.nii.gz'
#  'R:/preprocess_batch-001/commonspace_bold/_scan_info_subject_id066.session03_split_name_sub-066_ses-03_desc-o_T2w/_run_None/sub-066_ses-03_task-dist_desc-oa_bold_autobox_combined.nii.gz'
#  'R:/preprocess_batch-002/commonspace_bold/_scan_info_subject_id094.session03_split_name_sub-094_ses-03_desc-o_T2w/_run_None/sub-094_ses-03_task-dist_desc-oa_bold_autobox_combined.nii.gz'
#  'R:/preprocess_batch-002/commonspace_bold/_scan_info_subject_id098.session03_split_name_sub-098_ses-03_desc-o_T2w/_run_None/sub-098_ses-03_task-dist_desc-oa_bold_autobox_combined.nii.gz'
#  'R:/preprocess_batch-002/commonspace_bold/_scan_info_subject_id073.session03_split_name_sub-073_ses-03_desc-o_T2w/_run_None/sub-073_ses-03_task-dist_desc-oa_bold_autobox_combined.nii.gz']
# sub test:
# ['R:/preprocess_batch-002/commonspace_bold/_scan_info_subject_id100.session03_split_name_sub-100_ses-03_desc-o_T2w/_run_None/sub-100_ses-03_task-dist_desc-oa_bold_autobox_combined.nii.gz'
#  'R:/preprocess_batch-001/commonspace_bold/_scan_info_subject_id052.session03_split_name_sub-052_ses-03_desc-o_T2w/_run_None/sub-052_ses-03_task-dist_desc-oa_bold_autobox_combined.nii.gz'
#  'R:/preprocess_batch-002/commonspace_bold/_scan_info_subject_id077.session03_split_name_sub-077_ses-03_desc-o_T2w/_run_None/sub-077_ses-03_task-dist_desc-oa_bold_autobox_combined.nii.gz'
#  'R:/preprocess_batch-002/commonspace_bold/_scan_info_subject_id078.session03_split_name_sub-078_ses-03_desc-o_T2w/_run_None/sub-078_ses-03_task-dist_desc-oa_bold_autobox_combined.nii.gz'
#  'R:/preprocess_batch-002/commonspace_bold/_scan_info_subject_id096.session03_split_name_sub-096_ses-03_desc-o_T2w/_run_None/sub-096_ses-03_task-dist_desc-oa_bold_autobox_combined.nii.gz']
# sub val:
# ['R:/preprocess_batch-001/commonspace_bold/_scan_info_subject_id051.session03_split_name_sub-051_ses-03_desc-o_T2w/_run_None/sub-051_ses-03_task-dist_desc-oa_bold_autobox_combined.nii.gz'
#  'R:/preprocess_batch-002/commonspace_bold/_scan_info_subject_id095.session03_split_name_sub-095_ses-03_desc-o_T2w/_run_None/sub-095_ses-03_task-dist_desc-oa_bold_autobox_combined.nii.gz']
# # sesiones Train 11
# # sesiones Test 5
# # sesiones Val 2
# Starting VGG 16 3D-----------------------------------------------------
# wandb: WARNING WandbCallback is deprecated and will be removed in a future release. Please use the WandbMetricsLogger, WandbModelCheckpoint, and WandbEvalCallback callbacks instead. See https://docs.wandb.ai/guides/integrations/keras for more information.
# Training
# Starting VGG 16 3D-----------------------------------------------------
# Epoch 1/10
# W&B Graph visualization desactivada (inbound_layers incompatibles con Keras 3.x).
# 418/418 [==============================] - 1396s 3s/step - loss: 20.4964 - Accuracy: 0.6879 - val_loss: 18.6757 - val_Accuracy: 0.3000
# Epoch 2/10
# 418/418 [==============================] - 1309s 3s/step - loss: 16.6013 - Accuracy: 0.9337 - val_loss: 16.1940 - val_Accuracy: 0.4886
# Epoch 3/10
# 418/418 [==============================] - 1304s 3s/step - loss: 13.6377 - Accuracy: 0.9809 - val_loss: 14.8882 - val_Accuracy: 0.3728
# Epoch 4/10
# 418/418 [==============================] - 1306s 3s/step - loss: 11.3168 - Accuracy: 0.9931 - val_loss: 12.4185 - val_Accuracy: 0.0509
# Epoch 5/10
# 418/418 [==============================] - 1303s 3s/step - loss: 9.3715 - Accuracy: 0.9976 - val_loss: 10.6305 - val_Accuracy: 0.0325
# Epoch 6/10
# 418/418 [==============================] - 1328s 3s/step - loss: 7.7549 - Accuracy: 0.9967 - val_loss: 9.2137 - val_Accuracy: 0.3009
# Epoch 7/10
# 418/418 [==============================] - 1331s 3s/step - loss: 6.4080 - Accuracy: 0.9994 - val_loss: 7.9257 - val_Accuracy: 0.4219
# Epoch 8/10
# 418/418 [==============================] - 1315s 3s/step - loss: 5.3064 - Accuracy: 0.9986 - val_loss: 6.6599 - val_Accuracy: 0.5000
# Epoch 9/10
# 418/418 [==============================] - 1312s 3s/step - loss: 4.4108 - Accuracy: 0.9995 - val_loss: 5.9748 - val_Accuracy: 0.4947
# Epoch 10/10
# 418/418 [==============================] - 1334s 3s/step - loss: 3.6894 - Accuracy: 0.9994 - val_loss: 5.7168 - val_Accuracy: 0.4772
# Duration (CNN): 3:40:42.537703
# predicts CNN
# 190/190 [==============================] - 95s 502ms/step
# mislabeled subjects:
#  Counter({'R:/preprocess_batch-002/commonspace_bold/_scan_info_subject_id077.session03_split_name_sub-077_ses-03_desc-o_T2w/_run_None/sub-077_ses-03_task-dist_desc-oa_bold_autobox_combined.nii.gz': 570, 'R:/preprocess_batch-002/commonspace_bold/_scan_info_subject_id078.session03_split_name_sub-078_ses-03_desc-o_T2w/_run_None/sub-078_ses-03_task-dist_desc-oa_bold_autobox_combined.nii.gz': 489, 'R:/preprocess_batch-002/commonspace_bold/_scan_info_subject_id100.session03_split_name_sub-100_ses-03_desc-o_T2w/_run_None/sub-100_ses-03_task-dist_desc-oa_bold_autobox_combined.nii.gz': 43})
# evaluating CNN
# 190/190 [==============================] - 96s 506ms/step - loss: 4.0002 - Accuracy: 0.6133
# Coverage male: 0.6326421261319187
# Coverage female: 0.4269410062690886
# CM CNN
# Run # 2
# Finishing previous runs because reinit is set to 'default'.
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>Accuracy</td><td>▁▇████████</td></tr><tr><td>epoch</td><td>▁▂▃▃▄▅▆▆▇█</td></tr><tr><td>loss</td><td>█▆▅▄▃▃▂▂▁▁</td></tr><tr><td>test_acc</td><td>▁</td></tr><tr><td>val_Accuracy</td><td>▅█▆▁▁▅▇███</td></tr><tr><td>val_loss</td><td>█▇▆▅▄▃▂▂▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>Accuracy</td><td>0.99936</td></tr><tr><td>best_epoch</td><td>9</td></tr><tr><td>best_val_loss</td><td>5.71676</td></tr><tr><td>epoch</td><td>9</td></tr><tr><td>loss</td><td>3.68937</td></tr><tr><td>test_acc</td><td>0.61333</td></tr><tr><td>time_running</td><td>3:40:42.537703</td></tr><tr><td>val_Accuracy</td><td>0.47719</td></tr><tr><td>val_loss</td><td>5.71676</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">fearless-capybara-19</strong> at: <a href='https://wandb.ai/mansoor35/Male%20vs%20Female%28GradCam%29%20coverage/runs/q5sjekpi' target="_blank">https://wandb.ai/mansoor35/Male%20vs%20Female%28GradCam%29%20coverage/runs/q5sjekpi</a><br> View project at: <a href='https://wandb.ai/mansoor35/Male%20vs%20Female%28GradCam%29%20coverage' target="_blank">https://wandb.ai/mansoor35/Male%20vs%20Female%28GradCam%29%20coverage</a><br>Synced 5 W&B file(s), 1 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>C:\Users\L03117~1\AppData\Local\Temp\wandb\run-20251202_112426-q5sjekpi\logs</code>
# Tracking run with wandb version 0.22.0
# Run data is saved locally in <code>C:\Users\L03117~1\AppData\Local\Temp\wandb\run-20251202_150854-cc0iaed6</code>
# Syncing run <strong><a href='https://wandb.ai/mansoor35/Male%20vs%20Female%28GradCam%29%20coverage/runs/cc0iaed6' target="_blank">dauntless-dew-20</a></strong> to <a href='https://wandb.ai/mansoor35/Male%20vs%20Female%28GradCam%29%20coverage' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/mansoor35/Male%20vs%20Female%28GradCam%29%20coverage' target="_blank">https://wandb.ai/mansoor35/Male%20vs%20Female%28GradCam%29%20coverage</a>
#  View run at <a href='https://wandb.ai/mansoor35/Male%20vs%20Female%28GradCam%29%20coverage/runs/cc0iaed6' target="_blank">https://wandb.ai/mansoor35/Male%20vs%20Female%28GradCam%29%20coverage/runs/cc0iaed6</a>
# holaaaa, se metio al mask and bold
# SE METIO AL DISTTTTTTTTTT
# SE METIO AL LOGIN
# sesions:  [3]
# SESION:  3
# ENTRO AL SEGUNDO SUB BATCH
# ENTRO AL SEGUNDO SUB BATCH
# ENTRO AL SEGUNDO SUB BATCH
# Se metió al 68
# j:  65
# ENTRO AL SEGUNDO SUB BATCH
# Se metió al 68
# j:  49
# ENTRO AL SEGUNDO SUB BATCH
# ENTRO AL SEGUNDO SUB BATCH
# Se metió al 68
# j:  50
# Se metió al 68
# j:  57
# ENTRO AL SEGUNDO SUB BATCH
# AHHHHHHHHHHHHHHHHHH [['R:/preprocess_batch-002/commonspace_bold/_scan_info_subject_id082.session03_split_name_sub-082_ses-03_desc-o_T2w/_run_None/sub-082_ses-03_task-dist_desc-oa_bold_autobox_combined.nii.gz', 'R:/preprocess_batch-002_rest/bold_datasink/commonspace_mask/_scan_info_subject_id082.session03_split_name_sub-082_ses-03_desc-o_T2w/_run_None/sub-082_ses-03_task-rest_desc-oa_bold_autobox_EPI_brain_mask.nii.gz'], ['R:/preprocess_batch-002/commonspace_bold/_scan_info_subject_id079.session03_split_name_sub-079_ses-03_desc-o_T2w/_run_None/sub-079_ses-03_task-dist_desc-oa_bold_autobox_combined.nii.gz', 'R:/preprocess_batch-002_rest/bold_datasink/commonspace_mask/_scan_info_subject_id079.session03_split_name_sub-079_ses-03_desc-o_T2w/_run_None/sub-079_ses-03_task-rest_desc-oa_bold_autobox_EPI_brain_mask.nii.gz'], ['R:/preprocess_batch-002/commonspace_bold/_scan_info_subject_id099.session03_split_name_sub-099_ses-03_desc-o_T2w/_run_None/sub-099_ses-03_task-dist_desc-oa_bold_autobox_combined.nii.gz', 'R:/preprocess_batch-002_rest/bold_datasink/commonspace_mask/_scan_info_subject_id099.session03_split_name_sub-099_ses-03_desc-o_T2w/_run_None/sub-099_ses-03_task-rest_desc-oa_bold_autobox_EPI_brain_mask.nii.gz'], ['R:/preprocess_batch-001/commonspace_bold/_scan_info_subject_id065.session03_split_name_sub-065_ses-03_desc-o_T2w/_run_None/sub-065_ses-03_task-dist_desc-oa_bold_autobox_combined.nii.gz', 'R:/preprocess_batch-001_rest/bold_datasink/commonspace_mask/_scan_info_subject_id065.session03_split_name_sub-065_ses-03_desc-o_T2w/_run_None/sub-065_ses-03_task-rest_desc-oa_bold_autobox_EPI_brain_mask.nii.gz'], ['R:/preprocess_batch-002/commonspace_bold/_scan_info_subject_id098.session03_split_name_sub-098_ses-03_desc-o_T2w/_run_None/sub-098_ses-03_task-dist_desc-oa_bold_autobox_combined.nii.gz', 'R:/preprocess_batch-002_rest/bold_datasink/commonspace_mask/_scan_info_subject_id098.session03_split_name_sub-098_ses-03_desc-o_T2w/_run_None/sub-098_ses-03_task-rest_desc-oa_bold_autobox_EPI_brain_mask.nii.gz'], ['R:/preprocess_batch-001/commonspace_bold/_scan_info_subject_id049.session03_split_name_sub-049_ses-03_desc-o_T2w/_run_None/sub-049_ses-03_task-dist_desc-oa_bold_autobox_combined.nii.gz', 'R:/preprocess_batch-001_rest/bold_datasink/commonspace_mask/_scan_info_subject_id049.session03_split_name_sub-049_ses-03_desc-o_T2w/_run_None/sub-049_ses-03_task-rest_desc-oa_bold_autobox_EPI_brain_mask.nii.gz'], ['R:/preprocess_batch-002/commonspace_bold/_scan_info_subject_id080.session03_split_name_sub-080_ses-03_desc-o_T2w/_run_None/sub-080_ses-03_task-dist_desc-oa_bold_autobox_combined.nii.gz', 'R:/preprocess_batch-002_rest/bold_datasink/commonspace_mask/_scan_info_subject_id080.session03_split_name_sub-080_ses-03_desc-o_T2w/_run_None/sub-080_ses-03_task-rest_desc-oa_bold_autobox_EPI_brain_mask.nii.gz'], ['R:/preprocess_batch-002/commonspace_bold/_scan_info_subject_id081.session03_split_name_sub-081_ses-03_desc-o_T2w/_run_None/sub-081_ses-03_task-dist_desc-oa_bold_autobox_combined.nii.gz', 'R:/preprocess_batch-002_rest/bold_datasink/commonspace_mask/_scan_info_subject_id081.session03_split_name_sub-081_ses-03_desc-o_T2w/_run_None/sub-081_ses-03_task-rest_desc-oa_bold_autobox_EPI_brain_mask.nii.gz'], ['R:/preprocess_batch-001/commonspace_bold/_scan_info_subject_id050.session03_split_name_sub-050_ses-03_desc-o_T2w/_run_None/sub-050_ses-03_task-dist_desc-oa_bold_autobox_combined.nii.gz', 'R:/preprocess_batch-001_rest/bold_datasink/commonspace_mask/_scan_info_subject_id050.session03_split_name_sub-050_ses-03_desc-o_T2w/_run_None/sub-050_ses-03_task-rest_desc-oa_bold_autobox_EPI_brain_mask.nii.gz'], ['R:/preprocess_batch-001/commonspace_bold/_scan_info_subject_id057.session03_split_name_sub-057_ses-03_desc-o_T2w/_run_None/sub-057_ses-03_task-dist_desc-oa_bold_autobox_combined.nii.gz', 'R:/preprocess_batch-001_rest/bold_datasink/commonspace_mask/_scan_info_subject_id057.session03_split_name_sub-057_ses-03_desc-o_T2w/_run_None/sub-057_ses-03_task- ...
# X_train con exito
# holaaaa, se metio al mask and bold
# SE METIO AL DISTTTTTTTTTT
# SE METIO AL LOGIN
# sesions:  [3]
# SESION:  3
# ENTRO AL SEGUNDO SUB BATCH
# Se metió al 68
# j:  52
# ENTRO AL SEGUNDO SUB BATCH
# ENTRO AL SEGUNDO SUB BATCH
# ENTRO AL SEGUNDO SUB BATCH
# AHHHHHHHHHHHHHHHHHH [['R:/preprocess_batch-002/commonspace_bold/_scan_info_subject_id100.session03_split_name_sub-100_ses-03_desc-o_T2w/_run_None/sub-100_ses-03_task-dist_desc-oa_bold_autobox_combined.nii.gz', 'R:/preprocess_batch-002_rest/bold_datasink/commonspace_mask/_scan_info_subject_id100.session03_split_name_sub-100_ses-03_desc-o_T2w/_run_None/sub-100_ses-03_task-rest_desc-oa_bold_autobox_EPI_brain_mask.nii.gz'], ['R:/preprocess_batch-001/commonspace_bold/_scan_info_subject_id052.session03_split_name_sub-052_ses-03_desc-o_T2w/_run_None/sub-052_ses-03_task-dist_desc-oa_bold_autobox_combined.nii.gz', 'R:/preprocess_batch-001_rest/bold_datasink/commonspace_mask/_scan_info_subject_id052.session03_split_name_sub-052_ses-03_desc-o_T2w/_run_None/sub-052_ses-03_task-rest_desc-oa_bold_autobox_EPI_brain_mask.nii.gz'], ['R:/preprocess_batch-002/commonspace_bold/_scan_info_subject_id077.session03_split_name_sub-077_ses-03_desc-o_T2w/_run_None/sub-077_ses-03_task-dist_desc-oa_bold_autobox_combined.nii.gz', 'R:/preprocess_batch-002_rest/bold_datasink/commonspace_mask/_scan_info_subject_id077.session03_split_name_sub-077_ses-03_desc-o_T2w/_run_None/sub-077_ses-03_task-rest_desc-oa_bold_autobox_EPI_brain_mask.nii.gz'], ['R:/preprocess_batch-002/commonspace_bold/_scan_info_subject_id078.session03_split_name_sub-078_ses-03_desc-o_T2w/_run_None/sub-078_ses-03_task-dist_desc-oa_bold_autobox_combined.nii.gz', 'R:/preprocess_batch-002_rest/bold_datasink/commonspace_mask/_scan_info_subject_id078.session03_split_name_sub-078_ses-03_desc-o_T2w/_run_None/sub-078_ses-03_task-rest_desc-oa_bold_autobox_EPI_brain_mask.nii.gz'], ['R:/preprocess_batch-002/commonspace_bold/_scan_info_subject_id096.session03_split_name_sub-096_ses-03_desc-o_T2w/_run_None/sub-096_ses-03_task-dist_desc-oa_bold_autobox_combined.nii.gz', 'R:/preprocess_batch-002_rest/bold_datasink/commonspace_mask/_scan_info_subject_id096.session03_split_name_sub-096_ses-03_desc-o_T2w/_run_None/sub-096_ses-03_task-rest_desc-oa_bold_autobox_EPI_brain_mask.nii.gz']]
# X_test con exito
# holaaaa, se metio al mask and bold
# SE METIO AL DISTTTTTTTTTT
# SE METIO AL LOGIN
# sesions:  [3]
# SESION:  3
# Se metió al 68
# j:  51
# ENTRO AL SEGUNDO SUB BATCH
# AHHHHHHHHHHHHHHHHHH [['R:/preprocess_batch-001/commonspace_bold/_scan_info_subject_id051.session03_split_name_sub-051_ses-03_desc-o_T2w/_run_None/sub-051_ses-03_task-dist_desc-oa_bold_autobox_combined.nii.gz', 'R:/preprocess_batch-001_rest/bold_datasink/commonspace_mask/_scan_info_subject_id051.session03_split_name_sub-051_ses-03_desc-o_T2w/_run_None/sub-051_ses-03_task-rest_desc-oa_bold_autobox_EPI_brain_mask.nii.gz'], ['R:/preprocess_batch-002/commonspace_bold/_scan_info_subject_id093.session03_split_name_sub-093_ses-03_desc-o_T2w/_run_None/sub-093_ses-03_task-dist_desc-oa_bold_autobox_combined.nii.gz', 'R:/preprocess_batch-002_rest/bold_datasink/commonspace_mask/_scan_info_subject_id093.session03_split_name_sub-093_ses-03_desc-o_T2w/_run_None/sub-093_ses-03_task-rest_desc-oa_bold_autobox_EPI_brain_mask.nii.gz']]
# X_val con exito
# sub train:
# ['R:/preprocess_batch-002/commonspace_bold/_scan_info_subject_id082.session03_split_name_sub-082_ses-03_desc-o_T2w/_run_None/sub-082_ses-03_task-dist_desc-oa_bold_autobox_combined.nii.gz'
#  'R:/preprocess_batch-002/commonspace_bold/_scan_info_subject_id079.session03_split_name_sub-079_ses-03_desc-o_T2w/_run_None/sub-079_ses-03_task-dist_desc-oa_bold_autobox_combined.nii.gz'
#  'R:/preprocess_batch-002/commonspace_bold/_scan_info_subject_id099.session03_split_name_sub-099_ses-03_desc-o_T2w/_run_None/sub-099_ses-03_task-dist_desc-oa_bold_autobox_combined.nii.gz'
#  'R:/preprocess_batch-001/commonspace_bold/_scan_info_subject_id065.session03_split_name_sub-065_ses-03_desc-o_T2w/_run_None/sub-065_ses-03_task-dist_desc-oa_bold_autobox_combined.nii.gz'
#  'R:/preprocess_batch-002/commonspace_bold/_scan_info_subject_id098.session03_split_name_sub-098_ses-03_desc-o_T2w/_run_None/sub-098_ses-03_task-dist_desc-oa_bold_autobox_combined.nii.gz'
#  'R:/preprocess_batch-001/commonspace_bold/_scan_info_subject_id049.session03_split_name_sub-049_ses-03_desc-o_T2w/_run_None/sub-049_ses-03_task-dist_desc-oa_bold_autobox_combined.nii.gz'
#  'R:/preprocess_batch-002/commonspace_bold/_scan_info_subject_id080.session03_split_name_sub-080_ses-03_desc-o_T2w/_run_None/sub-080_ses-03_task-dist_desc-oa_bold_autobox_combined.nii.gz'
#  'R:/preprocess_batch-002/commonspace_bold/_scan_info_subject_id081.session03_split_name_sub-081_ses-03_desc-o_T2w/_run_None/sub-081_ses-03_task-dist_desc-oa_bold_autobox_combined.nii.gz'
#  'R:/preprocess_batch-001/commonspace_bold/_scan_info_subject_id050.session03_split_name_sub-050_ses-03_desc-o_T2w/_run_None/sub-050_ses-03_task-dist_desc-oa_bold_autobox_combined.nii.gz'
#  'R:/preprocess_batch-001/commonspace_bold/_scan_info_subject_id057.session03_split_name_sub-057_ses-03_desc-o_T2w/_run_None/sub-057_ses-03_task-dist_desc-oa_bold_autobox_combined.nii.gz'
#  'R:/preprocess_batch-002/commonspace_bold/_scan_info_subject_id094.session03_split_name_sub-094_ses-03_desc-o_T2w/_run_None/sub-094_ses-03_task-dist_desc-oa_bold_autobox_combined.nii.gz']
# sub test:
# ['R:/preprocess_batch-002/commonspace_bold/_scan_info_subject_id100.session03_split_name_sub-100_ses-03_desc-o_T2w/_run_None/sub-100_ses-03_task-dist_desc-oa_bold_autobox_combined.nii.gz'
#  'R:/preprocess_batch-001/commonspace_bold/_scan_info_subject_id052.session03_split_name_sub-052_ses-03_desc-o_T2w/_run_None/sub-052_ses-03_task-dist_desc-oa_bold_autobox_combined.nii.gz'
#  'R:/preprocess_batch-002/commonspace_bold/_scan_info_subject_id077.session03_split_name_sub-077_ses-03_desc-o_T2w/_run_None/sub-077_ses-03_task-dist_desc-oa_bold_autobox_combined.nii.gz'
#  'R:/preprocess_batch-002/commonspace_bold/_scan_info_subject_id078.session03_split_name_sub-078_ses-03_desc-o_T2w/_run_None/sub-078_ses-03_task-dist_desc-oa_bold_autobox_combined.nii.gz'
#  'R:/preprocess_batch-002/commonspace_bold/_scan_info_subject_id096.session03_split_name_sub-096_ses-03_desc-o_T2w/_run_None/sub-096_ses-03_task-dist_desc-oa_bold_autobox_combined.nii.gz']
# sub val:
# ['R:/preprocess_batch-001/commonspace_bold/_scan_info_subject_id051.session03_split_name_sub-051_ses-03_desc-o_T2w/_run_None/sub-051_ses-03_task-dist_desc-oa_bold_autobox_combined.nii.gz'
#  'R:/preprocess_batch-002/commonspace_bold/_scan_info_subject_id093.session03_split_name_sub-093_ses-03_desc-o_T2w/_run_None/sub-093_ses-03_task-dist_desc-oa_bold_autobox_combined.nii.gz']
# # sesiones Train 11
# # sesiones Test 5
# # sesiones Val 2
# Starting VGG 16 3D-----------------------------------------------------
# Training
# Starting VGG 16 3D-----------------------------------------------------
# Epoch 1/10
# W&B Graph visualization desactivada (inbound_layers incompatibles con Keras 3.x).
# 418/418 [==============================] - 1337s 3s/step - loss: 20.4845 - Accuracy: 0.6352 - val_loss: 19.5154 - val_Accuracy: 0.5000
# Epoch 2/10
# 418/418 [==============================] - 1340s 3s/step - loss: 16.7188 - Accuracy: 0.6365 - val_loss: 16.8551 - val_Accuracy: 0.5000
# Epoch 3/10
# 418/418 [==============================] - 1332s 3s/step - loss: 13.7630 - Accuracy: 0.7499 - val_loss: 14.1847 - val_Accuracy: 0.4904
# Epoch 4/10
# 418/418 [==============================] - 1330s 3s/step - loss: 11.2881 - Accuracy: 0.9895 - val_loss: 11.0313 - val_Accuracy: 0.4474
# Epoch 5/10
# 418/418 [==============================] - 1312s 3s/step - loss: 9.2654 - Accuracy: 0.9982 - val_loss: 10.6988 - val_Accuracy: 0.2868
# Epoch 6/10
# 418/418 [==============================] - 1319s 3s/step - loss: 7.6468 - Accuracy: 1.0000 - val_loss: 8.6858 - val_Accuracy: 0.4947
# Epoch 7/10
# 418/418 [==============================] - 1311s 3s/step - loss: 6.3135 - Accuracy: 1.0000 - val_loss: 6.6154 - val_Accuracy: 0.6114
# Epoch 8/10
# 418/418 [==============================] - 1346s 3s/step - loss: 5.2181 - Accuracy: 0.9998 - val_loss: 6.5832 - val_Accuracy: 0.5360
# Epoch 9/10
# 418/418 [==============================] - 1343s 3s/step - loss: 4.3257 - Accuracy: 1.0000 - val_loss: 5.1259 - val_Accuracy: 0.5640
# Epoch 10/10
# 418/418 [==============================] - 1329s 3s/step - loss: 3.6104 - Accuracy: 1.0000 - val_loss: 5.5219 - val_Accuracy: 0.4816
# Duration (CNN): 3:41:42.375789
# predicts CNN
# 190/190 [==============================] - 95s 500ms/step
# mislabeled subjects:
#  Counter({'R:/preprocess_batch-002/commonspace_bold/_scan_info_subject_id100.session03_split_name_sub-100_ses-03_desc-o_T2w/_run_None/sub-100_ses-03_task-dist_desc-oa_bold_autobox_combined.nii.gz': 570, 'R:/preprocess_batch-002/commonspace_bold/_scan_info_subject_id096.session03_split_name_sub-096_ses-03_desc-o_T2w/_run_None/sub-096_ses-03_task-dist_desc-oa_bold_autobox_combined.nii.gz': 317})
# evaluating CNN
# 190/190 [==============================] - 96s 506ms/step - loss: 3.9563 - Accuracy: 0.6888
# Coverage male: 0.44987408240904464
# Coverage female: 0.3491935915983497
# CM CNN
# Run # 3
# Finishing previous runs because reinit is set to 'default'.
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>Accuracy</td><td>▁▁▃███████</td></tr><tr><td>epoch</td><td>▁▂▃▃▄▅▆▆▇█</td></tr><tr><td>loss</td><td>█▆▅▄▃▃▂▂▁▁</td></tr><tr><td>test_acc</td><td>▁</td></tr><tr><td>val_Accuracy</td><td>▆▆▅▄▁▅█▆▇▅</td></tr><tr><td>val_loss</td><td>█▇▅▄▄▃▂▂▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>Accuracy</td><td>1</td></tr><tr><td>best_epoch</td><td>8</td></tr><tr><td>best_val_loss</td><td>5.12587</td></tr><tr><td>epoch</td><td>9</td></tr><tr><td>loss</td><td>3.61041</td></tr><tr><td>test_acc</td><td>0.68877</td></tr><tr><td>time_running</td><td>3:41:42.375789</td></tr><tr><td>val_Accuracy</td><td>0.48158</td></tr><tr><td>val_loss</td><td>5.52188</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">dauntless-dew-20</strong> at: <a href='https://wandb.ai/mansoor35/Male%20vs%20Female%28GradCam%29%20coverage/runs/cc0iaed6' target="_blank">https://wandb.ai/mansoor35/Male%20vs%20Female%28GradCam%29%20coverage/runs/cc0iaed6</a><br> View project at: <a href='https://wandb.ai/mansoor35/Male%20vs%20Female%28GradCam%29%20coverage' target="_blank">https://wandb.ai/mansoor35/Male%20vs%20Female%28GradCam%29%20coverage</a><br>Synced 5 W&B file(s), 1 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>C:\Users\L03117~1\AppData\Local\Temp\wandb\run-20251202_150854-cc0iaed6\logs</code>
# Tracking run with wandb version 0.22.0
# Run data is saved locally in <code>C:\Users\L03117~1\AppData\Local\Temp\wandb\run-20251202_185416-ppfym47l</code>
# Syncing run <strong><a href='https://wandb.ai/mansoor35/Male%20vs%20Female%28GradCam%29%20coverage/runs/ppfym47l' target="_blank">resilient-eon-21</a></strong> to <a href='https://wandb.ai/mansoor35/Male%20vs%20Female%28GradCam%29%20coverage' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/mansoor35/Male%20vs%20Female%28GradCam%29%20coverage' target="_blank">https://wandb.ai/mansoor35/Male%20vs%20Female%28GradCam%29%20coverage</a>
#  View run at <a href='https://wandb.ai/mansoor35/Male%20vs%20Female%28GradCam%29%20coverage/runs/ppfym47l' target="_blank">https://wandb.ai/mansoor35/Male%20vs%20Female%28GradCam%29%20coverage/runs/ppfym47l</a>
# holaaaa, se metio al mask and bold
# SE METIO AL DISTTTTTTTTTT
# SE METIO AL LOGIN
# sesions:  [3]
# SESION:  3
# Se metió al 68
# j:  66
# ENTRO AL SEGUNDO SUB BATCH
# ENTRO AL SEGUNDO SUB BATCH
# Se metió al 68
# j:  65
# ENTRO AL SEGUNDO SUB BATCH
# Se metió al 68
# j:  49
# ENTRO AL SEGUNDO SUB BATCH
# Se metió al 68
# j:  60
# ENTRO AL SEGUNDO SUB BATCH
# ENTRO AL SEGUNDO SUB BATCH
# ENTRO AL SEGUNDO SUB BATCH
# ENTRO AL SEGUNDO SUB BATCH
# AHHHHHHHHHHHHHHHHHH [['R:/preprocess_batch-001/commonspace_bold/_scan_info_subject_id066.session03_split_name_sub-066_ses-03_desc-o_T2w/_run_None/sub-066_ses-03_task-dist_desc-oa_bold_autobox_combined.nii.gz', 'R:/preprocess_batch-001_rest/bold_datasink/commonspace_mask/_scan_info_subject_id066.session03_split_name_sub-066_ses-03_desc-o_T2w/_run_None/sub-066_ses-03_task-rest_desc-oa_bold_autobox_EPI_brain_mask.nii.gz'], ['R:/preprocess_batch-002/commonspace_bold/_scan_info_subject_id079.session03_split_name_sub-079_ses-03_desc-o_T2w/_run_None/sub-079_ses-03_task-dist_desc-oa_bold_autobox_combined.nii.gz', 'R:/preprocess_batch-002_rest/bold_datasink/commonspace_mask/_scan_info_subject_id079.session03_split_name_sub-079_ses-03_desc-o_T2w/_run_None/sub-079_ses-03_task-rest_desc-oa_bold_autobox_EPI_brain_mask.nii.gz'], ['R:/preprocess_batch-002/commonspace_bold/_scan_info_subject_id073.session03_split_name_sub-073_ses-03_desc-o_T2w/_run_None/sub-073_ses-03_task-dist_desc-oa_bold_autobox_combined.nii.gz', 'R:/preprocess_batch-002_rest/bold_datasink/commonspace_mask/_scan_info_subject_id073.session03_split_name_sub-073_ses-03_desc-o_T2w/_run_None/sub-073_ses-03_task-rest_desc-oa_bold_autobox_EPI_brain_mask.nii.gz'], ['R:/preprocess_batch-001/commonspace_bold/_scan_info_subject_id065.session03_split_name_sub-065_ses-03_desc-o_T2w/_run_None/sub-065_ses-03_task-dist_desc-oa_bold_autobox_combined.nii.gz', 'R:/preprocess_batch-001_rest/bold_datasink/commonspace_mask/_scan_info_subject_id065.session03_split_name_sub-065_ses-03_desc-o_T2w/_run_None/sub-065_ses-03_task-rest_desc-oa_bold_autobox_EPI_brain_mask.nii.gz'], ['R:/preprocess_batch-002/commonspace_bold/_scan_info_subject_id099.session03_split_name_sub-099_ses-03_desc-o_T2w/_run_None/sub-099_ses-03_task-dist_desc-oa_bold_autobox_combined.nii.gz', 'R:/preprocess_batch-002_rest/bold_datasink/commonspace_mask/_scan_info_subject_id099.session03_split_name_sub-099_ses-03_desc-o_T2w/_run_None/sub-099_ses-03_task-rest_desc-oa_bold_autobox_EPI_brain_mask.nii.gz'], ['R:/preprocess_batch-001/commonspace_bold/_scan_info_subject_id049.session03_split_name_sub-049_ses-03_desc-o_T2w/_run_None/sub-049_ses-03_task-dist_desc-oa_bold_autobox_combined.nii.gz', 'R:/preprocess_batch-001_rest/bold_datasink/commonspace_mask/_scan_info_subject_id049.session03_split_name_sub-049_ses-03_desc-o_T2w/_run_None/sub-049_ses-03_task-rest_desc-oa_bold_autobox_EPI_brain_mask.nii.gz'], ['R:/preprocess_batch-002/commonspace_bold/_scan_info_subject_id080.session03_split_name_sub-080_ses-03_desc-o_T2w/_run_None/sub-080_ses-03_task-dist_desc-oa_bold_autobox_combined.nii.gz', 'R:/preprocess_batch-002_rest/bold_datasink/commonspace_mask/_scan_info_subject_id080.session03_split_name_sub-080_ses-03_desc-o_T2w/_run_None/sub-080_ses-03_task-rest_desc-oa_bold_autobox_EPI_brain_mask.nii.gz'], ['R:/preprocess_batch-001/commonspace_bold/_scan_info_subject_id060.session03_split_name_sub-060_ses-03_desc-o_T2w/_run_None/sub-060_ses-03_task-dist_desc-oa_bold_autobox_combined.nii.gz', 'R:/preprocess_batch-001_rest/bold_datasink/commonspace_mask/_scan_info_subject_id060.session03_split_name_sub-060_ses-03_desc-o_T2w/_run_None/sub-060_ses-03_task-rest_desc-oa_bold_autobox_EPI_brain_mask.nii.gz'], ['R:/preprocess_batch-002/commonspace_bold/_scan_info_subject_id098.session03_split_name_sub-098_ses-03_desc-o_T2w/_run_None/sub-098_ses-03_task-dist_desc-oa_bold_autobox_combined.nii.gz', 'R:/preprocess_batch-002_rest/bold_datasink/commonspace_mask/_scan_info_subject_id098.session03_split_name_sub-098_ses-03_desc-o_T2w/_run_None/sub-098_ses-03_task-rest_desc-oa_bold_autobox_EPI_brain_mask.nii.gz'], ['R:/preprocess_batch-002/commonspace_bold/_scan_info_subject_id081.session03_split_name_sub-081_ses-03_desc-o_T2w/_run_None/sub-081_ses-03_task-dist_desc-oa_bold_autobox_combined.nii.gz', 'R:/preprocess_batch-002_rest/bold_datasink/commonspace_mask/_scan_info_subject_id081.session03_split_name_sub-081_ses-03_desc-o_T2w/_run_None/sub-081_ses-03_task- ...
# X_train con exito
# holaaaa, se metio al mask and bold
# SE METIO AL DISTTTTTTTTTT
# SE METIO AL LOGIN
# sesions:  [3]
# SESION:  3
# ENTRO AL SEGUNDO SUB BATCH
# Se metió al 68
# j:  52
# ENTRO AL SEGUNDO SUB BATCH
# ENTRO AL SEGUNDO SUB BATCH
# ENTRO AL SEGUNDO SUB BATCH
# AHHHHHHHHHHHHHHHHHH [['R:/preprocess_batch-002/commonspace_bold/_scan_info_subject_id100.session03_split_name_sub-100_ses-03_desc-o_T2w/_run_None/sub-100_ses-03_task-dist_desc-oa_bold_autobox_combined.nii.gz', 'R:/preprocess_batch-002_rest/bold_datasink/commonspace_mask/_scan_info_subject_id100.session03_split_name_sub-100_ses-03_desc-o_T2w/_run_None/sub-100_ses-03_task-rest_desc-oa_bold_autobox_EPI_brain_mask.nii.gz'], ['R:/preprocess_batch-001/commonspace_bold/_scan_info_subject_id052.session03_split_name_sub-052_ses-03_desc-o_T2w/_run_None/sub-052_ses-03_task-dist_desc-oa_bold_autobox_combined.nii.gz', 'R:/preprocess_batch-001_rest/bold_datasink/commonspace_mask/_scan_info_subject_id052.session03_split_name_sub-052_ses-03_desc-o_T2w/_run_None/sub-052_ses-03_task-rest_desc-oa_bold_autobox_EPI_brain_mask.nii.gz'], ['R:/preprocess_batch-002/commonspace_bold/_scan_info_subject_id077.session03_split_name_sub-077_ses-03_desc-o_T2w/_run_None/sub-077_ses-03_task-dist_desc-oa_bold_autobox_combined.nii.gz', 'R:/preprocess_batch-002_rest/bold_datasink/commonspace_mask/_scan_info_subject_id077.session03_split_name_sub-077_ses-03_desc-o_T2w/_run_None/sub-077_ses-03_task-rest_desc-oa_bold_autobox_EPI_brain_mask.nii.gz'], ['R:/preprocess_batch-002/commonspace_bold/_scan_info_subject_id078.session03_split_name_sub-078_ses-03_desc-o_T2w/_run_None/sub-078_ses-03_task-dist_desc-oa_bold_autobox_combined.nii.gz', 'R:/preprocess_batch-002_rest/bold_datasink/commonspace_mask/_scan_info_subject_id078.session03_split_name_sub-078_ses-03_desc-o_T2w/_run_None/sub-078_ses-03_task-rest_desc-oa_bold_autobox_EPI_brain_mask.nii.gz'], ['R:/preprocess_batch-002/commonspace_bold/_scan_info_subject_id096.session03_split_name_sub-096_ses-03_desc-o_T2w/_run_None/sub-096_ses-03_task-dist_desc-oa_bold_autobox_combined.nii.gz', 'R:/preprocess_batch-002_rest/bold_datasink/commonspace_mask/_scan_info_subject_id096.session03_split_name_sub-096_ses-03_desc-o_T2w/_run_None/sub-096_ses-03_task-rest_desc-oa_bold_autobox_EPI_brain_mask.nii.gz']]
# X_test con exito
# holaaaa, se metio al mask and bold
# SE METIO AL DISTTTTTTTTTT
# SE METIO AL LOGIN
# sesions:  [3]
# SESION:  3
# Se metió al 68
# j:  51
# ENTRO AL SEGUNDO SUB BATCH
# AHHHHHHHHHHHHHHHHHH [['R:/preprocess_batch-001/commonspace_bold/_scan_info_subject_id051.session03_split_name_sub-051_ses-03_desc-o_T2w/_run_None/sub-051_ses-03_task-dist_desc-oa_bold_autobox_combined.nii.gz', 'R:/preprocess_batch-001_rest/bold_datasink/commonspace_mask/_scan_info_subject_id051.session03_split_name_sub-051_ses-03_desc-o_T2w/_run_None/sub-051_ses-03_task-rest_desc-oa_bold_autobox_EPI_brain_mask.nii.gz'], ['R:/preprocess_batch-002/commonspace_bold/_scan_info_subject_id074.session03_split_name_sub-074_ses-03_desc-o_T2w/_run_None/sub-074_ses-03_task-dist_desc-oa_bold_autobox_combined.nii.gz', 'R:/preprocess_batch-002_rest/bold_datasink/commonspace_mask/_scan_info_subject_id074.session03_split_name_sub-074_ses-03_desc-o_T2w/_run_None/sub-074_ses-03_task-rest_desc-oa_bold_autobox_EPI_brain_mask.nii.gz']]
# X_val con exito
# sub train:
# ['R:/preprocess_batch-001/commonspace_bold/_scan_info_subject_id066.session03_split_name_sub-066_ses-03_desc-o_T2w/_run_None/sub-066_ses-03_task-dist_desc-oa_bold_autobox_combined.nii.gz'
#  'R:/preprocess_batch-002/commonspace_bold/_scan_info_subject_id079.session03_split_name_sub-079_ses-03_desc-o_T2w/_run_None/sub-079_ses-03_task-dist_desc-oa_bold_autobox_combined.nii.gz'
#  'R:/preprocess_batch-002/commonspace_bold/_scan_info_subject_id073.session03_split_name_sub-073_ses-03_desc-o_T2w/_run_None/sub-073_ses-03_task-dist_desc-oa_bold_autobox_combined.nii.gz'
#  'R:/preprocess_batch-001/commonspace_bold/_scan_info_subject_id065.session03_split_name_sub-065_ses-03_desc-o_T2w/_run_None/sub-065_ses-03_task-dist_desc-oa_bold_autobox_combined.nii.gz'
#  'R:/preprocess_batch-002/commonspace_bold/_scan_info_subject_id099.session03_split_name_sub-099_ses-03_desc-o_T2w/_run_None/sub-099_ses-03_task-dist_desc-oa_bold_autobox_combined.nii.gz'
#  'R:/preprocess_batch-001/commonspace_bold/_scan_info_subject_id049.session03_split_name_sub-049_ses-03_desc-o_T2w/_run_None/sub-049_ses-03_task-dist_desc-oa_bold_autobox_combined.nii.gz'
#  'R:/preprocess_batch-002/commonspace_bold/_scan_info_subject_id080.session03_split_name_sub-080_ses-03_desc-o_T2w/_run_None/sub-080_ses-03_task-dist_desc-oa_bold_autobox_combined.nii.gz'
#  'R:/preprocess_batch-001/commonspace_bold/_scan_info_subject_id060.session03_split_name_sub-060_ses-03_desc-o_T2w/_run_None/sub-060_ses-03_task-dist_desc-oa_bold_autobox_combined.nii.gz'
#  'R:/preprocess_batch-002/commonspace_bold/_scan_info_subject_id098.session03_split_name_sub-098_ses-03_desc-o_T2w/_run_None/sub-098_ses-03_task-dist_desc-oa_bold_autobox_combined.nii.gz'
#  'R:/preprocess_batch-002/commonspace_bold/_scan_info_subject_id081.session03_split_name_sub-081_ses-03_desc-o_T2w/_run_None/sub-081_ses-03_task-dist_desc-oa_bold_autobox_combined.nii.gz'
#  'R:/preprocess_batch-002/commonspace_bold/_scan_info_subject_id082.session03_split_name_sub-082_ses-03_desc-o_T2w/_run_None/sub-082_ses-03_task-dist_desc-oa_bold_autobox_combined.nii.gz'
#  'R:/preprocess_batch-002/commonspace_bold/_scan_info_subject_id095.session03_split_name_sub-095_ses-03_desc-o_T2w/_run_None/sub-095_ses-03_task-dist_desc-oa_bold_autobox_combined.nii.gz']
# sub test:
# ['R:/preprocess_batch-002/commonspace_bold/_scan_info_subject_id100.session03_split_name_sub-100_ses-03_desc-o_T2w/_run_None/sub-100_ses-03_task-dist_desc-oa_bold_autobox_combined.nii.gz'
#  'R:/preprocess_batch-001/commonspace_bold/_scan_info_subject_id052.session03_split_name_sub-052_ses-03_desc-o_T2w/_run_None/sub-052_ses-03_task-dist_desc-oa_bold_autobox_combined.nii.gz'
#  'R:/preprocess_batch-002/commonspace_bold/_scan_info_subject_id077.session03_split_name_sub-077_ses-03_desc-o_T2w/_run_None/sub-077_ses-03_task-dist_desc-oa_bold_autobox_combined.nii.gz'
#  'R:/preprocess_batch-002/commonspace_bold/_scan_info_subject_id078.session03_split_name_sub-078_ses-03_desc-o_T2w/_run_None/sub-078_ses-03_task-dist_desc-oa_bold_autobox_combined.nii.gz'
#  'R:/preprocess_batch-002/commonspace_bold/_scan_info_subject_id096.session03_split_name_sub-096_ses-03_desc-o_T2w/_run_None/sub-096_ses-03_task-dist_desc-oa_bold_autobox_combined.nii.gz']
# sub val:
# ['R:/preprocess_batch-001/commonspace_bold/_scan_info_subject_id051.session03_split_name_sub-051_ses-03_desc-o_T2w/_run_None/sub-051_ses-03_task-dist_desc-oa_bold_autobox_combined.nii.gz'
#  'R:/preprocess_batch-002/commonspace_bold/_scan_info_subject_id074.session03_split_name_sub-074_ses-03_desc-o_T2w/_run_None/sub-074_ses-03_task-dist_desc-oa_bold_autobox_combined.nii.gz']
# # sesiones Train 12
# # sesiones Test 5
# # sesiones Val 2
# Starting VGG 16 3D-----------------------------------------------------
# Training
# Starting VGG 16 3D-----------------------------------------------------
# Epoch 1/10
# W&B Graph visualization desactivada (inbound_layers incompatibles con Keras 3.x).
# 456/456 [==============================] - 1435s 3s/step - loss: 20.2789 - Accuracy: 0.5746 - val_loss: 18.0864 - val_Accuracy: 0.5000
# Epoch 2/10
# 456/456 [==============================] - 1472s 3s/step - loss: 16.1765 - Accuracy: 0.5849 - val_loss: 16.3758 - val_Accuracy: 0.5000
# Epoch 3/10
# 456/456 [==============================] - 1438s 3s/step - loss: 13.0807 - Accuracy: 0.8610 - val_loss: 13.8298 - val_Accuracy: 0.3921
# Epoch 4/10
# 456/456 [==============================] - 1459s 3s/step - loss: 10.5457 - Accuracy: 0.9931 - val_loss: 12.2890 - val_Accuracy: 0.0825
# Epoch 5/10
# 456/456 [==============================] - 1447s 3s/step - loss: 8.5281 - Accuracy: 0.9997 - val_loss: 10.5474 - val_Accuracy: 0.1886
# Epoch 6/10
# 456/456 [==============================] - 1450s 3s/step - loss: 6.9287 - Accuracy: 1.0000 - val_loss: 9.4217 - val_Accuracy: 0.1377
# Epoch 7/10
# 456/456 [==============================] - 1474s 3s/step - loss: 5.6380 - Accuracy: 1.0000 - val_loss: 8.8662 - val_Accuracy: 0.0237
# Epoch 8/10
# 456/456 [==============================] - 1452s 3s/step - loss: 4.6011 - Accuracy: 1.0000 - val_loss: 7.0158 - val_Accuracy: 0.1456
# Epoch 9/10
# 456/456 [==============================] - 1443s 3s/step - loss: 3.8108 - Accuracy: 0.9984 - val_loss: 4.4132 - val_Accuracy: 0.4982
# Epoch 10/10
# 456/456 [==============================] - 1457s 3s/step - loss: 3.1761 - Accuracy: 1.0000 - val_loss: 4.8426 - val_Accuracy: 0.3596
# Duration (CNN): 4:02:09.288897
# predicts CNN
# 190/190 [==============================] - 95s 503ms/step
# mislabeled subjects:
# ...
#  View project at <a href='https://wandb.ai/mansoor35/Male%20vs%20Female%28GradCam%29%20coverage' target="_blank">https://wandb.ai/mansoor35/Male%20vs%20Female%28GradCam%29%20coverage</a>
#  View run at <a href='https://wandb.ai/mansoor35/Male%20vs%20Female%28GradCam%29%20coverage/runs/f79cj0va' target="_blank">https://wandb.ai/mansoor35/Male%20vs%20Female%28GradCam%29%20coverage/runs/f79cj0va</a>
# holaaaa, se metio al mask and bold
# SE METIO AL DISTTTTTTTTTT
# SE METIO AL LOGIN
# sesions:  [3]
# SESION:  3
# ENTRO AL SEGUNDO SUB BATCH
# Se metió al 68
# j:  60
# ENTRO AL SEGUNDO SUB BATCH
# Se metió al 68
# j:  66
# ENTRO AL SEGUNDO SUB BATCH
# ENTRO AL SEGUNDO SUB BATCH
# Se metió al 68
# j:  65
# Se metió al 68
# j:  57
# ENTRO AL SEGUNDO SUB BATCH
# Se metió al 68
# j:  50
# Se metió al 68
# j:  49
# ENTRO AL SEGUNDO SUB BATCH
# AHHHHHHHHHHHHHHHHHH [['R:/preprocess_batch-002/commonspace_bold/_scan_info_subject_id080.session03_split_name_sub-080_ses-03_desc-o_T2w/_run_None/sub-080_ses-03_task-dist_desc-oa_bold_autobox_combined.nii.gz', 'R:/preprocess_batch-002_rest/bold_datasink/commonspace_mask/_scan_info_subject_id080.session03_split_name_sub-080_ses-03_desc-o_T2w/_run_None/sub-080_ses-03_task-rest_desc-oa_bold_autobox_EPI_brain_mask.nii.gz'], ['R:/preprocess_batch-001/commonspace_bold/_scan_info_subject_id060.session03_split_name_sub-060_ses-03_desc-o_T2w/_run_None/sub-060_ses-03_task-dist_desc-oa_bold_autobox_combined.nii.gz', 'R:/preprocess_batch-001_rest/bold_datasink/commonspace_mask/_scan_info_subject_id060.session03_split_name_sub-060_ses-03_desc-o_T2w/_run_None/sub-060_ses-03_task-rest_desc-oa_bold_autobox_EPI_brain_mask.nii.gz'], ['R:/preprocess_batch-002/commonspace_bold/_scan_info_subject_id093.session03_split_name_sub-093_ses-03_desc-o_T2w/_run_None/sub-093_ses-03_task-dist_desc-oa_bold_autobox_combined.nii.gz', 'R:/preprocess_batch-002_rest/bold_datasink/commonspace_mask/_scan_info_subject_id093.session03_split_name_sub-093_ses-03_desc-o_T2w/_run_None/sub-093_ses-03_task-rest_desc-oa_bold_autobox_EPI_brain_mask.nii.gz'], ['R:/preprocess_batch-001/commonspace_bold/_scan_info_subject_id066.session03_split_name_sub-066_ses-03_desc-o_T2w/_run_None/sub-066_ses-03_task-dist_desc-oa_bold_autobox_combined.nii.gz', 'R:/preprocess_batch-001_rest/bold_datasink/commonspace_mask/_scan_info_subject_id066.session03_split_name_sub-066_ses-03_desc-o_T2w/_run_None/sub-066_ses-03_task-rest_desc-oa_bold_autobox_EPI_brain_mask.nii.gz'], ['R:/preprocess_batch-002/commonspace_bold/_scan_info_subject_id074.session03_split_name_sub-074_ses-03_desc-o_T2w/_run_None/sub-074_ses-03_task-dist_desc-oa_bold_autobox_combined.nii.gz', 'R:/preprocess_batch-002_rest/bold_datasink/commonspace_mask/_scan_info_subject_id074.session03_split_name_sub-074_ses-03_desc-o_T2w/_run_None/sub-074_ses-03_task-rest_desc-oa_bold_autobox_EPI_brain_mask.nii.gz'], ['R:/preprocess_batch-002/commonspace_bold/_scan_info_subject_id099.session03_split_name_sub-099_ses-03_desc-o_T2w/_run_None/sub-099_ses-03_task-dist_desc-oa_bold_autobox_combined.nii.gz', 'R:/preprocess_batch-002_rest/bold_datasink/commonspace_mask/_scan_info_subject_id099.session03_split_name_sub-099_ses-03_desc-o_T2w/_run_None/sub-099_ses-03_task-rest_desc-oa_bold_autobox_EPI_brain_mask.nii.gz'], ['R:/preprocess_batch-001/commonspace_bold/_scan_info_subject_id065.session03_split_name_sub-065_ses-03_desc-o_T2w/_run_None/sub-065_ses-03_task-dist_desc-oa_bold_autobox_combined.nii.gz', 'R:/preprocess_batch-001_rest/bold_datasink/commonspace_mask/_scan_info_subject_id065.session03_split_name_sub-065_ses-03_desc-o_T2w/_run_None/sub-065_ses-03_task-rest_desc-oa_bold_autobox_EPI_brain_mask.nii.gz'], ['R:/preprocess_batch-001/commonspace_bold/_scan_info_subject_id057.session03_split_name_sub-057_ses-03_desc-o_T2w/_run_None/sub-057_ses-03_task-dist_desc-oa_bold_autobox_combined.nii.gz', 'R:/preprocess_batch-001_rest/bold_datasink/commonspace_mask/_scan_info_subject_id057.session03_split_name_sub-057_ses-03_desc-o_T2w/_run_None/sub-057_ses-03_task-rest_desc-oa_bold_autobox_EPI_brain_mask.nii.gz'], ['R:/preprocess_batch-002/commonspace_bold/_scan_info_subject_id095.session03_split_name_sub-095_ses-03_desc-o_T2w/_run_None/sub-095_ses-03_task-dist_desc-oa_bold_autobox_combined.nii.gz', 'R:/preprocess_batch-002_rest/bold_datasink/commonspace_mask/_scan_info_subject_id095.session03_split_name_sub-095_ses-03_desc-o_T2w/_run_None/sub-095_ses-03_task-rest_desc-oa_bold_autobox_EPI_brain_mask.nii.gz'], ['R:/preprocess_batch-001/commonspace_bold/_scan_info_subject_id050.session03_split_name_sub-050_ses-03_desc-o_T2w/_run_None/sub-050_ses-03_task-dist_desc-oa_bold_autobox_combined.nii.gz', 'R:/preprocess_batch-001_rest/bold_datasink/commonspace_mask/_scan_info_subject_id050.session03_split_name_sub-050_ses-03_desc-o_T2w/_run_None/sub-050_ses-03_task- ...
# X_train con exito
# holaaaa, se metio al mask and bold
# SE METIO AL DISTTTTTTTTTT
# SE METIO AL LOGIN
# sesions:  [3]
# SESION:  3
# ENTRO AL SEGUNDO SUB BATCH
# Se metió al 68
# j:  52
# ENTRO AL SEGUNDO SUB BATCH
# ENTRO AL SEGUNDO SUB BATCH
# ENTRO AL SEGUNDO SUB BATCH
# AHHHHHHHHHHHHHHHHHH [['R:/preprocess_batch-002/commonspace_bold/_scan_info_subject_id100.session03_split_name_sub-100_ses-03_desc-o_T2w/_run_None/sub-100_ses-03_task-dist_desc-oa_bold_autobox_combined.nii.gz', 'R:/preprocess_batch-002_rest/bold_datasink/commonspace_mask/_scan_info_subject_id100.session03_split_name_sub-100_ses-03_desc-o_T2w/_run_None/sub-100_ses-03_task-rest_desc-oa_bold_autobox_EPI_brain_mask.nii.gz'], ['R:/preprocess_batch-001/commonspace_bold/_scan_info_subject_id052.session03_split_name_sub-052_ses-03_desc-o_T2w/_run_None/sub-052_ses-03_task-dist_desc-oa_bold_autobox_combined.nii.gz', 'R:/preprocess_batch-001_rest/bold_datasink/commonspace_mask/_scan_info_subject_id052.session03_split_name_sub-052_ses-03_desc-o_T2w/_run_None/sub-052_ses-03_task-rest_desc-oa_bold_autobox_EPI_brain_mask.nii.gz'], ['R:/preprocess_batch-002/commonspace_bold/_scan_info_subject_id077.session03_split_name_sub-077_ses-03_desc-o_T2w/_run_None/sub-077_ses-03_task-dist_desc-oa_bold_autobox_combined.nii.gz', 'R:/preprocess_batch-002_rest/bold_datasink/commonspace_mask/_scan_info_subject_id077.session03_split_name_sub-077_ses-03_desc-o_T2w/_run_None/sub-077_ses-03_task-rest_desc-oa_bold_autobox_EPI_brain_mask.nii.gz'], ['R:/preprocess_batch-002/commonspace_bold/_scan_info_subject_id078.session03_split_name_sub-078_ses-03_desc-o_T2w/_run_None/sub-078_ses-03_task-dist_desc-oa_bold_autobox_combined.nii.gz', 'R:/preprocess_batch-002_rest/bold_datasink/commonspace_mask/_scan_info_subject_id078.session03_split_name_sub-078_ses-03_desc-o_T2w/_run_None/sub-078_ses-03_task-rest_desc-oa_bold_autobox_EPI_brain_mask.nii.gz'], ['R:/preprocess_batch-002/commonspace_bold/_scan_info_subject_id096.session03_split_name_sub-096_ses-03_desc-o_T2w/_run_None/sub-096_ses-03_task-dist_desc-oa_bold_autobox_combined.nii.gz', 'R:/preprocess_batch-002_rest/bold_datasink/commonspace_mask/_scan_info_subject_id096.session03_split_name_sub-096_ses-03_desc-o_T2w/_run_None/sub-096_ses-03_task-rest_desc-oa_bold_autobox_EPI_brain_mask.nii.gz']]
# X_test con exito
# holaaaa, se metio al mask and bold
# SE METIO AL DISTTTTTTTTTT
# SE METIO AL LOGIN
# sesions:  [3]
# SESION:  3
# ENTRO AL SEGUNDO SUB BATCH
# ENTRO AL SEGUNDO SUB BATCH
# AHHHHHHHHHHHHHHHHHH [['R:/preprocess_batch-002/commonspace_bold/_scan_info_subject_id079.session03_split_name_sub-079_ses-03_desc-o_T2w/_run_None/sub-079_ses-03_task-dist_desc-oa_bold_autobox_combined.nii.gz', 'R:/preprocess_batch-002_rest/bold_datasink/commonspace_mask/_scan_info_subject_id079.session03_split_name_sub-079_ses-03_desc-o_T2w/_run_None/sub-079_ses-03_task-rest_desc-oa_bold_autobox_EPI_brain_mask.nii.gz'], ['R:/preprocess_batch-002/commonspace_bold/_scan_info_subject_id094.session03_split_name_sub-094_ses-03_desc-o_T2w/_run_None/sub-094_ses-03_task-dist_desc-oa_bold_autobox_combined.nii.gz', 'R:/preprocess_batch-002_rest/bold_datasink/commonspace_mask/_scan_info_subject_id094.session03_split_name_sub-094_ses-03_desc-o_T2w/_run_None/sub-094_ses-03_task-rest_desc-oa_bold_autobox_EPI_brain_mask.nii.gz']]
# X_val con exito
# sub train:
# ['R:/preprocess_batch-002/commonspace_bold/_scan_info_subject_id080.session03_split_name_sub-080_ses-03_desc-o_T2w/_run_None/sub-080_ses-03_task-dist_desc-oa_bold_autobox_combined.nii.gz'
#  'R:/preprocess_batch-001/commonspace_bold/_scan_info_subject_id060.session03_split_name_sub-060_ses-03_desc-o_T2w/_run_None/sub-060_ses-03_task-dist_desc-oa_bold_autobox_combined.nii.gz'
#  'R:/preprocess_batch-002/commonspace_bold/_scan_info_subject_id093.session03_split_name_sub-093_ses-03_desc-o_T2w/_run_None/sub-093_ses-03_task-dist_desc-oa_bold_autobox_combined.nii.gz'
#  'R:/preprocess_batch-001/commonspace_bold/_scan_info_subject_id066.session03_split_name_sub-066_ses-03_desc-o_T2w/_run_None/sub-066_ses-03_task-dist_desc-oa_bold_autobox_combined.nii.gz'
#  'R:/preprocess_batch-002/commonspace_bold/_scan_info_subject_id074.session03_split_name_sub-074_ses-03_desc-o_T2w/_run_None/sub-074_ses-03_task-dist_desc-oa_bold_autobox_combined.nii.gz'
#  'R:/preprocess_batch-002/commonspace_bold/_scan_info_subject_id099.session03_split_name_sub-099_ses-03_desc-o_T2w/_run_None/sub-099_ses-03_task-dist_desc-oa_bold_autobox_combined.nii.gz'
#  'R:/preprocess_batch-001/commonspace_bold/_scan_info_subject_id065.session03_split_name_sub-065_ses-03_desc-o_T2w/_run_None/sub-065_ses-03_task-dist_desc-oa_bold_autobox_combined.nii.gz'
#  'R:/preprocess_batch-001/commonspace_bold/_scan_info_subject_id057.session03_split_name_sub-057_ses-03_desc-o_T2w/_run_None/sub-057_ses-03_task-dist_desc-oa_bold_autobox_combined.nii.gz'
#  'R:/preprocess_batch-002/commonspace_bold/_scan_info_subject_id095.session03_split_name_sub-095_ses-03_desc-o_T2w/_run_None/sub-095_ses-03_task-dist_desc-oa_bold_autobox_combined.nii.gz'
#  'R:/preprocess_batch-001/commonspace_bold/_scan_info_subject_id050.session03_split_name_sub-050_ses-03_desc-o_T2w/_run_None/sub-050_ses-03_task-dist_desc-oa_bold_autobox_combined.nii.gz'
#  'R:/preprocess_batch-001/commonspace_bold/_scan_info_subject_id049.session03_split_name_sub-049_ses-03_desc-o_T2w/_run_None/sub-049_ses-03_task-dist_desc-oa_bold_autobox_combined.nii.gz'
#  'R:/preprocess_batch-002/commonspace_bold/_scan_info_subject_id073.session03_split_name_sub-073_ses-03_desc-o_T2w/_run_None/sub-073_ses-03_task-dist_desc-oa_bold_autobox_combined.nii.gz']
# sub test:
# ['R:/preprocess_batch-002/commonspace_bold/_scan_info_subject_id100.session03_split_name_sub-100_ses-03_desc-o_T2w/_run_None/sub-100_ses-03_task-dist_desc-oa_bold_autobox_combined.nii.gz'
#  'R:/preprocess_batch-001/commonspace_bold/_scan_info_subject_id052.session03_split_name_sub-052_ses-03_desc-o_T2w/_run_None/sub-052_ses-03_task-dist_desc-oa_bold_autobox_combined.nii.gz'
#  'R:/preprocess_batch-002/commonspace_bold/_scan_info_subject_id077.session03_split_name_sub-077_ses-03_desc-o_T2w/_run_None/sub-077_ses-03_task-dist_desc-oa_bold_autobox_combined.nii.gz'
#  'R:/preprocess_batch-002/commonspace_bold/_scan_info_subject_id078.session03_split_name_sub-078_ses-03_desc-o_T2w/_run_None/sub-078_ses-03_task-dist_desc-oa_bold_autobox_combined.nii.gz'
#  'R:/preprocess_batch-002/commonspace_bold/_scan_info_subject_id096.session03_split_name_sub-096_ses-03_desc-o_T2w/_run_None/sub-096_ses-03_task-dist_desc-oa_bold_autobox_combined.nii.gz']
# sub val:
# ['R:/preprocess_batch-002/commonspace_bold/_scan_info_subject_id079.session03_split_name_sub-079_ses-03_desc-o_T2w/_run_None/sub-079_ses-03_task-dist_desc-oa_bold_autobox_combined.nii.gz'
#  'R:/preprocess_batch-002/commonspace_bold/_scan_info_subject_id094.session03_split_name_sub-094_ses-03_desc-o_T2w/_run_None/sub-094_ses-03_task-dist_desc-oa_bold_autobox_combined.nii.gz']
# # sesiones Train 12
# # sesiones Test 5
# # sesiones Val 2
# Starting VGG 16 3D-----------------------------------------------------
# Training
# Starting VGG 16 3D-----------------------------------------------------
# Epoch 1/10
# W&B Graph visualization desactivada (inbound_layers incompatibles con Keras 3.x).
# 456/456 [==============================] - 1445s 3s/step - loss: 20.3207 - Accuracy: 0.6629 - val_loss: 18.6579 - val_Accuracy: 0.4947
# Epoch 2/10
# 456/456 [==============================] - 1446s 3s/step - loss: 16.1490 - Accuracy: 0.9175 - val_loss: 17.4486 - val_Accuracy: 0.0333
# Epoch 3/10
# 456/456 [==============================] - 1434s 3s/step - loss: 13.0099 - Accuracy: 0.9902 - val_loss: 13.5775 - val_Accuracy: 0.0237
# Epoch 4/10
# 456/456 [==============================] - 1450s 3s/step - loss: 10.5687 - Accuracy: 0.9985 - val_loss: 12.4046 - val_Accuracy: 0.0061
# Epoch 5/10
# 456/456 [==============================] - 1421s 3s/step - loss: 8.5708 - Accuracy: 0.9990 - val_loss: 9.7368 - val_Accuracy: 0.0316
# Epoch 6/10
# 456/456 [==============================] - 1431s 3s/step - loss: 6.9415 - Accuracy: 0.9991 - val_loss: 8.4277 - val_Accuracy: 0.0088
# Epoch 7/10
# 456/456 [==============================] - 1427s 3s/step - loss: 5.6298 - Accuracy: 0.9996 - val_loss: 7.5456 - val_Accuracy: 0.0044
# Epoch 8/10
# 456/456 [==============================] - 1452s 3s/step - loss: 4.5815 - Accuracy: 0.9993 - val_loss: 5.5379 - val_Accuracy: 0.1026
# Epoch 9/10
# 456/456 [==============================] - 1444s 3s/step - loss: 3.7561 - Accuracy: 0.9999 - val_loss: 5.0833 - val_Accuracy: 0.0509
# Epoch 10/10
# 456/456 [==============================] - 1461s 3s/step - loss: 3.1151 - Accuracy: 0.9996 - val_loss: 4.5582 - val_Accuracy: 0.0193
# Duration (CNN): 4:00:14.676678
# predicts CNN
# 190/190 [==============================] - 95s 501ms/step
# mislabeled subjects:
#  Counter()
# evaluating CNN
# 190/190 [==============================] - 98s 513ms/step - loss: 2.8846 - Accuracy: 1.0000
# Coverage male: 0.5241922520495097
# Coverage female: 0.4546964582328672
# CM CNN
# histories and scores from VGG 16 M2D
# Accuracy: mean=77.193 std=14.515, n=4
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>Accuracy</td><td>▁▆████████</td></tr><tr><td>epoch</td><td>▁▂▃▃▄▅▆▆▇█</td></tr><tr><td>loss</td><td>█▆▅▄▃▃▂▂▁▁</td></tr><tr><td>test_acc</td><td>▁</td></tr><tr><td>val_Accuracy</td><td>█▁▁▁▁▁▁▂▂▁</td></tr><tr><td>val_loss</td><td>█▇▅▅▄▃▂▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>Accuracy</td><td>0.99956</td></tr><tr><td>best_epoch</td><td>9</td></tr><tr><td>best_val_loss</td><td>4.55824</td></tr><tr><td>epoch</td><td>9</td></tr><tr><td>loss</td><td>3.11513</td></tr><tr><td>test_acc</td><td>1</td></tr><tr><td>time_running</td><td>4:00:14.676678</td></tr><tr><td>val_Accuracy</td><td>0.0193</td></tr><tr><td>val_loss</td><td>4.55824</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">upbeat-forest-22</strong> at: <a href='https://wandb.ai/mansoor35/Male%20vs%20Female%28GradCam%29%20coverage/runs/f79cj0va' target="_blank">https://wandb.ai/mansoor35/Male%20vs%20Female%28GradCam%29%20coverage/runs/f79cj0va</a><br> View project at: <a href='https://wandb.ai/mansoor35/Male%20vs%20Female%28GradCam%29%20coverage' target="_blank">https://wandb.ai/mansoor35/Male%20vs%20Female%28GradCam%29%20coverage</a><br>Synced 5 W&B file(s), 1 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>C:\Users\L03117~1\AppData\Local\Temp\wandb\run-20251202_230006-f79cj0va\logs</code>

# %%
resized_heatmap_male = (resized_heatmap_male - resized_heatmap_male.min()) / (resized_heatmap_male.max() - resized_heatmap_male.min() + 1e-8)

heatmap_norm_male = resized_heatmap_male.astype(np.float32)
thr_male = np.percentile(heatmap_norm_male, 90)
salient_male = heatmap_norm_male >= thr_male

activation_voxels_male = salient_male.sum()
voxels_inside_male = np.logical_and(salient_male, mask).sum()
coverage_male = voxels_inside_male / activation_voxels_male
print("Coverage male:", coverage_male)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[17], line 8
#       5 salient_male = heatmap_norm_male >= thr_male
#       7 activation_voxels_male = salient_male.sum()
# ----> 8 voxels_inside_male = np.logical_and(salient_male, mask).sum()
#       9 coverage_male = voxels_inside_male / activation_voxels_male
#      10 print("Coverage male:", coverage_male)
#
# ValueError: operands could not be broadcast together with shapes (42,65,29) (48,81,48)

# %%
# 80% train y val y 20% test
sub_trainval, sub_test, y_trainval, y_test = train_test_split(
    subjects, labels, test_size=0.2, random_state=42, stratify=labels
)

n_bootstraps= 1
for boot in range(n_bootstraps): 
    print(f"\n=== Bootstrapping Run {boot+1}/{n_bootstraps} ===")

    boot_subjects, boot_labels = resample(
        sub_trainval, y_trainval, replace=True, random_state=42+boot
    )

    kfold = StratifiedKFold(n_splits=4, shuffle=True, random_state=1)

    scores, histories = list(), list()
    run = 1
    for train_ix, val_ix in kfold.split(boot_subjects, boot_labels):

        sub_train, sub_val = boot_subjects[train_ix], boot_subjects[val_ix]
        y_train, y_val     = boot_labels[train_ix], boot_labels[val_ix]

        sub_test, y_test = sub_test, y_test

        print("Run #",run)

        # Set default values
        config_defaults = {
            "batch": 1,
        }
        # Initialize wandb with a sample project name
        wandb.init(project="Male vs Female(grad++) coverage", notes="FOLD "+str(run)+".  Evaluacion de male vs female con GradCam ++. lr = 1e-6",dir="C:/Users/103087364/wandb_runs"
                   ,config=config_defaults)

        # Specify the other hyperparameters to the configuration.
        wandb.config.epochs = 2
        wandb.config.sub_batch = 15
        wandb.config.sub_batch_ts = 15
        wandb.config.subjects = subjects
        wandb.config.architecture_name = "VGG16_3D"
        wandb.config.dataset_name = "Male vs Female, plus GradCam++ coverage"
        wandb.config.CNN_blocks = 5
        wandb.config.sessions = sessions
        wandb.config.vols_per_session_tr = 570#570
        wandb.config.vols_per_session_ts = 570#570
        wandb.config.initial_learning_rate = 1e-5
        #wandb.config.lr_decay_rate = 0.95
        wandb.config.optimizer = "Adam"
        
        
        val_size = max(2, int(round(0.1 * len(train_ix))))
    
        sub_train, sub_val, y_train, y_val = train_test_split(
            sub_trainval[train_ix], y_trainval[train_ix],
            test_size=val_size,  # test_size se refiere a la validacion
            random_state=42, stratify=y_trainval[train_ix]
        )
        
        CPHclassTrain = FILES_and_LABELS(sub_train, sessions, MRI_type, functional_type)
        CPHclassTest = FILES_and_LABELS(sub_test, sessions, MRI_type, functional_type)
        CPHclassval = FILES_and_LABELS(sub_val, sessions, MRI_type, functional_type)
            
        X_train = CPHclassTrain.get_mask_and_bold()
      
        print("X_train con exito")
        X_test = CPHclassTest.get_mask_and_bold()
        print("X_test con exito")
        X_val = CPHclassval.get_mask_and_bold()
        print("X_val con exito")

        print("sub train:")
        print(np.array(X_train)[:,0])
        print("sub test:")
        print(np.array(X_test)[:,0])
        print("sub val:")
        print(np.array(X_val)[:,0])

        print("# sesiones Train",len(X_train))
        print("# sesiones Test",len(X_test))
        print("# sesiones Val",len(X_val))
        
        traingen = CustomDataGen(X_train, batch_size=wandb.config.batch, subbatch_size=wandb.config.sub_batch,
                                format = "just_brain", vols = wandb.config.vols_per_session_tr,
                                num_class = 2, classes = "sex", augmentation = True, functional_type = "rest")
        traingen.on_epoch_end()
        #Es necesario que la division entre X_test y batch_size tenga un modulo igual a 0. 
        #De otra manera el ultimo batch no lo utiliza al utilizar .predict
        testgen  = CustomDataGen(X_test, batch_size=1,subbatch_size=wandb.config.sub_batch_ts,
                                format = "just_brain", vols= wandb.config.vols_per_session_ts,
                                num_class = 2, classes = "sex",shuffle=False, functional_type = "rest")
        valgen  = CustomDataGen(X_val, batch_size=len(X_val),subbatch_size=15, format = "just_brain",vols=570, augmentation = True, num_class = 2,
                                classes = "sex", functional_type = "rest")
        
        #getting model 3D CNN
        #callback = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=4, min_delta=0.0001)
        print("Starting VGG 16 3D-----------------------------------------------------")
        tf.keras.backend.clear_session()
        gc.collect()

        #transfer learning
        layers = [l for l in CNN.layers]
            
        for i in range(len(baseModel.layers)):
            layers[i].set_weights(baseModel.layers[i].get_weights())
            
        """
        lr_schedule = ExponentialDecay(wandb.config.initial_learning_rate,
                                    decay_steps=int((wandb.config.vols_per_session_tr/wandb.config.sub_batch)*len(X_train)),
                                    decay_rate=wandb.config.lr_decay_rate, staircase=True)
        """
        CNN.compile(loss="categorical_crossentropy", optimizer=tf.keras.optimizers.Adam(learning_rate=wandb.config.initial_learning_rate),
                        metrics=["Accuracy"])

        #checkpoint_filepath =os.getcwd()+"/"+wandb.run.name
        checkpoint_filepath = os.path.join("W:/", f"{wandb.run.name}.h5")
        #'/tmp/ckpt/MalevsFemale(CPH)_3D-VGG16_flips/'+wandb.run.name
        
        model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(filepath=checkpoint_filepath, monitor='val_loss', mode='min',
                                                                save_best_only=True)
        
        start_time = datetime.now()
        
        print("Training")

        print("Starting VGG 16 3D-----------------------------------------------------")
    # --- DEBUG: inspección del generador ---
        history = CNN.fit(traingen, epochs=wandb.config.epochs, validation_data = valgen, shuffle=True, callbacks=[SafeWandbCallback(monitor='val_loss',mode="min",save_model=False),model_checkpoint_callback])         
        end_time = datetime.now()
        print('Duration (CNN): {}'.format(end_time - start_time))

        y_test=[]
        x_vols = []
        for i in range(int(len(X_test)*(wandb.config.vols_per_session_ts/wandb.config.sub_batch_ts))):
            x,y = testgen[i]
            y_test.extend(y)
            x_vols.extend(x)
        y_test = np.argmax(y_test, axis=1)
        print("predicts CNN")
        preds = tf.cast(tf.argmax(CNN.predict(testgen), axis=1), tf.int32)
        #Wrong predicted subjects
        wrong_labeled_subj = mislabeled_subj(y_test, preds, X_test, wandb.config.vols_per_session_ts)

        print("mislabeled subjects:\n",wrong_labeled_subj)
        
        print("evaluating CNN")
        _,acc = CNN.evaluate(testgen, verbose=1)
        
        scores.append(acc)
        histories.append(history)

        #HiresCam
        last_conv_layer_name = 'conv3d_25'
        hirescam = HiResCAM(model=CNN, last_conv_layer_name=last_conv_layer_name)
        index_male = index_for_gradcam(0, y_test, preds)
        index_female = index_for_gradcam(1, y_test, preds)

        if index_female is not None:
            x_female = np.expand_dims(x_vols[index_female], axis=0)
            heatmap_female = hirescam.get_cam(x_female, pred_index=1)
            while heatmap_female.ndim < data_grad_completo.ndim:
                heatmap_female = np.expand_dims(heatmap_female, axis=-1)
            if heatmap_female.ndim > data_grad_completo.ndim:
                heatmap_female = np.squeeze(heatmap_female)
            if heatmap_female.shape != data_grad_completo.shape:
                factor_f = np.array(data_grad_completo.shape) / np.array(heatmap_female.shape)
                heatmap_female = zoom(heatmap_female, factor_f, order=1)
            heatmap_female = (heatmap_female - heatmap_female.min()) / (heatmap_female.max() - heatmap_female.min() + 1e-8)
            for i in range(heatmap_female.shape[1]):
                plt.imshow(np.rot90(data_grad_completo[:, i, :]), cmap='gray')
                thr = np.percentile(heatmap_female, 90)
                plt.imshow(np.rot90(np.where(heatmap_female[:, i, :] > thr, heatmap_female[:, i, :], np.nan)), cmap='Reds', alpha=1.0)
                plt.axis('off')
                plt.tight_layout()
                plt.show()

            crop_slice = (slice(3,45), slice(4,69), slice(7,36))
            crop_shape = (45-3, 69-4, 36-7)

            original_hmap_female = heatmap_female

            original_shape_female = original_hmap_female.shape
            factor = np.array(crop_shape) / np.array(original_shape_female)

            heatmap_female_original_resized_for_save = zoom(original_hmap_female, factor, order=1)

            full_grad_female = np.zeros((48,81,48))
            full_grad_female[crop_slice] = heatmap_female_original_resized_for_save

            save_dir_female = f"W:/{wandb.run.name}/female"
            os.makedirs(save_dir_female, exist_ok=True)

            np.save(f"{save_dir_female}/Array_GradCamplusplus-F.npy", full_grad_female)
    

        if index_male is not None:
            x_male = np.expand_dims(x_vols[index_male], axis=0)
            heatmap_male = hirescam.get_cam(x_male, pred_index=0)
            while heatmap_male.ndim < data_grad_completo.ndim:
                heatmap_male = np.expand_dims(heatmap_male, axis=-1)
            if heatmap_male.ndim > data_grad_completo.ndim:
                heatmap_male = np.squeeze(heatmap_male)
            if heatmap_male.shape != data_grad_completo.shape:
                factor_m = np.array(data_grad_completo.shape) / np.array(heatmap_male.shape)
                heatmap_male = zoom(heatmap_male, factor_m, order=1)
            heatmap_male = (heatmap_male - heatmap_male.min()) / (heatmap_male.max() - heatmap_male.min() + 1e-8)
            for i in range(heatmap_male.shape[1]):
                plt.imshow(np.rot90(data_grad_completo[:, i, :]), cmap='gray')
                thr = np.percentile(heatmap_male, 90)
                plt.imshow(np.rot90(np.where(heatmap_male[:, i, :] > thr, heatmap_male[:, i, :], np.nan)), cmap='Reds', alpha=1.0)
                plt.axis('off')
                plt.tight_layout()
                plt.show()
        
            crop_slice = (slice(3,45), slice(4,69), slice(7,36))
            crop_shape = (45-3, 69-4, 36-7)

            original_hmap = heatmap_male 
            original_shape = original_hmap.shape

            factor = np.array(crop_shape) / np.array(original_shape)
            heatmap_male_original_resized_for_save = zoom(original_hmap, factor, order=1)

            full_grad_male = np.zeros((48,81,48))
            full_grad_male[crop_slice] = heatmap_male_original_resized_for_save

            save_dir = f"W:/{wandb.run.name}/male"
            os.makedirs(save_dir, exist_ok=True)

            np.save(f"{save_dir}/Array_GradCamplusplus-M.npy", full_grad_male)

        print("CM CNN")
        cm = confusionmatrix(y_test, preds)
            
        wandb.log({'test_acc': float(acc),
                'time_running': '{}'.format(end_time - start_time),
                'confution_matrix': wandb.Image(cm),
                'mislabeled_subj':wrong_labeled_subj})
        run = run + 1
        
    print("histories and scores from VGG 16 M2D") 
    summarize_diagnostics(histories)
    summarize_performance(scores)

    wandb.finish()

# %%
crop_slice = (slice(3,45), slice(4,69), slice(7,36))
crop_shape = (45-3, 69-4, 36-7)  # (42,65,29)
original_hmap = heatmap_male[0]            
original_shape = original_hmap.shape       
factor = np.array(crop_shape) / np.array(original_shape)
resized_heatmap_male = zoom(original_hmap, factor, order=1)
full_grad_male = np.zeros((48,81,48))
full_grad_male[crop_slice] = resized_heatmap_male
save_dir = f"W:/{wandb.run.name}/male"
os.makedirs(save_dir, exist_ok=True)

np.save(f"{save_dir}/Array_GradCamplusplus-M.npy", full_grad_male)

print("Guardado exitoso. Shape final:", full_grad_male.shape)

# %%
#mask_nii = nib.load("R:/rabies/preprocess_batch-001_rest/bold_datasink/commonspace_mask/_scan_info_subject_id057.session01_split_name_sub-057_ses-01_desc-o_T2w/_run_None/sub-057_ses-01_task-rest_desc-oa_bold_autobox_EPI_brain_mask.nii.gz")
mask_nii =  nib.load("C:/Users/l03087364/Downloads/Kerensa Sierra_EI/sigma_files/sigma_files/SIGMA_resam_syn_waxholm_atlas.nii")
mask = mask_nii.get_fdata()
mask = mask > 0
print("Mask shape:", mask.shape)
heatmap = np.load("C:/Users/l03087364/Downloads/Kerensa Sierra_EI/etheral_pyramid-579.npy")
heatmap_norm = heatmap.astype(np.float32) / 255.0 #Considerando que abarcaba hasta el 255
thr = np.percentile(heatmap_norm, 90) #Determines the value in which 10% of the voxels are the most higher
salient = heatmap_norm >= thr #Binary maps that mark the highest activations
#Determination of the convergence in the brain area
activation_voxels = salient.sum() #How many voxels are active
voxels_inside = np.logical_and(salient, mask).sum() #How many voxels inside are activated, sum() counts how many results are positive
coverage = voxels_inside / activation_voxels #Metric that establishes, the ratio of the voxels within the area of the brain
print("Coverage:", coverage)
for i in range(heatmap.shape[1]):
    plt.imshow(np.rot90(data_grad_completo[:, i, :]), cmap='gray')
    plt.imshow(np.rot90(np.where(heatmap[:, i, :] > np.percentile(heatmap, 90),heatmap[:, i, :], np.nan)),cmap='Reds',alpha=1.0)
    plt.axis('off')
    plt.tight_layout()
    plt.show()
