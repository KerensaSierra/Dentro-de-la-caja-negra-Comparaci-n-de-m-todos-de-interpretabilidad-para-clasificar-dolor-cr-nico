# %%
import os
import sys
sys.path.append("C:/Users/PC-EIAD209/Desktop/AnaKei/NIPD-AI")
#sys.path.append("C:\\Users\\"+os.getlogin()+"\\OneDrive - Instituto Tecnologico y de Estudios Superiores de Monterrey\\PainClassifier")
from my_data_generator1 import *

# %%
import matplotlib as mpl
os.environ["PATH"] += os.pathsep + r"C:\ffmpeg\ffmpeg-8.0-essentials_build\bin"
mpl.rcParams["animation.ffmpeg_path"] = r"C:\ffmpeg\ffmpeg-8.0-essentials_build\bin\ffmpeg.exe"

# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.io as sio
import os
from tensorflow.keras.utils import plot_model
from sklearn.model_selection import train_test_split
import h5py
import warnings
from sklearn.metrics import roc_auc_score, roc_curve
from sklearn.metrics import precision_recall_fscore_support as score, precision_score, recall_score, f1_score
from sklearn.metrics import confusion_matrix
from datetime import datetime
import scipy as sp
from sklearn.preprocessing import LabelBinarizer
from sklearn.metrics import auc, roc_curve
from itertools import cycle
from sklearn.metrics import RocCurveDisplay
from sklearn.utils import resample
import tensorflow as tf
from tensorflow.keras.layers import Input, Dense, Reshape, Conv3D, MaxPooling3D, Flatten, Dropout, GlobalAveragePooling3D, concatenate, BatchNormalization
from tensorflow.keras.models import Model
from tensorflow.keras.utils import to_categorical
from sklearn.model_selection import StratifiedKFold
import seaborn as sns
import imageio_ffmpeg
from tensorflow.keras.applications.vgg16 import VGG16


#from keras.regularizers import l2
import cv2
#from keras import initializers
#from keras.layers import LeakyReLU
#from keras.layers import BatchNormalization
import tensorflow as tf
#from keras import losses
import matplotlib as mpl
import imageio_ffmpeg
#nuevo
from tensorflow.keras.regularizers import l2
from tensorflow.keras import initializers, losses
from tensorflow.keras.layers import LeakyReLU, BatchNormalization


from tensorflow.keras.optimizers import SGD
import wandb
from wandb.integration.keras import WandbCallback
import gc
#from numba import cuda   nota: no se usa
from tensorflow.keras.optimizers.schedules import ExponentialDecay


from tf_keras_vis.utils.model_modifiers import ReplaceToLinear
from tf_keras_vis.utils.scores import CategoricalScore
from tf_keras_vis.gradcam_plus_plus import GradcamPlusPlus

# %%
import wandb
from wandb.integration.keras import keras

old_from_keras = getattr(wandb.Graph, "from_keras", None)

def safe_from_keras(model, *args, **kwargs):
    print("W&B Graph visualization desactivada (inbound_layers incompatibles con Keras 3.x).")
    return None  # evita que se intente generar el grafo

if old_from_keras is not None:
    wandb.Graph.from_keras = safe_from_keras

# %%
import wandb
from wandb.integration.keras import WandbCallback
import keras

wandb.keras = None  # Desactiva funciones viejas de grafo

class SafeWandbCallback(WandbCallback):
    """Versión segura de WandbCallback compatible con Keras moderno."""
    def __init__(self, *args, **kwargs):
        super().__init__(*args, **kwargs)
        self._model = None  # ← previene el AttributeError

    def set_model(self, model):
        try:
            self._model = model  # almacena referencia sin conflicto
            super().set_model(model)
        except Exception as e:
            print(f"Se omitió un error interno de W&B-Keras: {e}")

# %%
physical_devices = tf.config.list_physical_devices('GPU')
try:
  tf.config.experimental.set_memory_growth(physical_devices[0], True)
except:
  # Invalid device or cannot modify virtual devices once initialized.
  pass

# %%
# Mixed precision training

from tensorflow.keras import mixed_precision
mixed_precision.set_global_policy('float32')

#DirectML no se lleva com mixedfloat16
#mixed_precision.set_global_policy('mixed_float16')

# %%
def VGG16_3D(blocks):
        
    inputs = Input(shape=(42, 65, 29), name='input_layer')
    x = Reshape(target_shape=[42, 65, 29, 1], name='input_x_3d_volumes')(inputs)

    if blocks == 1:
        print("entra al 1")
        #batch_norm
        x = BatchNormalization()(x)
        # 1st Conv Block
        x = Conv3D(filters =64, kernel_size =3, padding ='same', activation='relu',kernel_regularizer='l2')(x)
        x = Conv3D(filters =64, kernel_size =3, padding ='same', activation='relu',kernel_regularizer='l2')(x)
        x = MaxPooling3D(pool_size =2, strides =2, padding ='same')(x)
        x = tf.keras.layers.GlobalAveragePooling3D()(x)
        x = tf.keras.layers.Dropout(0.5)(x)
        
    elif blocks == 2:
        print("entra al 2")
        #batch_norm
        x = BatchNormalization()(x)
        # 1st Conv Block
        x = Conv3D(filters =64, kernel_size =3, padding ='same', activation='relu',kernel_regularizer='l2')(x)
        x = Conv3D(filters =64, kernel_size =3, padding ='same', activation='relu',kernel_regularizer='l2')(x)
        x = MaxPooling3D(pool_size =2, strides =2, padding ='same')(x)
        x = tf.keras.layers.Dropout(0.2)(x)
            
        #batch_norm
        x = BatchNormalization()(x)
        # 2nd Conv Block
        x = Conv3D (filters =128, kernel_size =3, padding ='same', activation='relu',kernel_regularizer='l2')(x)
        x = Conv3D (filters =128, kernel_size =3, padding ='same', activation='relu',kernel_regularizer='l2')(x)
        x = MaxPooling3D(pool_size =2, strides =2, padding ='same')(x)
        x = tf.keras.layers.GlobalAveragePooling3D()(x)
        x = tf.keras.layers.Dropout(0.5)(x)
        
    elif blocks == 3:
        print("entra al 3")
        #batch_norm
        x = BatchNormalization()(x)
        # 1st Conv Block
        x = Conv3D(filters =64, kernel_size =3, padding ='same', activation='relu',kernel_regularizer='l2')(x)
        x = Conv3D(filters =64, kernel_size =3, padding ='same', activation='relu',kernel_regularizer='l2')(x)
        x = MaxPooling3D(pool_size =2, strides =2, padding ='same')(x)
        x = tf.keras.layers.Dropout(0.2)(x)
            
        #batch_norm
        x = BatchNormalization()(x)
        # 2nd Conv Block
        x = Conv3D (filters =128, kernel_size =3, padding ='same', activation='relu',kernel_regularizer='l2')(x)
        x = Conv3D (filters =128, kernel_size =3, padding ='same', activation='relu',kernel_regularizer='l2')(x)
        x = MaxPooling3D(pool_size =2, strides =2, padding ='same')(x)
        x = tf.keras.layers.Dropout(0.2)(x)
        
        #batch_norm
        x = BatchNormalization()(x)
        # 3rd Conv block  
        x = Conv3D (filters =256, kernel_size =3, padding ='same', activation='relu',kernel_regularizer='l2')(x) 
        x = Conv3D (filters =256, kernel_size =3, padding ='same', activation='relu',kernel_regularizer='l2')(x) 
        x = Conv3D (filters =256, kernel_size =3, padding ='same', activation='relu',kernel_regularizer='l2')(x) 
        x = MaxPooling3D(pool_size =2, strides =2, padding ='same')(x)
        x = tf.keras.layers.GlobalAveragePooling3D()(x)
        x = tf.keras.layers.Dropout(0.5)(x)
        
    elif blocks == 4:
        print("entra al 4")
        #batch_norm
        x = BatchNormalization()(x)
        # 1st Conv Block
        x = Conv3D(filters =64, kernel_size =3, padding ='same', activation='relu',kernel_regularizer='l2')(x)
        x = Conv3D(filters =64, kernel_size =3, padding ='same', activation='relu',kernel_regularizer='l2')(x)
        x = MaxPooling3D(pool_size =2, strides =2, padding ='same')(x)
        x = tf.keras.layers.Dropout(0.2)(x)
            
        #batch_norm
        x = BatchNormalization()(x)
        # 2nd Conv Block
        x = Conv3D (filters =128, kernel_size =3, padding ='same', activation='relu',kernel_regularizer='l2')(x)
        x = Conv3D (filters =128, kernel_size =3, padding ='same', activation='relu',kernel_regularizer='l2')(x)
        #x = MaxPooling3D(pool_size =2, strides =2, padding ='same')(x)
        x = tf.keras.layers.Dropout(0.2)(x)
        
        #batch_norm
        x = BatchNormalization()(x)
        # 3rd Conv block  
        x = Conv3D (filters =256, kernel_size =3, padding ='same', activation='relu',kernel_regularizer='l2')(x) 
        x = Conv3D (filters =256, kernel_size =3, padding ='same', activation='relu',kernel_regularizer='l2')(x) 
        x = Conv3D (filters =256, kernel_size =3, padding ='same', activation='relu',kernel_regularizer='l2')(x) 
        #x = MaxPooling3D(pool_size =2, strides =2, padding ='same')(x)
        x = tf.keras.layers.Dropout(0.2)(x)
        
        #batch_norm
        x = BatchNormalization()(x)
        # 4th Conv block
        x = Conv3D (filters =512, kernel_size =3, padding ='same', activation='relu',kernel_regularizer='l2')(x)
        x = Conv3D (filters =512, kernel_size =3, padding ='same', activation='relu',kernel_regularizer='l2')(x)
        x = Conv3D (filters =512, kernel_size =3, padding ='same', activation='relu',kernel_regularizer='l2')(x)
        x = MaxPooling3D(pool_size =2, strides =2, padding ='same')(x)
        #x = tf.keras.layers.GlobalAveragePooling3D()(x)
        x = tf.keras.layers.Dropout(0.5)(x)

    elif blocks == 5:
        print("entra al 5")
        #batch_norm
        #x = BatchNormalization()(x)
        # 1st Conv Block
        x = Conv3D(filters =64, kernel_size =3, padding ='same', activation='relu',kernel_regularizer=tf.keras.regularizers.L2(l2=0.001))(x)
        x = Conv3D(filters =64, kernel_size =3, padding ='same', activation='relu',kernel_regularizer=tf.keras.regularizers.L2(l2=0.001))(x)
        x = BatchNormalization()(x)
        x = MaxPooling3D(pool_size =2, strides =2, padding ='same')(x)
        x = tf.keras.layers.Dropout(0.1)(x)
            
        #batch_norm
        #x = BatchNormalization()(x)
        # 2nd Conv Block
        x = Conv3D (filters =128, kernel_size =3, padding ='same', activation='relu',kernel_regularizer=tf.keras.regularizers.L2(l2=0.001))(x)
        x = Conv3D (filters =128, kernel_size =3, padding ='same', activation='relu',kernel_regularizer=tf.keras.regularizers.L2(l2=0.001))(x)
        x = BatchNormalization()(x)
        #x = MaxPooling3D(pool_size =2, strides =1, padding ='same')(x)
        x = tf.keras.layers.Dropout(0.1)(x)
        
        #batch_norm
        #x = BatchNormalization()(x)
        # 3rd Conv block  
        x = Conv3D (filters =256, kernel_size =3, padding ='same', activation='relu',kernel_regularizer=tf.keras.regularizers.L2(l2=0.001))(x) 
        x = Conv3D (filters =256, kernel_size =3, padding ='same', activation='relu',kernel_regularizer=tf.keras.regularizers.L2(l2=0.001))(x) 
        x = Conv3D (filters =256, kernel_size =3, padding ='same', activation='relu',kernel_regularizer=tf.keras.regularizers.L2(l2=0.001))(x) 
        x = BatchNormalization()(x)
        #x = MaxPooling3D(pool_size =2, strides =1, padding ='same')(x)
        x = tf.keras.layers.Dropout(0.1)(x)
        
        #batch_norm
        #x = BatchNormalization()(x)
        # 4th Conv block
        x = Conv3D (filters =512, kernel_size =3, padding ='same', activation='relu',kernel_regularizer=tf.keras.regularizers.L2(l2=0.001))(x)
        x = Conv3D (filters =512, kernel_size =3, padding ='same', activation='relu',kernel_regularizer=tf.keras.regularizers.L2(l2=0.001))(x)
        x = Conv3D (filters =512, kernel_size =3, padding ='same', activation='relu',kernel_regularizer=tf.keras.regularizers.L2(l2=0.001))(x)
        x = BatchNormalization()(x)
        #x = MaxPooling3D(pool_size =2, strides =1, padding ='same')(x)
        x = tf.keras.layers.Dropout(0.1)(x)
    
        #batch_norm
        #x = BatchNormalization()(x)
        # 5th Conv block
        x = Conv3D (filters =512, kernel_size =3, padding ='same', activation='relu',kernel_regularizer=tf.keras.regularizers.L2(l2=0.001))(x)
        x = Conv3D (filters =512, kernel_size =3, padding ='same', activation='relu',kernel_regularizer=tf.keras.regularizers.L2(l2=0.001))(x)
        x = Conv3D (filters =512, kernel_size =3, padding ='same', activation='relu',kernel_regularizer=tf.keras.regularizers.L2(l2=0.001))(x)
        x = BatchNormalization()(x)
        #x = MaxPooling3D(pool_size =2, strides =2, padding ='same')(x)
        x = tf.keras.layers.GlobalAveragePooling3D()(x)
        x = tf.keras.layers.Dropout(0.1)(x)
    
    # Fully connected layers  
    x = Flatten()(x) 
    x = Dense(units = 1024, activation ='relu',kernel_regularizer='l2')(x)
    #x = tf.keras.layers.Dropout(0.5)(x)
    x = Dense(units = 1024, activation ='relu',kernel_regularizer='l2')(x) 
    x = tf.keras.layers.Dropout(0.3)(x)
    output = Dense(units = 2,activation ='softmax',kernel_regularizer='l2')(x)
    
    # creating the model
    VGG_3d_model = Model (inputs=inputs, outputs =output)
    #model.summary()

    return VGG_3d_model

def set_pretrained_weigths(VGG_3d_model):
    #VGG 16 with weights from Imagenet
    pretrained_model = tf.keras.applications.VGG16(
        include_top=False,
        weights="imagenet",
        pooling='avg',
        input_shape = (42, 65, 3)
    )
    
    #conv layers on VGG_3d_model
    layers_conv = []
    for j in range(len(VGG_3d_model.layers)):
        if "conv3d" in str(VGG_3d_model.layers[j]):
            layers_conv.append(j)
    layers_conv_pretrained = []
    for j in range(len(pretrained_model.layers)):
        if "Conv2D" in str(pretrained_model.layers[j]):
            layers_conv_pretrained.append(j)
    
    for i in range(len(layers_conv)):
        if "Conv2D" in str(pretrained_model.layers[layers_conv_pretrained[i]]):
            if i == 0:
                w = pretrained_model.layers[layers_conv_pretrained[i]].get_weights()[0].sum(axis=2, keepdims=True)
            else:
                w = pretrained_model.layers[layers_conv_pretrained[i]].get_weights()[0]
                
            w3d=[]
            
            w = np.reshape(w,(3,3,-1),order='F')
            for j in range(len(w[0,0,:])):
                for k in range(3):
                    w3d.append(w[:,:,j])
            w3d = np.transpose(w3d, (1,2,0))
            
            new_weights = np.reshape(w3d, np.array(VGG_3d_model.layers[layers_conv[i]].get_weights()[0]).shape,order='F')
            new_bias = pretrained_model.layers[layers_conv_pretrained[i]].get_weights()[1]
            
            WnB = []
            WnB.append(new_weights)
            WnB.append(new_bias)
    
            VGG_3d_model.layers[layers_conv[i]].set_weights(WnB)

    del pretrained_model, w, WnB, new_weights, new_bias, w3d

# %%
def confusionmatrix_multiclass(y_test,pred):
    cm = confusion_matrix(y_test, (np.rint(preds)).astype(int) )
    group_names = ['True baseline','False Baseline','False Baseline',   
                   'False week 1','Truec','False Week 1',
                  'False week 7','False week 7','True week 7']
    group_counts = ["{0:0.0f}".format(value) for value in
                    cm.flatten()]
    group_percentages = ["{0:.2%}".format(value) for value in
                         np.ndarray.flatten(cm/(np.sum(cm,axis=1).reshape(3,1)))]
    labels = [f"{v1}\n{v2}\n{v3}" for v1, v2, v3 in
              zip(group_names,group_counts,group_percentages)]
    labels = np.asarray(labels).reshape(3,3)
    sns.heatmap(cm, annot=labels, fmt='', cmap='Blues', xticklabels = ['Baseline','Week 1','Week 7'] ,yticklabels = ['Baseline','Week 1','Week 7'])
    plt.show()

def confusionmatrix(y_test,preds):
    #Construct the Confusion Matrix
    cm = confusion_matrix(y_test, preds)
    group_names = ['True Male','False Male','False Female','True Female']
    group_counts = ["{0:0.0f}".format(value) for value in
                    cm.flatten()]
    group_percentages = ["{0:.2%}".format(value) for value in
                         np.ndarray.flatten(cm/(np.sum(cm,axis=1).reshape(2,1)))]
    labels = [f"{v1}\n{v2}\n{v3}" for v1, v2, v3 in
              zip(group_names,group_counts,group_percentages)]
    labels = np.asarray(labels).reshape(2,2)
    sns.heatmap(cm, annot=labels, fmt='', cmap='Blues', xticklabels = ['MALE','FEMALE'] ,yticklabels = ['MALE','FEMALE'])
    plt.show()
    return sns.heatmap(cm, annot=labels, fmt='', cmap='Blues', xticklabels = ['MALE','FEMALE'] ,yticklabels = ['MALE','FEMALE'])
    
def confusionmatrix_binary(y_test, preds):
    cm = confusion_matrix(y_test, preds)
    group_names = ['True baseline','False baseline','False Week 1','True Week 1']
    group_counts = ["{0:0.0f}".format(value) for value in
                    cm.flatten()]
    group_percentages = ["{0:.2%}".format(value) for value in
                         np.ndarray.flatten(cm/(np.sum(cm,axis=1).reshape(2,1)))]
    labels = [f"{v1}\n{v2}\n{v3}" for v1, v2, v3 in
              zip(group_names,group_counts,group_percentages)]
    labels = np.asarray(labels).reshape(2,2)
    sns.heatmap(cm, annot=labels, fmt='', cmap='Blues', xticklabels = ['MALE','FEMALE'] ,yticklabels = ['MALE','FEMALE'])
    plt.show()

def ROC(probs,y_test): #binary
    #Classification Area under curve
     warnings.filterwarnings('ignore')
             
     auc = roc_auc_score(y_test, probs)
     print('AUC - Test Set: %.2f%%' % (auc*100))
    
     # calculate roc curve
     fpr, tpr, thresholds = roc_curve(y_test, probs)
     # plot no skill
     plt.plot([0, 1], [0, 1], linestyle='--')
     # plot the roc curve for the model
     plt.plot(fpr, tpr, marker='.')
     plt.xlabel('False positive rate')
     plt.ylabel('Sensitivity/ Recall')
     # show the plot
     plt.show()
    
     probs = (np.rint(probs)).astype(int)   
        
     precision = precision_score(y_test, probs)
     print('Precision: %f' % precision)
     # recall: tp / (tp + fn)
     recall = recall_score(y_test, probs)
     print('Recall: %f' % recall)
     # f1: tp / (tp + fp + fn)
     f1 = f1_score(y_test, probs)
     print('F1 score: %f' % f1)
        
def ROC_multiclass(model, y_test, n_class):
    #y_test: array size (# of subjects, ) with classes 
    #pretrained model to be evaluated 
    
    label_binarizer = LabelBinarizer().fit(y_test)
    y_onehot_test = label_binarizer.transform(y_test)
    y_onehot_test.shape  # (n_samples, n_classes)

    y_score = model.predict(X_test) # y_score is onehot
    
    # store the fpr, tpr, and roc_auc for all averaging strategies
    fpr, tpr, roc_auc = dict(), dict(), dict()
    # Compute micro-average ROC curve and ROC area
    fpr["micro"], tpr["micro"], _ = roc_curve(y_onehot_test.ravel(), y_score.ravel())
    roc_auc["micro"] = auc(fpr["micro"], tpr["micro"])

    print(f"Micro-averaged One-vs-Rest ROC AUC score:\n{roc_auc['micro']:.2f}")
    
    n_classes = n_class
    
    for i in range(n_classes):
        fpr[i], tpr[i], _ = roc_curve(y_onehot_test[:, i], y_score[:, i])
        roc_auc[i] = auc(fpr[i], tpr[i])

    fpr_grid = np.linspace(0.0, 1.0, 1000)

    # Interpolate all ROC curves at these points
    mean_tpr = np.zeros_like(fpr_grid)

    for i in range(n_classes):
        mean_tpr += np.interp(fpr_grid, fpr[i], tpr[i])  # linear interpolation

    # Average it and compute AUC
    mean_tpr /= n_classes

    fpr["macro"] = fpr_grid
    tpr["macro"] = mean_tpr
    roc_auc["macro"] = auc(fpr["macro"], tpr["macro"])

    print(f"Macro-averaged One-vs-Rest ROC AUC score:\n{roc_auc['macro']:.2f}")
    
    target_names = ['Naive','Week1','Week7']

    fig, ax = plt.subplots(figsize=(6, 6))

    plt.plot(
        fpr["micro"],
        tpr["micro"],
        label=f"micro-average ROC curve (AUC = {roc_auc['micro']:.2f})",
        color="deeppink",
        linestyle=":",
        linewidth=4,
    )

    plt.plot(
        fpr["macro"],
        tpr["macro"],
        label=f"macro-average ROC curve (AUC = {roc_auc['macro']:.2f})",
        color="navy",
        linestyle=":",
        linewidth=4,
    )

    colors = cycle(["aqua", "darkorange", "cornflowerblue"])
    for class_id, color in zip(range(n_classes), colors):
        RocCurveDisplay.from_predictions(
            y_onehot_test[:, class_id],
            y_score[:, class_id],
            name=f"ROC curve for {target_names[class_id]}",
            color=color,
            ax=ax,
            plot_chance_level=(class_id == 2),
        )

    _ = ax.set(
        xlabel="False Positive Rate",
        ylabel="True Positive Rate",
        title="Extension of Receiver Operating Characteristic\nto One-vs-Rest multiclass",
    )
    
# plot diagnostic learning curves
def summarize_diagnostics(histories):
    c = ['b','g','r','c','m','y','k','w']
    ltr = ['fold 1(train)','fold 2(train)','fold 3(train)','fold 4(train)','fold 5(train)']
    lts = ['fold 1(val)','fold 2(val)','fold 3(val)','fold 4(val)','fold 5(val)']
    for i in range(len(histories)):
        # plot loss
        plt.subplot(2, 1, 1)
        plt.title('Cross Entropy Loss')
        plt.plot(histories[i].history['loss'], color=c[i], label=ltr[i], linestyle="-")
        plt.plot(histories[i].history['val_loss'], color=c[i], label=lts[i], linestyle="--")
        # plot accuracy
        plt.subplot(2, 1, 2)
        plt.title('Classification Accuracy')
        plt.plot(histories[i].history['Accuracy'], color=c[i], label=ltr[i], linestyle="-")
        plt.plot(histories[i].history['val_Accuracy'], color=c[i], label=lts[i], linestyle="--")
    plt.legend()
    plt.show()

# summarize model performance
def summarize_performance(scores):
    # print summary
    print('Accuracy: mean=%.3f std=%.3f, n=%d' % (np.mean(scores)*100, np.std(scores)*100, len(scores)))
    # box and whisker plots of results
    plt.boxplot(scores)
    plt.show()

# %% [markdown]
# # Just Brain Male-BL vs Female-BL

# %%
CPHfemale = [49,50,51,52,65,66,77,78,79,80,81,82,83] # List of subjects belonging to the CPH female group. 

subjects = np.array(CPHfemale) # Convert the list into a NumPy array so it can be indexed easily during data loading

sessions = [1, 2, 3]  #Takes
MRI_type = "func"
functional_type = "dist"

baseModel = VGG16_3D(5)
set_pretrained_weigths(baseModel) 
labels = np.zeros(len(subjects)) # Convert the list into a NumPy array so it can be indexed easily during data loading.

CNN = VGG16_3D(5)
# Out:
# entra al 5
# entra al 5

# %%
rootpath1= r"C:\Users\l03087364\Downloads\Kerensa Sierra_EI\sigma_files\sigma_files\SIGMA_resam_InVivo_Brain_Template_Masked.nii" #Path to the brain template
img = nib.load(rootpath1) #Loads the NIfTI file using nibabel
data_grad_completo = img.get_fdata() #Convert the NIfTI image into a NumPy array
print(data_grad_completo.shape)
# Out:
# (48, 81, 48)

# %%
# 80% train y val y 20% test
sub_trainval, sub_test, y_trainval, y_test = train_test_split(
    subjects, labels, test_size=0.2, random_state=42, stratify=labels
)

n_bootstraps= 1
for boot in range(n_bootstraps): 
    print(f"\n=== Bootstrapping Run {boot+1}/{n_bootstraps} ===")

    boot_subjects, boot_labels = resample(
        sub_trainval, y_trainval, replace=True, random_state=42+boot
    )

    kfold = StratifiedKFold(n_splits=5, shuffle=True, random_state=1)

    scores, histories = list(), list()
    run = 1
    for train_ix, val_ix in kfold.split(boot_subjects, boot_labels):

        sub_train, sub_val = boot_subjects[train_ix], boot_subjects[val_ix]
        y_train, y_val     = boot_labels[train_ix], boot_labels[val_ix]

        sub_test, y_test = sub_test, y_test

        print("Run #",run)

        # Set default values
        config_defaults = {
            "batch": 1,
        }
        # Initialize wandb with a sample project name
        wandb.init(project="CPHfemale_BLvsW1W7_100epochs", notes="FOLD "+str(run)+".  Female-BL vs W1W7_100epochs. Rest-approach on DIST data",dir="C:/Users/103087364/wandb_runs"
                   ,config=config_defaults)

        # Specify the other hyperparameters to the configuration.
        wandb.config.epochs = 1
        wandb.config.sub_batch = 15
        wandb.config.sub_batch_ts = 15
        wandb.config.subjects = subjects
        wandb.config.architecture_name = "VGG16_3D"
        wandb.config.dataset_name = "CPHfemale_BLvsW1W7_100epochs"
        wandb.config.CNN_blocks = 5
        wandb.config.sessions = sessions
        wandb.config.vols_per_session_tr = 30#570
        wandb.config.vols_per_session_ts = 30#570
        wandb.config.initial_learning_rate = 1e-5
        #wandb.config.lr_decay_rate = 0.95
        wandb.config.optimizer = "Adam"
        
        
        val_size = max(2, int(round(0.1 * len(train_ix))))
    
        sub_train, sub_val, y_train, y_val = train_test_split(
            sub_trainval[train_ix], y_trainval[train_ix],
            test_size=val_size,  # test_size se refiere a la validacion
            random_state=42, stratify=y_trainval[train_ix]
        )
        
        CPHclassTrain = FILES_and_LABELS(sub_train, sessions, MRI_type, functional_type)
        CPHclassTest = FILES_and_LABELS(sub_test, sessions, MRI_type, functional_type)
        CPHclassval = FILES_and_LABELS(sub_val, sessions, MRI_type, functional_type)
            
        X_train = CPHclassTrain.get_mask_and_bold()
    
        print("X_train con exito")
        X_test = CPHclassTest.get_mask_and_bold()
        print("X_test con exito")
        X_val = CPHclassval.get_mask_and_bold()
        print("X_val con exito")

        print("sub train:")
        print(np.array(X_train)[:,0])
        print("sub test:")
        print(np.array(X_test)[:,0])
        print("sub val:")
        print(np.array(X_val)[:,0])

        print("# sesiones Train",len(X_train))
        print("# sesiones Test",len(X_test))
        print("# sesiones Val",len(X_val))
        
        traingen = CustomDataGen(X_train, batch_size=wandb.config.batch, subbatch_size=wandb.config.sub_batch,
                                format = "just_brain", vols = wandb.config.vols_per_session_tr,
                                num_class = 2, classes = "CPHfemale_BLvsW1W7", augmentation = True, functional_type = "rest")
        traingen.on_epoch_end()
        #Es necesario que la division entre X_test y batch_size tenga un modulo igual a 0. 
        #De otra manera el ultimo batch no lo utiliza al utilizar .predict
        testgen  = CustomDataGen(X_test, batch_size=1,subbatch_size=wandb.config.sub_batch_ts,
                                format = "just_brain", vols= wandb.config.vols_per_session_ts,
                                num_class = 2, classes = "CPHfemale_BLvsW1W7",shuffle=False, functional_type = "rest")
        valgen  = CustomDataGen(X_val, batch_size=len(X_val),subbatch_size=15, format = "just_brain",vols=570, augmentation = True, num_class = 2,
                                classes = "CPHfemale_BLvsW1W7", functional_type = "rest")
        
        #getting model 3D CNN
        #callback = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=4, min_delta=0.0001)
        print("Starting VGG 16 3D-----------------------------------------------------")
        tf.keras.backend.clear_session()
        gc.collect()

        #transfer learning
        layers = [l for l in CNN.layers]
            
        for i in range(len(baseModel.layers)):
            layers[i].set_weights(baseModel.layers[i].get_weights())
            
        """
        lr_schedule = ExponentialDecay(wandb.config.initial_learning_rate,
                                    decay_steps=int((wandb.config.vols_per_session_tr/wandb.config.sub_batch)*len(X_train)),
                                    decay_rate=wandb.config.lr_decay_rate, staircase=True)
        """
        CNN.compile(loss="categorical_crossentropy", optimizer=tf.keras.optimizers.Adam(learning_rate=wandb.config.initial_learning_rate),
                        metrics=["Accuracy"])

        #checkpoint_filepath =os.getcwd()+"/"+wandb.run.name
        checkpoint_filepath = os.path.join("W:/", f"{wandb.run.name}.h5")
        #'/tmp/ckpt/MalevsFemale(CPH)_3D-VGG16_flips/'+wandb.run.name
        
        model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(filepath=checkpoint_filepath, monitor='val_loss', mode='min',
                                                                save_best_only=True)
        
        start_time = datetime.now()
        
        print("Training")

        print("Starting VGG 16 3D-----------------------------------------------------")
    # --- DEBUG: inspección del generador ---
        history = CNN.fit(traingen, epochs=wandb.config.epochs, validation_data = valgen, shuffle=True, callbacks=[SafeWandbCallback(monitor='val_loss',mode="min",save_model=False),model_checkpoint_callback])  
               
        end_time = datetime.now()
        print('Duration (CNN): {}'.format(end_time - start_time))

        y_test=[]
        x_vols = []
        for i in range(int(len(X_test)*(wandb.config.vols_per_session_ts/wandb.config.sub_batch_ts))):
            x,y = testgen[i]
            y_test.extend(y)
            x_vols.extend(x)
        y_test = np.argmax(y_test, axis=1)
        print("predicts CNN")
        preds = tf.cast(tf.argmax(CNN.predict(testgen), axis=1), tf.int32)
        #Wrong predicted subjects
        wrong_labeled_subj = mislabeled_subj(y_test, preds, X_test, wandb.config.vols_per_session_ts)

        print("mislabeled subjects:\n",wrong_labeled_subj)
        
        print("evaluating CNN")
        _,acc = CNN.evaluate(testgen, verbose=1)
        
        scores.append(acc)
        histories.append(history)

        #GradCam
        all_layers = [layer.name for layer in reversed(CNN.layers) if len(layer.output_shape) == 5 and (layer.__class__.__name__ == 'ReLU' or isinstance(layer, tf.keras.layers.Conv3D))]
        index_male = index_for_gradcam(0,y_test,preds)
        index_female = index_for_gradcam(1,y_test,preds)
        data_grad = data_grad_completo[3:45, 4:69, 7:36]
        #Writer = animation.writers['ffmpeg']
        #writer = Writer(fps=15, metadata=dict(artist='Me'), bitrate=1800)

        if index_male != None:
            heatmap_male = make_gradcam_heatmap(np.expand_dims(x_vols[index_male], axis=0), CNN, all_layers[0])
            resized_heatmap_male = get_resized_heatmap(heatmap_male, np.shape(x_vols[index_male]))
            #gradcam_male = create_animation(data_grad, 'Male', heatmap=resized_heatmap_male) #Cambio requerido, mismo sujeto
            print("Frame shape de x_vols[index_male]:", np.shape(x_vols[index_male]))
            print("Heatmap shape:", np.shape(resized_heatmap_male))
            print("Animación:", gradcam_male)

            #name_ani_male = "GradCam_male(malevsfemale-CPH)-"+wandb.run.name+".mp4"
            #gradcam_male.save(name_ani_male, writer=writer)
            
            output_dir = "E:"
            os.makedirs(output_dir, exist_ok=True)
            #name_ani_male = os.path.join(output_dir, "GradCam_male(CPH_BLvsW1W7)-" + wandb.run.name + ".mp4")
            #gradcam_male.save(name_ani_male, writer=writer)
            
            #GradCam average all conv layers
            print("GradCam All ConvLayers-male")

            all_layers_gradcam_male = fuse_layers(all_layers, CNN, x_vols, index_male, emphasize=False)
            #all_layers_animation_male = create_animation(data_grad, 'All_layers_GradCam_male', heatmap=all_layers_gradcam_male) #Cambio requerido, muchos sujetos
            #name_all_male = 'All_layers_GradCam_male'+wandb.run.name+'.mp4'
            #name_all_male = os.path.join(output_dir, "All_layers_GradCam_male" + wandb.run.name + ".mp4")
            a#ll_layers_animation_male.save(name_all_male, writer=writer)

            #males
            if not os.path.exists("W:"+"/"+wandb.run.name+"/male"): 
                # if the demo_folder directory is not present  
                # then create it. 
                os.makedirs("W:"+"/"+wandb.run.name+"/male")
                
            for i in range(len(x_vols[index_female][0,:,0])):
                plt.imshow(cv2.resize(np.rot90(np.array(x_vols[index_male])[:,i,:]),dsize=(126,87)), alpha=0.8, cmap='bone')
                # over the cam output
                plt.imshow(cv2.resize(np.rot90(resized_heatmap_male[:,i,:]),dsize=(126,87)), alpha=0.4,cmap='jet')
                plt.axis('off')
                # display the image
                name = str(i)+".png" 
                plt.savefig(os.getcwd()+"/"+wandb.run.name+"/male/"+name)
                plt.show()

            full_grad_male = np.zeros_like(data_grad_completo)
            full_grad_male[3:45,4:69,7:36] = resized_heatmap_male
            np.save("W:"+"/"+wandb.run.name+"/male/Array_GradCam-M", full_grad_male)
            
            #wandb.log({'GradCam_Male-coronal': wandb.Video(name_ani_male),
                #'GradCam_Male_all-layers': wandb.Video(name_all_male),
                #'GradCam-per_frames-male': wandb.Image(grad_cam_per_frames(data_grad,resized_heatmap_male, 150))})

        if index_female != None:
            heatmap_female = make_gradcam_heatmap(np.expand_dims(x_vols[index_female], axis=0), CNN, all_layers[0]) 
            resized_heatmap_female = get_resized_heatmap(heatmap_female, np.shape(x_vols[index_female]))
            #gradcam_female = create_animation(data_grad, 'Female', heatmap=resized_heatmap_female)
            #name_ani_female = "GradCam_female(malevsfemale-CPH)-"+wandb.run.name+".mp4"
            #gradcam_female.save(name_ani_female, writer=writer)

            output_dir = "E:"
            #name_ani_female = os.path.join(output_dir, "GradCam_female(CPH_BLvsW1W7)-" + wandb.run.name + ".mp4")
            #gradcam_female.save(name_ani_female, writer=writer)
            
            #GradCam average all conv layers
            print("GradCam All ConvLayers-female")
        
            all_layers_gradcam_female = fuse_layers(all_layers, CNN, x_vols, index_female, emphasize=False)
            #all_layers_animation_female = create_animation(data_grad, 'All_layers_GradCam_female', heatmap=all_layers_gradcam_female)
            #name_all_female = 'All_layers_GradCam_female'+wandb.run.name+'.mp4'
            #name_all_female = os.path.join(output_dir, "All_layers_GradCam_female" + wandb.run.name + ".mp4")
            #all_layers_animation_female.save(name_all_female, writer=writer)
        
            #Save frame by frame of gradcam
            #Females
            if not os.path.exists("W:"+"/"+wandb.run.name+"/female"): 
                # if the demo_folder directory is not present  
                # then create it. 
                os.makedirs("W:"+"/"+wandb.run.name+"/female")
            
            for i in range(len(x_vols[index_female][0,:,0])):
                plt.imshow(cv2.resize(np.rot90(np.array(data_grad)[:,i,:]),dsize=(126,87)), alpha=0.8, cmap='bone')
                # over the cam output
                #plt.imshow(cv2.resize(np.rot90(resized_heatmap_female[:,i,:]),dsize=(126,87)), alpha=0.4,cmap='jet')
                plt.imshow(cv2.resize(np.rot90(np.where(resized_heatmap_female[:, i, :] > np.percentile(resized_heatmap_female, 90),resized_heatmap_female[:, i, :], np.nan)),dsize=(126, 87)),cmap='Reds',alpha=1.0)
                plt.axis('off')
                # display the image
                
                name = str(i)+".png" 
                plt.savefig("W:"+"/"+wandb.run.name+"/female/"+name)
                plt.show()
        
            
            #get gradCams with the shape of the original volumes before crop
            full_grad_female = np.zeros_like(data_grad_completo)
            full_grad_female[3:45,4:69,7:36] = resized_heatmap_female
            #full_grad_female = np.zeros((48,81,48))
            #full_grad_female[3:45,4:69,7:36] = resized_heatmap_female
            np.save("W:"+"/"+wandb.run.name+"/female/Array_GradCam-F", full_grad_female)
            #wandb.log({'GradCam-Female-coronal': wandb.Video(name_ani_female),
                #'GradCam-Female_all-layers': wandb.Video(name_all_female),
                #'GradCam-per_frames-female': wandb.Image(grad_cam_per_frames(data_grad,resized_heatmap_female, 150))})
            

        print("CM CNN")
        cm = confusionmatrix(y_test, preds)

        wandb.log({'test_acc': float(acc),
                'time_running': '{}'.format(end_time - start_time),
                'confution_matrix': wandb.Image(cm),
                'mislabeled_subj':wrong_labeled_subj})
        

        run = run + 1
            
    print("histories and scores from VGG 16 M2D") 
    summarize_diagnostics(histories)
    summarize_performance(scores)

    wandb.finish()
# Out:
# === Bootstrapping Run 1/1 ===
# Run # 1
# Finishing previous runs because reinit is set to 'default'.
#  View run <strong style="color:#cdcd00">generous-meadow-1</strong> at: <a href='https://wandb.ai/mansoor35/CPHfemale_BLvsW1W7_100epochs/runs/u4fy0ubz' target="_blank">https://wandb.ai/mansoor35/CPHfemale_BLvsW1W7_100epochs/runs/u4fy0ubz</a><br> View project at: <a href='https://wandb.ai/mansoor35/CPHfemale_BLvsW1W7_100epochs' target="_blank">https://wandb.ai/mansoor35/CPHfemale_BLvsW1W7_100epochs</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>C:\Users\L03087~1\AppData\Local\Temp\wandb\run-20251205_233314-u4fy0ubz\logs</code>
# Tracking run with wandb version 0.22.0
# Run data is saved locally in <code>C:\Users\L03087~1\AppData\Local\Temp\wandb\run-20251205_235329-rzbzqjk2</code>
# Syncing run <strong><a href='https://wandb.ai/mansoor35/CPHfemale_BLvsW1W7_100epochs/runs/rzbzqjk2' target="_blank">jumping-leaf-2</a></strong> to <a href='https://wandb.ai/mansoor35/CPHfemale_BLvsW1W7_100epochs' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/mansoor35/CPHfemale_BLvsW1W7_100epochs' target="_blank">https://wandb.ai/mansoor35/CPHfemale_BLvsW1W7_100epochs</a>
#  View run at <a href='https://wandb.ai/mansoor35/CPHfemale_BLvsW1W7_100epochs/runs/rzbzqjk2' target="_blank">https://wandb.ai/mansoor35/CPHfemale_BLvsW1W7_100epochs/runs/rzbzqjk2</a>
# holaaaa, se metio al mask and bold
# SE METIO AL DISTTTTTTTTTT
# SE METIO AL LOGIN
# sesions:  [1, 2, 3]
# SESION:  1
# Se metió al 68
# j:  66
# Se metió al 68
# j:  65
# ENTRO AL SEGUNDO SUB BATCH
# Se metió al 68
# j:  50
# ENTRO AL SEGUNDO SUB BATCH
# Se metió al 68
# j:  49
# SESION:  2
# Se metió al 68
# j:  66
# Se metió al 68
# j:  65
# ENTRO AL SEGUNDO SUB BATCH
# Se metió al 68
# j:  50
# ENTRO AL SEGUNDO SUB BATCH
# Se metió al 68
# j:  49
# SESION:  3
# Se metió al 68
# j:  66
# Se metió al 68
# j:  65
# ENTRO AL SEGUNDO SUB BATCH
# Se metió al 68
# j:  50
# ENTRO AL SEGUNDO SUB BATCH
# Se metió al 68
# j:  49
# X_train con exito
# holaaaa, se metio al mask and bold
# SE METIO AL DISTTTTTTTTTT
# SE METIO AL LOGIN
# sesions:  [1, 2, 3]
# SESION:  1
# ENTRO AL SEGUNDO SUB BATCH
# ENTRO AL SEGUNDO SUB BATCH
# Se metió al 68
# j:  52
# SESION:  2
# ENTRO AL SEGUNDO SUB BATCH
# ENTRO AL SEGUNDO SUB BATCH
# Se metió al 68
# j:  52
# SESION:  3
# ENTRO AL SEGUNDO SUB BATCH
# ENTRO AL SEGUNDO SUB BATCH
# Se metió al 68
# j:  52
# X_test con exito
# holaaaa, se metio al mask and bold
# SE METIO AL DISTTTTTTTTTT
# SE METIO AL LOGIN
# sesions:  [1, 2, 3]
# SESION:  1
# ENTRO AL SEGUNDO SUB BATCH
# ENTRO AL SEGUNDO SUB BATCH
# SESION:  2
# ENTRO AL SEGUNDO SUB BATCH
# ENTRO AL SEGUNDO SUB BATCH
# SESION:  3
# ENTRO AL SEGUNDO SUB BATCH
# ENTRO AL SEGUNDO SUB BATCH
# X_val con exito
# sub train:
# ['R:/preprocess_batch-001/commonspace_bold/_scan_info_subject_id066.session01_split_name_sub-066_ses-01_desc-o_T2w/_run_None/sub-066_ses-01_task-dist_desc-oa_bold_autobox_combined.nii.gz'
#  'R:/preprocess_batch-001/commonspace_bold/_scan_info_subject_id065.session01_split_name_sub-065_ses-01_desc-o_T2w/_run_None/sub-065_ses-01_task-dist_desc-oa_bold_autobox_combined.nii.gz'
#  'R:/preprocess_batch-002/commonspace_bold/_scan_info_subject_id083.session01_split_name_sub-083_ses-01_desc-o_T2w/_run_None/sub-083_ses-01_task-dist_desc-oa_bold_autobox_combined.nii.gz'
#  'R:/preprocess_batch-001/commonspace_bold/_scan_info_subject_id050.session01_split_name_sub-050_ses-01_desc-o_T2w/_run_None/sub-050_ses-01_task-dist_desc-oa_bold_autobox_combined.nii.gz'
#  'R:/preprocess_batch-002/commonspace_bold/_scan_info_subject_id082.session01_split_name_sub-082_ses-01_desc-o_T2w/_run_None/sub-082_ses-01_task-dist_desc-oa_bold_autobox_combined.nii.gz'
#  'R:/preprocess_batch-001/commonspace_bold/_scan_info_subject_id049.session01_split_name_sub-049_ses-01_desc-o_T2w/_run_None/sub-049_ses-01_task-dist_desc-oa_bold_autobox_combined.nii.gz'
#  'R:/preprocess_batch-001/commonspace_bold/_scan_info_subject_id066.session02_split_name_sub-066_ses-02_desc-o_T2w/_run_None/sub-066_ses-02_task-dist_desc-oa_bold_autobox_combined.nii.gz'
#  'R:/preprocess_batch-001/commonspace_bold/_scan_info_subject_id065.session02_split_name_sub-065_ses-02_desc-o_T2w/_run_None/sub-065_ses-02_task-dist_desc-oa_bold_autobox_combined.nii.gz'
#  'R:/preprocess_batch-002/commonspace_bold/_scan_info_subject_id083.session02_split_name_sub-083_ses-02_desc-o_T2w/_run_None/sub-083_ses-02_task-dist_desc-oa_bold_autobox_combined.nii.gz'
#  'R:/preprocess_batch-001/commonspace_bold/_scan_info_subject_id050.session02_split_name_sub-050_ses-02_desc-o_T2w/_run_None/sub-050_ses-02_task-dist_desc-oa_bold_autobox_combined.nii.gz'
#  'R:/preprocess_batch-002/commonspace_bold/_scan_info_subject_id082.session02_split_name_sub-082_ses-02_desc-o_T2w/_run_None/sub-082_ses-02_task-dist_desc-oa_bold_autobox_combined.nii.gz'
#  'R:/preprocess_batch-001/commonspace_bold/_scan_info_subject_id049.session02_split_name_sub-049_ses-02_desc-o_T2w/_run_None/sub-049_ses-02_task-dist_desc-oa_bold_autobox_combined.nii.gz'
#  'R:/preprocess_batch-001/commonspace_bold/_scan_info_subject_id066.session03_split_name_sub-066_ses-03_desc-o_T2w/_run_None/sub-066_ses-03_task-dist_desc-oa_bold_autobox_combined.nii.gz'
#  'R:/preprocess_batch-001/commonspace_bold/_scan_info_subject_id065.session03_split_name_sub-065_ses-03_desc-o_T2w/_run_None/sub-065_ses-03_task-dist_desc-oa_bold_autobox_combined.nii.gz'
#  'R:/preprocess_batch-002/commonspace_bold/_scan_info_subject_id083.session03_split_name_sub-083_ses-03_desc-o_T2w/_run_None/sub-083_ses-03_task-dist_desc-oa_bold_autobox_combined.nii.gz'
#  'R:/preprocess_batch-001/commonspace_bold/_scan_info_subject_id050.session03_split_name_sub-050_ses-03_desc-o_T2w/_run_None/sub-050_ses-03_task-dist_desc-oa_bold_autobox_combined.nii.gz'
#  'R:/preprocess_batch-002/commonspace_bold/_scan_info_subject_id082.session03_split_name_sub-082_ses-03_desc-o_T2w/_run_None/sub-082_ses-03_task-dist_desc-oa_bold_autobox_combined.nii.gz'
#  'R:/preprocess_batch-001/commonspace_bold/_scan_info_subject_id049.session03_split_name_sub-049_ses-03_desc-o_T2w/_run_None/sub-049_ses-03_task-dist_desc-oa_bold_autobox_combined.nii.gz']
# sub test:
# ['R:/preprocess_batch-002/commonspace_bold/_scan_info_subject_id081.session01_split_name_sub-081_ses-01_desc-o_T2w/_run_None/sub-081_ses-01_task-dist_desc-oa_bold_autobox_combined.nii.gz'
#  'R:/preprocess_batch-002/commonspace_bold/_scan_info_subject_id077.session01_split_name_sub-077_ses-01_desc-o_T2w/_run_None/sub-077_ses-01_task-dist_desc-oa_bold_autobox_combined.nii.gz'
#  'R:/preprocess_batch-001/commonspace_bold/_scan_info_subject_id052.session01_split_name_sub-052_ses-01_desc-o_T2w/_run_None/sub-052_ses-01_task-dist_desc-oa_bold_autobox_combined.nii.gz'
#  'R:/preprocess_batch-002/commonspace_bold/_scan_info_subject_id081.session02_split_name_sub-081_ses-02_desc-o_T2w/_run_None/sub-081_ses-02_task-dist_desc-oa_bold_autobox_combined.nii.gz'
#  'R:/preprocess_batch-002/commonspace_bold/_scan_info_subject_id077.session02_split_name_sub-077_ses-02_desc-o_T2w/_run_None/sub-077_ses-02_task-dist_desc-oa_bold_autobox_combined.nii.gz'
#  'R:/preprocess_batch-001/commonspace_bold/_scan_info_subject_id052.session02_split_name_sub-052_ses-02_desc-o_T2w/_run_None/sub-052_ses-02_task-dist_desc-oa_bold_autobox_combined.nii.gz'
#  'R:/preprocess_batch-002/commonspace_bold/_scan_info_subject_id081.session03_split_name_sub-081_ses-03_desc-o_T2w/_run_None/sub-081_ses-03_task-dist_desc-oa_bold_autobox_combined.nii.gz'
#  'R:/preprocess_batch-002/commonspace_bold/_scan_info_subject_id077.session03_split_name_sub-077_ses-03_desc-o_T2w/_run_None/sub-077_ses-03_task-dist_desc-oa_bold_autobox_combined.nii.gz'
#  'R:/preprocess_batch-001/commonspace_bold/_scan_info_subject_id052.session03_split_name_sub-052_ses-03_desc-o_T2w/_run_None/sub-052_ses-03_task-dist_desc-oa_bold_autobox_combined.nii.gz']
# sub val:
# ['R:/preprocess_batch-002/commonspace_bold/_scan_info_subject_id079.session01_split_name_sub-079_ses-01_desc-o_T2w/_run_None/sub-079_ses-01_task-dist_desc-oa_bold_autobox_combined.nii.gz'
#  'R:/preprocess_batch-002/commonspace_bold/_scan_info_subject_id078.session01_split_name_sub-078_ses-01_desc-o_T2w/_run_None/sub-078_ses-01_task-dist_desc-oa_bold_autobox_combined.nii.gz'
#  'R:/preprocess_batch-002/commonspace_bold/_scan_info_subject_id079.session02_split_name_sub-079_ses-02_desc-o_T2w/_run_None/sub-079_ses-02_task-dist_desc-oa_bold_autobox_combined.nii.gz'
#  'R:/preprocess_batch-002/commonspace_bold/_scan_info_subject_id078.session02_split_name_sub-078_ses-02_desc-o_T2w/_run_None/sub-078_ses-02_task-dist_desc-oa_bold_autobox_combined.nii.gz'
#  'R:/preprocess_batch-002/commonspace_bold/_scan_info_subject_id079.session03_split_name_sub-079_ses-03_desc-o_T2w/_run_None/sub-079_ses-03_task-dist_desc-oa_bold_autobox_combined.nii.gz'
#  'R:/preprocess_batch-002/commonspace_bold/_scan_info_subject_id078.session03_split_name_sub-078_ses-03_desc-o_T2w/_run_None/sub-078_ses-03_task-dist_desc-oa_bold_autobox_combined.nii.gz']
# # sesiones Train 18
# # sesiones Test 9
# # sesiones Val 6
# Starting VGG 16 3D-----------------------------------------------------
# Training
# Starting VGG 16 3D-----------------------------------------------------
# subbatch_index: 0
#  batch_index calculado: 0
# DEBUG tamaño total de self.df: 18
# Tamaño de batches recibido: 1
# Longitud final de path_batch: 1
# Forma final de y_batch: (30, 2)
# subbatch_index: 23
#  batch_index calculado: 11
# DEBUG tamaño total de self.df: 18
# Tamaño de batches recibido: 1
# Longitud final de path_batch: 1
# Forma final de y_batch: (30, 2)
# subbatch_index: 10
#  batch_index calculado: 5
# DEBUG tamaño total de self.df: 18
# Tamaño de batches recibido: 1
# Longitud final de path_batch: 1
# Forma final de y_batch: (30, 2)
# W&B Graph visualization desactivada (inbound_layers incompatibles con Keras 3.x).
#  1/36 [..............................] - ETA: 8:34 - loss: 22.6437 - Accuracy: 0.6667subbatch_index: 18
#  batch_index calculado: 9
# DEBUG tamaño total de self.df: 18
# Tamaño de batches recibido: 1
# Longitud final de path_batch: 1
# Forma final de y_batch: (30, 2)
#  2/36 [>.............................] - ETA: 3:20 - loss: 22.6385 - Accuracy: 0.7000subbatch_index: 9
#  batch_index calculado: 4
# DEBUG tamaño total de self.df: 18
# Tamaño de batches recibido: 1
# Longitud final de path_batch: 1
# Forma final de y_batch: (30, 2)
#  3/36 [=>............................] - ETA: 3:15 - loss: 22.6335 - Accuracy: 0.6889subbatch_index: 14
#  batch_index calculado: 7
# DEBUG tamaño total de self.df: 18
# Tamaño de batches recibido: 1
# Longitud final de path_batch: 1
# Forma final de y_batch: (30, 2)
#  4/36 [==>...........................] - ETA: 3:24 - loss: 22.6297 - Accuracy: 0.6000subbatch_index: 31
#  batch_index calculado: 15
# DEBUG tamaño total de self.df: 18
# Tamaño de batches recibido: 1
# Longitud final de path_batch: 1
# Forma final de y_batch: (30, 2)
#  5/36 [===>..........................] - ETA: 3:26 - loss: 22.6219 - Accuracy: 0.6267subbatch_index: 13
#  batch_index calculado: 6
# DEBUG tamaño total de self.df: 18
# Tamaño de batches recibido: 1
# Longitud final de path_batch: 1
# Forma final de y_batch: (30, 2)
#  6/36 [====>.........................] - ETA: 3:21 - loss: 22.6186 - Accuracy: 0.5556WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 2.3116s vs `on_train_batch_end` time: 4.3916s). Check your callbacks.
# subbatch_index: 30
#  batch_index calculado: 15
# DEBUG tamaño total de self.df: 18
# Tamaño de batches recibido: 1
# Longitud final de path_batch: 1
# Forma final de y_batch: (30, 2)
#  7/36 [====>.........................] - ETA: 3:16 - loss: 22.6140 - Accuracy: 0.5333subbatch_index: 15
#  batch_index calculado: 7
# DEBUG tamaño total de self.df: 18
# Tamaño de batches recibido: 1
# Longitud final de path_batch: 1
# Forma final de y_batch: (30, 2)
#  8/36 [=====>........................] - ETA: 3:23 - loss: 22.6095 - Accuracy: 0.5167subbatch_index: 35
#  batch_index calculado: 17
# DEBUG tamaño total de self.df: 18
# Tamaño de batches recibido: 1
# Longitud final de path_batch: 1
# Forma final de y_batch: (30, 2)
#  9/36 [======>.......................] - ETA: 3:18 - loss: 22.6027 - Accuracy: 0.5481subbatch_index: 3
#  batch_index calculado: 1
# DEBUG tamaño total de self.df: 18
# Tamaño de batches recibido: 1
# Longitud final de path_batch: 1
# Forma final de y_batch: (30, 2)
# 10/36 [=======>......................] - ETA: 3:11 - loss: 22.5984 - Accuracy: 0.5333subbatch_index: 4
#  batch_index calculado: 2
# DEBUG tamaño total de self.df: 18
# Tamaño de batches recibido: 1
# Longitud final de path_batch: 1
# Forma final de y_batch: (30, 2)
# 11/36 [========>.....................] - ETA: 3:08 - loss: 22.5917 - Accuracy: 0.5515subbatch_index: 7
#  batch_index calculado: 3
# DEBUG tamaño total de self.df: 18
# Tamaño de batches recibido: 1
# Longitud final de path_batch: 1
# Forma final de y_batch: (30, 2)
# 12/36 [=========>....................] - ETA: 3:00 - loss: 22.5871 - Accuracy: 0.5167subbatch_index: 16
#  batch_index calculado: 8
# DEBUG tamaño total de self.df: 18
# Tamaño de batches recibido: 1
# Longitud final de path_batch: 1
# Forma final de y_batch: (30, 2)
# 13/36 [=========>....................] - ETA: 2:54 - loss: 22.5809 - Accuracy: 0.5179subbatch_index: 6
#  batch_index calculado: 3
# DEBUG tamaño total de self.df: 18
# Tamaño de batches recibido: 1
# Longitud final de path_batch: 1
# Forma final de y_batch: (30, 2)
# 14/36 [==========>...................] - ETA: 2:48 - loss: 22.5766 - Accuracy: 0.4905subbatch_index: 0
#  batch_index calculado: 0
# DEBUG tamaño total de self.df: 18
# Tamaño de batches recibido: 1
# Longitud final de path_batch: 1
# Forma final de y_batch: (30, 2)
# 15/36 [===========>..................] - ETA: 2:38 - loss: 22.5706 - Accuracy: 0.5022subbatch_index: 8
#  batch_index calculado: 4
# DEBUG tamaño total de self.df: 18
# Tamaño de batches recibido: 1
# Longitud final de path_batch: 1
# Forma final de y_batch: (30, 2)
# 16/36 [============>.................] - ETA: 2:30 - loss: 22.5653 - Accuracy: 0.5000subbatch_index: 29
#  batch_index calculado: 14
# DEBUG tamaño total de self.df: 18
# Tamaño de batches recibido: 1
# Longitud final de path_batch: 1
# Forma final de y_batch: (30, 2)
# 17/36 [=============>................] - ETA: 2:21 - loss: 22.5603 - Accuracy: 0.4863subbatch_index: 27
#  batch_index calculado: 13
# DEBUG tamaño total de self.df: 18
# Tamaño de batches recibido: 1
# Longitud final de path_batch: 1
# Forma final de y_batch: (30, 2)
# 18/36 [==============>...............] - ETA: 2:13 - loss: 22.5551 - Accuracy: 0.4815subbatch_index: 32
#  batch_index calculado: 16
# DEBUG tamaño total de self.df: 18
# Tamaño de batches recibido: 1
# Longitud final de path_batch: 1
# Forma final de y_batch: (30, 2)
# 19/36 [==============>...............] - ETA: 2:05 - loss: 22.5498 - Accuracy: 0.4772subbatch_index: 21
#  batch_index calculado: 10
# DEBUG tamaño total de self.df: 18
# Tamaño de batches recibido: 1
# Longitud final de path_batch: 1
# Forma final de y_batch: (30, 2)
# 20/36 [===============>..............] - ETA: 1:58 - loss: 22.5445 - Accuracy: 0.4700subbatch_index: 33
#  batch_index calculado: 16
# DEBUG tamaño total de self.df: 18
# Tamaño de batches recibido: 1
# Longitud final de path_batch: 1
# Forma final de y_batch: (30, 2)
# 21/36 [================>.............] - ETA: 1:50 - loss: 22.5393 - Accuracy: 0.4698subbatch_index: 1
#  batch_index calculado: 0
# DEBUG tamaño total de self.df: 18
# Tamaño de batches recibido: 1
# Longitud final de path_batch: 1
# Forma final de y_batch: (30, 2)
# 22/36 [=================>............] - ETA: 1:42 - loss: 22.5339 - Accuracy: 0.4697subbatch_index: 12
#  batch_index calculado: 6
# DEBUG tamaño total de self.df: 18
# Tamaño de batches recibido: 1
# Longitud final de path_batch: 1
# Forma final de y_batch: (30, 2)
# 23/36 [==================>...........] - ETA: 1:34 - loss: 22.5286 - Accuracy: 0.4638subbatch_index: 11
#  batch_index calculado: 5
# DEBUG tamaño total de self.df: 18
# Tamaño de batches recibido: 1
# Longitud final de path_batch: 1
# Forma final de y_batch: (30, 2)
# 24/36 [===================>..........] - ETA: 1:28 - loss: 22.5232 - Accuracy: 0.4583subbatch_index: 5
#  batch_index calculado: 2
# DEBUG tamaño total de self.df: 18
# Tamaño de batches recibido: 1
# Longitud final de path_batch: 1
# Forma final de y_batch: (30, 2)
# 25/36 [===================>..........] - ETA: 1:20 - loss: 22.5177 - Accuracy: 0.4693subbatch_index: 20
#  batch_index calculado: 10
# DEBUG tamaño total de self.df: 18
# Tamaño de batches recibido: 1
# Longitud final de path_batch: 1
# Forma final de y_batch: (30, 2)
# 26/36 [====================>.........] - ETA: 1:13 - loss: 22.5123 - Accuracy: 0.4615subbatch_index: 26
#  batch_index calculado: 13
# DEBUG tamaño total de self.df: 18
# Tamaño de batches recibido: 1
# Longitud final de path_batch: 1
# Forma final de y_batch: (30, 2)
# 27/36 [=====================>........] - ETA: 1:05 - loss: 22.5069 - Accuracy: 0.4617subbatch_index: 2
#  batch_index calculado: 1
# DEBUG tamaño total de self.df: 18
# Tamaño de batches recibido: 1
# Longitud final de path_batch: 1
# Forma final de y_batch: (30, 2)
# 28/36 [======================>.......] - ETA: 58s - loss: 22.5015 - Accuracy: 0.4571 subbatch_index: 25
#  batch_index calculado: 12
# DEBUG tamaño total de self.df: 18
# Tamaño de batches recibido: 1
# Longitud final de path_batch: 1
# Forma final de y_batch: (30, 2)
# 29/36 [=======================>......] - ETA: 50s - loss: 22.4957 - Accuracy: 0.4644subbatch_index: 28
#  batch_index calculado: 14
# DEBUG tamaño total de self.df: 18
# Tamaño de batches recibido: 1
# Longitud final de path_batch: 1
# Forma final de y_batch: (30, 2)
# 30/36 [========================>.....] - ETA: 43s - loss: 22.4902 - Accuracy: 0.4689subbatch_index: 24
#  batch_index calculado: 12
# DEBUG tamaño total de self.df: 18
# Tamaño de batches recibido: 1
# Longitud final de path_batch: 1
# Forma final de y_batch: (30, 2)
# 31/36 [========================>.....] - ETA: 36s - loss: 22.4847 - Accuracy: 0.4710subbatch_index: 19
#  batch_index calculado: 9
# DEBUG tamaño total de self.df: 18
# Tamaño de batches recibido: 1
# Longitud final de path_batch: 1
# Forma final de y_batch: (30, 2)
# 32/36 [=========================>....] - ETA: 28s - loss: 22.4793 - Accuracy: 0.4750subbatch_index: 22
#  batch_index calculado: 11
# DEBUG tamaño total de self.df: 18
# Tamaño de batches recibido: 1
# Longitud final de path_batch: 1
# Forma final de y_batch: (30, 2)
# 33/36 [==========================>...] - ETA: 21s - loss: 22.4738 - Accuracy: 0.4747subbatch_index: 34
#  batch_index calculado: 17
# DEBUG tamaño total de self.df: 18
# Tamaño de batches recibido: 1
# Longitud final de path_batch: 1
# Forma final de y_batch: (30, 2)
# 34/36 [===========================>..] - ETA: 14s - loss: 22.4683 - Accuracy: 0.4765subbatch_index: 17
#  batch_index calculado: 8
# DEBUG tamaño total de self.df: 18
# Tamaño de batches recibido: 1
# Longitud final de path_batch: 1
# Forma final de y_batch: (30, 2)
# 36/36 [==============================] - ETA: 0s - loss: 22.4576 - Accuracy: 0.4722subbatch_index: 0
#  batch_index calculado: 0
# DEBUG tamaño total de self.df: 6
# Tamaño de batches recibido: 6
# Longitud final de path_batch: 6
# Forma final de y_batch: (3420, 2)
# subbatch_index: 0
#  batch_index calculado: 0
# subbatch_index: 1
#  batch_index calculado: 0
# subbatch_index: 2
#  batch_index calculado: 0
# subbatch_index: 3
#  batch_index calculado: 0
# subbatch_index: 4
#  batch_index calculado: 0
# subbatch_index: 5
#  batch_index calculado: 0
# subbatch_index: 6
#  batch_index calculado: 0
# subbatch_index: 7
#  batch_index calculado: 0
# subbatch_index: 8
#  batch_index calculado: 0
# subbatch_index: 9
#  batch_index calculado: 0
# subbatch_index: 10
#  batch_index calculado: 0
# subbatch_index: 11
#  batch_index calculado: 0
# subbatch_index: 12
#  batch_index calculado: 0
# subbatch_index: 13
#  batch_index calculado: 0
# subbatch_index: 14
#  batch_index calculado: 0
# subbatch_index: 15
#  batch_index calculado: 0
# subbatch_index: 16
#  batch_index calculado: 0
# subbatch_index: 17
#  batch_index calculado: 0
# subbatch_index: 18
#  batch_index calculado: 0
# subbatch_index: 19
#  batch_index calculado: 0
# subbatch_index: 20
#  batch_index calculado: 0
# subbatch_index: 21
#  batch_index calculado: 0
# subbatch_index: 22
#  batch_index calculado: 0
# subbatch_index: 23
#  batch_index calculado: 0
# subbatch_index: 24
#  batch_index calculado: 0
# subbatch_index: 25
#  batch_index calculado: 0
# subbatch_index: 26
#  batch_index calculado: 0
# subbatch_index: 27
#  batch_index calculado: 0
# subbatch_index: 28
#  batch_index calculado: 0
# subbatch_index: 29
#  batch_index calculado: 0
# subbatch_index: 30
#  batch_index calculado: 0
# subbatch_index: 31
#  batch_index calculado: 0
# subbatch_index: 32
#  batch_index calculado: 0
# subbatch_index: 33
#  batch_index calculado: 0
# subbatch_index: 34
#  batch_index calculado: 0
# subbatch_index: 35
#  batch_index calculado: 0
# subbatch_index: 36
#  batch_index calculado: 0
# subbatch_index: 37
#  batch_index calculado: 0
# subbatch_index: 38
#  batch_index calculado: 0
# subbatch_index: 39
#  batch_index calculado: 0
# subbatch_index: 40
#  batch_index calculado: 0
# subbatch_index: 41
#  batch_index calculado: 0
# subbatch_index: 42
#  batch_index calculado: 0
# subbatch_index: 43
#  batch_index calculado: 0
# subbatch_index: 44
#  batch_index calculado: 0
# subbatch_index: 45
#  batch_index calculado: 0
# subbatch_index: 46
#  batch_index calculado: 0
# subbatch_index: 47
#  batch_index calculado: 0
# subbatch_index: 48
#  batch_index calculado: 0
# subbatch_index: 49
#  batch_index calculado: 0
# subbatch_index: 50
#  batch_index calculado: 0
# subbatch_index: 51
#  batch_index calculado: 0
# subbatch_index: 52
#  batch_index calculado: 0
# subbatch_index: 53
#  batch_index calculado: 0
# subbatch_index: 54
#  batch_index calculado: 0
# subbatch_index: 55
#  batch_index calculado: 0
# subbatch_index: 56
#  batch_index calculado: 0
# subbatch_index: 57
#  batch_index calculado: 0
# subbatch_index: 58
#  batch_index calculado: 0
# subbatch_index: 59
#  batch_index calculado: 0
# subbatch_index: 60
#  batch_index calculado: 0
# subbatch_index: 61
#  batch_index calculado: 0
# subbatch_index: 62
#  batch_index calculado: 0
# subbatch_index: 63
#  batch_index calculado: 0
# subbatch_index: 64
#  batch_index calculado: 0
# subbatch_index: 65
#  batch_index calculado: 0
# subbatch_index: 66
#  batch_index calculado: 0
# subbatch_index: 67
#  batch_index calculado: 0
# subbatch_index: 68
#  batch_index calculado: 0
# subbatch_index: 69
#  batch_index calculado: 0
# subbatch_index: 70
#  batch_index calculado: 0
# subbatch_index: 71
#  batch_index calculado: 0
# subbatch_index: 72
#  batch_index calculado: 0
# subbatch_index: 73
#  batch_index calculado: 0
# subbatch_index: 74
#  batch_index calculado: 0
# subbatch_index: 75
#  batch_index calculado: 0
# subbatch_index: 76
#  batch_index calculado: 0
# subbatch_index: 77
#  batch_index calculado: 0
# subbatch_index: 78
#  batch_index calculado: 0
# subbatch_index: 79
#  batch_index calculado: 0
# subbatch_index: 80
#  batch_index calculado: 0
# subbatch_index: 81
#  batch_index calculado: 0
# subbatch_index: 82
#  batch_index calculado: 0
# subbatch_index: 83
#  batch_index calculado: 0
# subbatch_index: 84
#  batch_index calculado: 0
# subbatch_index: 85
#  batch_index calculado: 0
# subbatch_index: 86
#  batch_index calculado: 0
# subbatch_index: 87
#  batch_index calculado: 0
# subbatch_index: 88
#  batch_index calculado: 0
# subbatch_index: 89
#  batch_index calculado: 0
# subbatch_index: 90
#  batch_index calculado: 0
# subbatch_index: 91
#  batch_index calculado: 0
# subbatch_index: 92
#  batch_index calculado: 0
# subbatch_index: 93
#  batch_index calculado: 0
# subbatch_index: 94
#  batch_index calculado: 0
# subbatch_index: 95
#  batch_index calculado: 0
# subbatch_index: 96
#  batch_index calculado: 0
# subbatch_index: 97
#  batch_index calculado: 0
# subbatch_index: 98
#  batch_index calculado: 0
# subbatch_index: 99
#  batch_index calculado: 0
# subbatch_index: 100
#  batch_index calculado: 0
# subbatch_index: 101
#  batch_index calculado: 0
# subbatch_index: 102
#  batch_index calculado: 0
# subbatch_index: 103
#  batch_index calculado: 0
# subbatch_index: 104
#  batch_index calculado: 0
# subbatch_index: 105
#  batch_index calculado: 0
# subbatch_index: 106
#  batch_index calculado: 0
# subbatch_index: 107
#  batch_index calculado: 0
# subbatch_index: 108
#  batch_index calculado: 0
# subbatch_index: 109
#  batch_index calculado: 0
# subbatch_index: 110
#  batch_index calculado: 0
# subbatch_index: 111
#  batch_index calculado: 0
# subbatch_index: 112
#  batch_index calculado: 0
# subbatch_index: 113
#  batch_index calculado: 0
# subbatch_index: 114
#  batch_index calculado: 0
# subbatch_index: 115
#  batch_index calculado: 0
# subbatch_index: 116
#  batch_index calculado: 0
# subbatch_index: 117
#  batch_index calculado: 0
# subbatch_index: 118
#  batch_index calculado: 0
# subbatch_index: 119
#  batch_index calculado: 0
# subbatch_index: 120
#  batch_index calculado: 0
# subbatch_index: 121
#  batch_index calculado: 0
# subbatch_index: 122
#  batch_index calculado: 0
# subbatch_index: 123
#  batch_index calculado: 0
# subbatch_index: 124
#  batch_index calculado: 0
# subbatch_index: 125
#  batch_index calculado: 0
# subbatch_index: 126
#  batch_index calculado: 0
# subbatch_index: 127
#  batch_index calculado: 0
# subbatch_index: 128
#  batch_index calculado: 0
# subbatch_index: 129
#  batch_index calculado: 0
# subbatch_index: 130
#  batch_index calculado: 0
# subbatch_index: 131
#  batch_index calculado: 0
# subbatch_index: 132
#  batch_index calculado: 0
# subbatch_index: 133
#  batch_index calculado: 0
# subbatch_index: 134
#  batch_index calculado: 0
# subbatch_index: 135
#  batch_index calculado: 0
# subbatch_index: 136
#  batch_index calculado: 0
# subbatch_index: 137
#  batch_index calculado: 0
# subbatch_index: 138
#  batch_index calculado: 0
# subbatch_index: 139
#  batch_index calculado: 0
# subbatch_index: 140
#  batch_index calculado: 0
# subbatch_index: 141
#  batch_index calculado: 0
# subbatch_index: 142
#  batch_index calculado: 0
# subbatch_index: 143
#  batch_index calculado: 0
# subbatch_index: 144
#  batch_index calculado: 0
# subbatch_index: 145
#  batch_index calculado: 0
# subbatch_index: 146
#  batch_index calculado: 0
# subbatch_index: 147
#  batch_index calculado: 0
# subbatch_index: 148
#  batch_index calculado: 0
# subbatch_index: 149
#  batch_index calculado: 0
# subbatch_index: 150
#  batch_index calculado: 0
# subbatch_index: 151
#  batch_index calculado: 0
# subbatch_index: 152
#  batch_index calculado: 0
# subbatch_index: 153
#  batch_index calculado: 0
# subbatch_index: 154
#  batch_index calculado: 0
# subbatch_index: 155
#  batch_index calculado: 0
# subbatch_index: 156
#  batch_index calculado: 0
# subbatch_index: 157
#  batch_index calculado: 0
# subbatch_index: 158
#  batch_index calculado: 0
# subbatch_index: 159
#  batch_index calculado: 0
# subbatch_index: 160
#  batch_index calculado: 0
# subbatch_index: 161
#  batch_index calculado: 0
# subbatch_index: 162
#  batch_index calculado: 0
# subbatch_index: 163
#  batch_index calculado: 0
# subbatch_index: 164
#  batch_index calculado: 0
# subbatch_index: 165
#  batch_index calculado: 0
# subbatch_index: 166
#  batch_index calculado: 0
# subbatch_index: 167
#  batch_index calculado: 0
# subbatch_index: 168
#  batch_index calculado: 0
# subbatch_index: 169
#  batch_index calculado: 0
# subbatch_index: 170
#  batch_index calculado: 0
# subbatch_index: 171
#  batch_index calculado: 0
# subbatch_index: 172
#  batch_index calculado: 0
# subbatch_index: 173
#  batch_index calculado: 0
# subbatch_index: 174
#  batch_index calculado: 0
# subbatch_index: 175
#  batch_index calculado: 0
# subbatch_index: 176
#  batch_index calculado: 0
# subbatch_index: 177
#  batch_index calculado: 0
# subbatch_index: 178
#  batch_index calculado: 0
# subbatch_index: 179
#  batch_index calculado: 0
# subbatch_index: 180
#  batch_index calculado: 0
# subbatch_index: 181
#  batch_index calculado: 0
# subbatch_index: 182
#  batch_index calculado: 0
# subbatch_index: 183
#  batch_index calculado: 0
# subbatch_index: 184
#  batch_index calculado: 0
# subbatch_index: 185
#  batch_index calculado: 0
# subbatch_index: 186
#  batch_index calculado: 0
# subbatch_index: 187
#  batch_index calculado: 0
# subbatch_index: 188
#  batch_index calculado: 0
# subbatch_index: 189
#  batch_index calculado: 0
# subbatch_index: 190
#  batch_index calculado: 0
# subbatch_index: 191
#  batch_index calculado: 0
# subbatch_index: 192
#  batch_index calculado: 0
# subbatch_index: 193
#  batch_index calculado: 0
# subbatch_index: 194
#  batch_index calculado: 0
# subbatch_index: 195
#  batch_index calculado: 0
# subbatch_index: 196
#  batch_index calculado: 0
# subbatch_index: 197
#  batch_index calculado: 0
# subbatch_index: 198
#  batch_index calculado: 0
# subbatch_index: 199
#  batch_index calculado: 0
# subbatch_index: 200
#  batch_index calculado: 0
# subbatch_index: 201
#  batch_index calculado: 0
# subbatch_index: 202
#  batch_index calculado: 0
# subbatch_index: 203
#  batch_index calculado: 0
# subbatch_index: 204
#  batch_index calculado: 0
# subbatch_index: 205
#  batch_index calculado: 0
# subbatch_index: 206
#  batch_index calculado: 0
# subbatch_index: 207
#  batch_index calculado: 0
# subbatch_index: 208
#  batch_index calculado: 0
# subbatch_index: 209
#  batch_index calculado: 0
# subbatch_index: 210
#  batch_index calculado: 0
# subbatch_index: 211
#  batch_index calculado: 0
# subbatch_index: 212
#  batch_index calculado: 0
# subbatch_index: 213
#  batch_index calculado: 0
# subbatch_index: 214
#  batch_index calculado: 0
# subbatch_index: 215
#  batch_index calculado: 0
# subbatch_index: 216
#  batch_index calculado: 0
# subbatch_index: 217
#  batch_index calculado: 0
# subbatch_index: 218
#  batch_index calculado: 0
# subbatch_index: 219
#  batch_index calculado: 0
# subbatch_index: 220
#  batch_index calculado: 0
# subbatch_index: 221
#  batch_index calculado: 0
# subbatch_index: 222
#  batch_index calculado: 0
# subbatch_index: 223
#  batch_index calculado: 0
# subbatch_index: 224
#  batch_index calculado: 0
# subbatch_index: 225
#  batch_index calculado: 0
# subbatch_index: 226
#  batch_index calculado: 0
# subbatch_index: 227
#  batch_index calculado: 0
# 36/36 [==============================] - 680s 19s/step - loss: 22.4576 - Accuracy: 0.4722 - val_loss: 22.3774 - val_Accuracy: 0.6667
# Duration (CNN): 0:11:26.283858
# subbatch_index: 0
#  batch_index calculado: 0
# DEBUG tamaño total de self.df: 9
# Tamaño de batches recibido: 1
# Longitud final de path_batch: 1
# Forma final de y_batch: (30, 2)
# subbatch_index: 1
#  batch_index calculado: 0
# DEBUG tamaño total de self.df: 9
# Tamaño de batches recibido: 1
# Longitud final de path_batch: 1
# Forma final de y_batch: (30, 2)
# subbatch_index: 2
#  batch_index calculado: 1
# DEBUG tamaño total de self.df: 9
# Tamaño de batches recibido: 1
# Longitud final de path_batch: 1
# Forma final de y_batch: (30, 2)
# subbatch_index: 3
#  batch_index calculado: 1
# DEBUG tamaño total de self.df: 9
# Tamaño de batches recibido: 1
# Longitud final de path_batch: 1
# Forma final de y_batch: (30, 2)
# subbatch_index: 4
#  batch_index calculado: 2
# DEBUG tamaño total de self.df: 9
# Tamaño de batches recibido: 1
# Longitud final de path_batch: 1
# Forma final de y_batch: (30, 2)
# subbatch_index: 5
#  batch_index calculado: 2
# DEBUG tamaño total de self.df: 9
# Tamaño de batches recibido: 1
# Longitud final de path_batch: 1
# Forma final de y_batch: (30, 2)
# subbatch_index: 6
#  batch_index calculado: 3
# DEBUG tamaño total de self.df: 9
# Tamaño de batches recibido: 1
# Longitud final de path_batch: 1
# Forma final de y_batch: (30, 2)
# subbatch_index: 7
#  batch_index calculado: 3
# DEBUG tamaño total de self.df: 9
# Tamaño de batches recibido: 1
# Longitud final de path_batch: 1
# Forma final de y_batch: (30, 2)
# subbatch_index: 8
#  batch_index calculado: 4
# DEBUG tamaño total de self.df: 9
# Tamaño de batches recibido: 1
# Longitud final de path_batch: 1
# Forma final de y_batch: (30, 2)
# subbatch_index: 9
#  batch_index calculado: 4
# DEBUG tamaño total de self.df: 9
# Tamaño de batches recibido: 1
# Longitud final de path_batch: 1
# Forma final de y_batch: (30, 2)
# subbatch_index: 10
#  batch_index calculado: 5
# DEBUG tamaño total de self.df: 9
# Tamaño de batches recibido: 1
# Longitud final de path_batch: 1
# Forma final de y_batch: (30, 2)
# subbatch_index: 11
#  batch_index calculado: 5
# DEBUG tamaño total de self.df: 9
# Tamaño de batches recibido: 1
# Longitud final de path_batch: 1
# Forma final de y_batch: (30, 2)
# subbatch_index: 12
#  batch_index calculado: 6
# DEBUG tamaño total de self.df: 9
# Tamaño de batches recibido: 1
# Longitud final de path_batch: 1
# Forma final de y_batch: (30, 2)
# subbatch_index: 13
#  batch_index calculado: 6
# DEBUG tamaño total de self.df: 9
# Tamaño de batches recibido: 1
# Longitud final de path_batch: 1
# Forma final de y_batch: (30, 2)
# subbatch_index: 14
#  batch_index calculado: 7
# DEBUG tamaño total de self.df: 9
# Tamaño de batches recibido: 1
# Longitud final de path_batch: 1
# Forma final de y_batch: (30, 2)
# subbatch_index: 15
#  batch_index calculado: 7
# DEBUG tamaño total de self.df: 9
# Tamaño de batches recibido: 1
# Longitud final de path_batch: 1
# Forma final de y_batch: (30, 2)
# subbatch_index: 16
#  batch_index calculado: 8
# DEBUG tamaño total de self.df: 9
# Tamaño de batches recibido: 1
# Longitud final de path_batch: 1
# Forma final de y_batch: (30, 2)
# subbatch_index: 17
#  batch_index calculado: 8
# DEBUG tamaño total de self.df: 9
# Tamaño de batches recibido: 1
# Longitud final de path_batch: 1
# Forma final de y_batch: (30, 2)
# predicts CNN
# subbatch_index: 0
#  batch_index calculado: 0
# DEBUG tamaño total de self.df: 9
# Tamaño de batches recibido: 1
# Longitud final de path_batch: 1
# Forma final de y_batch: (30, 2)
# subbatch_index: 0
#  batch_index calculado: 0
# DEBUG tamaño total de self.df: 9
# Tamaño de batches recibido: 1
# Longitud final de path_batch: 1
# Forma final de y_batch: (30, 2)
# subbatch_index: 1
#  batch_index calculado: 0
# DEBUG tamaño total de self.df: 9
# Tamaño de batches recibido: 1
# Longitud final de path_batch: 1
# Forma final de y_batch: (30, 2)
#  1/18 [>.............................] - ETA: 1:31subbatch_index: 2
#  batch_index calculado: 1
# DEBUG tamaño total de self.df: 9
# Tamaño de batches recibido: 1
# Longitud final de path_batch: 1
# Forma final de y_batch: (30, 2)
#  2/18 [==>...........................] - ETA: 1:40subbatch_index: 3
#  batch_index calculado: 1
# DEBUG tamaño total de self.df: 9
# Tamaño de batches recibido: 1
#  3/18 [====>.........................] - ETA: 1:27 1
# Forma final de y_batch: (30, 2)
# subbatch_index: 4
#  batch_index calculado: 2
#  4/18 [=====>........................] - ETA: 1:19
# Tamaño de batches recibido: 1
# Longitud final de path_batch: 1
# Forma final de y_batch: (30, 2)
# subbatch_index: 5
#  batch_index calculado: 2
# DEBUG tamaño total de self.df: 9
# Tamaño de batches recibido: 1
# Longitud final de path_batch: 1
#  5/18 [=======>......................] - ETA: 1:11(30, 2)
# subbatch_index: 6
#  batch_index calculado: 3
# DEBUG tamaño total de self.df: 9
# Tamaño de batches recibido: 1
#  6/18 [=========>....................] - ETA: 1:041
# Forma final de y_batch: (30, 2)
# subbatch_index: 7
#  batch_index calculado: 3
# DEBUG tamaño total de self.df: 9
# Tamaño de batches recibido: 1
#  7/18 [==========>...................] - ETA: 58s
# Forma final de y_batch: (30, 2)
# subbatch_index: 8
#  batch_index calculado: 4
# DEBUG tamaño total de self.df: 9
#  8/18 [============>.................] - ETA: 53s
# Longitud final de path_batch: 1
# Forma final de y_batch: (30, 2)
# subbatch_index: 9
#  batch_index calculado: 4
#  9/18 [==============>...............] - ETA: 47s 9
# Tamaño de batches recibido: 1
# Longitud final de path_batch: 1
# Forma final de y_batch: (30, 2)
# subbatch_index: 10
#  batch_index calculado: 5
# 10/18 [===============>..............] - ETA: 42s 9
# Tamaño de batches recibido: 1
# Longitud final de path_batch: 1
# Forma final de y_batch: (30, 2)
# subbatch_index: 11
#  batch_index calculado: 5
# DEBUG tamaño total de self.df: 9
# 11/18 [=================>............] - ETA: 36s
# Longitud final de path_batch: 1
# Forma final de y_batch: (30, 2)
# subbatch_index: 12
#  batch_index calculado: 6
# 12/18 [===================>..........] - ETA: 31s
# Tamaño de batches recibido: 1
# Longitud final de path_batch: 1
# Forma final de y_batch: (30, 2)
# subbatch_index: 13
#  batch_index calculado: 6
# 13/18 [====================>.........] - ETA: 26s 9
# Tamaño de batches recibido: 1
# Longitud final de path_batch: 1
# Forma final de y_batch: (30, 2)
# subbatch_index: 14
#  batch_index calculado: 7
# 14/18 [======================>.......] - ETA: 20s
# Tamaño de batches recibido: 1
# Longitud final de path_batch: 1
# Forma final de y_batch: (30, 2)
# subbatch_index: 15
#  batch_index calculado: 7
# DEBUG tamaño total de self.df: 9
# Tamaño de batches recibido: 1
# Longitud final de path_batch: 1
# 15/18 [========================>.....] - ETA: 15s(30, 2)
# subbatch_index: 16
#  batch_index calculado: 8
# 16/18 [=========================>....] - ETA: 10s9
# Tamaño de batches recibido: 1
# Longitud final de path_batch: 1
# Forma final de y_batch: (30, 2)
# subbatch_index: 17
#  batch_index calculado: 8
# 17/18 [===========================>..] - ETA: 5s DEBUG tamaño total de self.df: 9
# Tamaño de batches recibido: 1
# Longitud final de path_batch: 1
# Forma final de y_batch: (30, 2)
# 18/18 [==============================] - 93s 5s/step
# mislabeled subjects:
#  Counter({'R:/preprocess_batch-002/commonspace_bold/_scan_info_subject_id081.session01_split_name_sub-081_ses-01_desc-o_T2w/_run_None/sub-081_ses-01_task-dist_desc-oa_bold_autobox_combined.nii.gz': 30, 'R:/preprocess_batch-002/commonspace_bold/_scan_info_subject_id077.session01_split_name_sub-077_ses-01_desc-o_T2w/_run_None/sub-077_ses-01_task-dist_desc-oa_bold_autobox_combined.nii.gz': 30, 'R:/preprocess_batch-001/commonspace_bold/_scan_info_subject_id052.session01_split_name_sub-052_ses-01_desc-o_T2w/_run_None/sub-052_ses-01_task-dist_desc-oa_bold_autobox_combined.nii.gz': 30})
# evaluating CNN
# subbatch_index: 0
#  batch_index calculado: 0
# DEBUG tamaño total de self.df: 9
# Tamaño de batches recibido: 1
# Longitud final de path_batch: 1
# Forma final de y_batch: (30, 2)
# subbatch_index: 0
#  batch_index calculado: 0
# DEBUG tamaño total de self.df: 9
# Tamaño de batches recibido: 1
# Longitud final de path_batch: 1
# Forma final de y_batch: (30, 2)
# subbatch_index: 1
#  batch_index calculado: 0
# DEBUG tamaño total de self.df: 9
# Tamaño de batches recibido: 1
# Longitud final de path_batch: 1
# Forma final de y_batch: (30, 2)
#  1/18 [>.............................] - ETA: 1:59 - loss: 24.6115 - Accuracy: 0.0000e+00subbatch_index: 2
#  batch_index calculado: 1
# DEBUG tamaño total de self.df: 9
# Tamaño de batches recibido: 1
# Longitud final de path_batch: 1
# Forma final de y_batch: (30, 2)
#  2/18 [==>...........................] - ETA: 1:22 - loss: 24.6030 - Accuracy: 0.0000e+00subbatch_index: 3
#  batch_index calculado: 1
# DEBUG tamaño total de self.df: 9
# Tamaño de batches recibido: 1
# Longitud final de path_batch: 1
# Forma final de y_batch: (30, 2)
#  3/18 [====>.........................] - ETA: 1:19 - loss: 23.9663 - Accuracy: 0.0000e+00subbatch_index: 4
#  batch_index calculado: 2
# DEBUG tamaño total de self.df: 9
# Tamaño de batches recibido: 1
# Longitud final de path_batch: 1
# Forma final de y_batch: (30, 2)
#  4/18 [=====>........................] - ETA: 1:15 - loss: 23.6944 - Accuracy: 0.0000e+00subbatch_index: 5
#  batch_index calculado: 2
# DEBUG tamaño total de self.df: 9
# Tamaño de batches recibido: 1
# Longitud final de path_batch: 1
# Forma final de y_batch: (30, 2)
#  5/18 [=======>......................] - ETA: 1:10 - loss: 23.8000 - Accuracy: 0.0000e+00subbatch_index: 6
#  batch_index calculado: 3
# DEBUG tamaño total de self.df: 9
# Tamaño de batches recibido: 1
# Longitud final de path_batch: 1
# Forma final de y_batch: (30, 2)
#  6/18 [=========>....................] - ETA: 1:04 - loss: 23.8517 - Accuracy: 0.0000e+00subbatch_index: 7
#  batch_index calculado: 3
# DEBUG tamaño total de self.df: 9
# Tamaño de batches recibido: 1
# Longitud final de path_batch: 1
# Forma final de y_batch: (30, 2)
#  7/18 [==========>...................] - ETA: 1:01 - loss: 23.5447 - Accuracy: 0.1429    subbatch_index: 8
#  batch_index calculado: 4
# DEBUG tamaño total de self.df: 9
# Tamaño de batches recibido: 1
# Longitud final de path_batch: 1
# Forma final de y_batch: (30, 2)
#  8/18 [============>.................] - ETA: 57s - loss: 23.3135 - Accuracy: 0.2500 subbatch_index: 9
#  batch_index calculado: 4
# DEBUG tamaño total de self.df: 9
# Tamaño de batches recibido: 1
# Longitud final de path_batch: 1
# Forma final de y_batch: (30, 2)
#  9/18 [==============>...............] - ETA: 51s - loss: 23.1245 - Accuracy: 0.3333subbatch_index: 10
#  batch_index calculado: 5
# DEBUG tamaño total de self.df: 9
# Tamaño de batches recibido: 1
# Longitud final de path_batch: 1
# Forma final de y_batch: (30, 2)
# 10/18 [===============>..............] - ETA: 45s - loss: 22.9732 - Accuracy: 0.4000subbatch_index: 11
#  batch_index calculado: 5
# DEBUG tamaño total de self.df: 9
# Tamaño de batches recibido: 1
# Longitud final de path_batch: 1
# Forma final de y_batch: (30, 2)
# 11/18 [=================>............] - ETA: 40s - loss: 22.8589 - Accuracy: 0.4545subbatch_index: 12
#  batch_index calculado: 6
# DEBUG tamaño total de self.df: 9
# Tamaño de batches recibido: 1
# Longitud final de path_batch: 1
# Forma final de y_batch: (30, 2)
# 12/18 [===================>..........] - ETA: 34s - loss: 22.7636 - Accuracy: 0.5000subbatch_index: 13
#  batch_index calculado: 6
# DEBUG tamaño total de self.df: 9
# Tamaño de batches recibido: 1
# Longitud final de path_batch: 1
# Forma final de y_batch: (30, 2)
# 13/18 [====================>.........] - ETA: 28s - loss: 22.6762 - Accuracy: 0.5385subbatch_index: 14
#  batch_index calculado: 7
# DEBUG tamaño total de self.df: 9
# Tamaño de batches recibido: 1
# Longitud final de path_batch: 1
# Forma final de y_batch: (30, 2)
# 14/18 [======================>.......] - ETA: 22s - loss: 22.6017 - Accuracy: 0.5714subbatch_index: 15
#  batch_index calculado: 7
# DEBUG tamaño total de self.df: 9
# Tamaño de batches recibido: 1
# Longitud final de path_batch: 1
# Forma final de y_batch: (30, 2)
# 15/18 [========================>.....] - ETA: 17s - loss: 22.5374 - Accuracy: 0.6000subbatch_index: 16
#  batch_index calculado: 8
# DEBUG tamaño total de self.df: 9
# Tamaño de batches recibido: 1
# Longitud final de path_batch: 1
# Forma final de y_batch: (30, 2)
# 16/18 [=========================>....] - ETA: 11s - loss: 22.4815 - Accuracy: 0.6250subbatch_index: 17
#  batch_index calculado: 8
# DEBUG tamaño total de self.df: 9
# Tamaño de batches recibido: 1
# Longitud final de path_batch: 1
# Forma final de y_batch: (30, 2)
# 18/18 [==============================] - 107s 6s/step - loss: 22.3853 - Accuracy: 0.6667
# GradCam All ConvLayers-female
# CM CNN
# Run # 2
# Finishing previous runs because reinit is set to 'default'.
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>Accuracy</td><td>▁</td></tr><tr><td>epoch</td><td>▁</td></tr><tr><td>loss</td><td>▁</td></tr><tr><td>test_acc</td><td>▁</td></tr><tr><td>val_Accuracy</td><td>▁</td></tr><tr><td>val_loss</td><td>▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>Accuracy</td><td>0.47222</td></tr><tr><td>best_epoch</td><td>0</td></tr><tr><td>best_val_loss</td><td>22.37743</td></tr><tr><td>epoch</td><td>0</td></tr><tr><td>loss</td><td>22.45761</td></tr><tr><td>test_acc</td><td>0.66667</td></tr><tr><td>time_running</td><td>0:11:26.283858</td></tr><tr><td>val_Accuracy</td><td>0.66667</td></tr><tr><td>val_loss</td><td>22.37743</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">jumping-leaf-2</strong> at: <a href='https://wandb.ai/mansoor35/CPHfemale_BLvsW1W7_100epochs/runs/rzbzqjk2' target="_blank">https://wandb.ai/mansoor35/CPHfemale_BLvsW1W7_100epochs/runs/rzbzqjk2</a><br> View project at: <a href='https://wandb.ai/mansoor35/CPHfemale_BLvsW1W7_100epochs' target="_blank">https://wandb.ai/mansoor35/CPHfemale_BLvsW1W7_100epochs</a><br>Synced 5 W&B file(s), 1 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>C:\Users\L03087~1\AppData\Local\Temp\wandb\run-20251205_235329-rzbzqjk2\logs</code>
# Tracking run with wandb version 0.22.0
# Run data is saved locally in <code>C:\Users\L03087~1\AppData\Local\Temp\wandb\run-20251206_001039-o8uxid3p</code>
# Syncing run <strong><a href='https://wandb.ai/mansoor35/CPHfemale_BLvsW1W7_100epochs/runs/o8uxid3p' target="_blank">helpful-sky-3</a></strong> to <a href='https://wandb.ai/mansoor35/CPHfemale_BLvsW1W7_100epochs' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/mansoor35/CPHfemale_BLvsW1W7_100epochs' target="_blank">https://wandb.ai/mansoor35/CPHfemale_BLvsW1W7_100epochs</a>
#  View run at <a href='https://wandb.ai/mansoor35/CPHfemale_BLvsW1W7_100epochs/runs/o8uxid3p' target="_blank">https://wandb.ai/mansoor35/CPHfemale_BLvsW1W7_100epochs/runs/o8uxid3p</a>
# holaaaa, se metio al mask and bold
# SE METIO AL DISTTTTTTTTTT
# SE METIO AL LOGIN
# sesions:  [1, 2, 3]
# SESION:  1
# Se metió al 68
# j:  51
# Se metió al 68
# j:  50
# ENTRO AL SEGUNDO SUB BATCH
# ENTRO AL SEGUNDO SUB BATCH
# Se metió al 68
# j:  65
# Se metió al 68
# j:  49
# SESION:  2
# Se metió al 68
# j:  51
# Se metió al 68
# j:  50
# ENTRO AL SEGUNDO SUB BATCH
# ENTRO AL SEGUNDO SUB BATCH
# Se metió al 68
# j:  65
# Se metió al 68
# j:  49
# SESION:  3
# Se metió al 68
# j:  51
# Se metió al 68
# j:  50
# ENTRO AL SEGUNDO SUB BATCH
# ENTRO AL SEGUNDO SUB BATCH
# Se metió al 68
# j:  65
# Se metió al 68
# j:  49
# X_train con exito
# holaaaa, se metio al mask and bold
# SE METIO AL DISTTTTTTTTTT
# SE METIO AL LOGIN
# sesions:  [1, 2, 3]
# SESION:  1
# ENTRO AL SEGUNDO SUB BATCH
# ENTRO AL SEGUNDO SUB BATCH
# Se metió al 68
# j:  52
# SESION:  2
# ENTRO AL SEGUNDO SUB BATCH
# ENTRO AL SEGUNDO SUB BATCH
# Se metió al 68
# j:  52
# SESION:  3
# ENTRO AL SEGUNDO SUB BATCH
# ENTRO AL SEGUNDO SUB BATCH
# Se metió al 68
# j:  52
# X_test con exito
# holaaaa, se metio al mask and bold
# SE METIO AL DISTTTTTTTTTT
# SE METIO AL LOGIN
# sesions:  [1, 2, 3]
# SESION:  1
# ENTRO AL SEGUNDO SUB BATCH
# ENTRO AL SEGUNDO SUB BATCH
# SESION:  2
# ENTRO AL SEGUNDO SUB BATCH
# ENTRO AL SEGUNDO SUB BATCH
# SESION:  3
# ENTRO AL SEGUNDO SUB BATCH
# ENTRO AL SEGUNDO SUB BATCH
# X_val con exito
# sub train:
# ['R:/preprocess_batch-001/commonspace_bold/_scan_info_subject_id051.session01_split_name_sub-051_ses-01_desc-o_T2w/_run_None/sub-051_ses-01_task-dist_desc-oa_bold_autobox_combined.nii.gz'
#  'R:/preprocess_batch-001/commonspace_bold/_scan_info_subject_id050.session01_split_name_sub-050_ses-01_desc-o_T2w/_run_None/sub-050_ses-01_task-dist_desc-oa_bold_autobox_combined.nii.gz'
#  'R:/preprocess_batch-002/commonspace_bold/_scan_info_subject_id083.session01_split_name_sub-083_ses-01_desc-o_T2w/_run_None/sub-083_ses-01_task-dist_desc-oa_bold_autobox_combined.nii.gz'
#  'R:/preprocess_batch-002/commonspace_bold/_scan_info_subject_id079.session01_split_name_sub-079_ses-01_desc-o_T2w/_run_None/sub-079_ses-01_task-dist_desc-oa_bold_autobox_combined.nii.gz'
#  'R:/preprocess_batch-001/commonspace_bold/_scan_info_subject_id065.session01_split_name_sub-065_ses-01_desc-o_T2w/_run_None/sub-065_ses-01_task-dist_desc-oa_bold_autobox_combined.nii.gz'
#  'R:/preprocess_batch-001/commonspace_bold/_scan_info_subject_id049.session01_split_name_sub-049_ses-01_desc-o_T2w/_run_None/sub-049_ses-01_task-dist_desc-oa_bold_autobox_combined.nii.gz'
#  'R:/preprocess_batch-001/commonspace_bold/_scan_info_subject_id051.session02_split_name_sub-051_ses-02_desc-o_T2w/_run_None/sub-051_ses-02_task-dist_desc-oa_bold_autobox_combined.nii.gz'
#  'R:/preprocess_batch-001/commonspace_bold/_scan_info_subject_id050.session02_split_name_sub-050_ses-02_desc-o_T2w/_run_None/sub-050_ses-02_task-dist_desc-oa_bold_autobox_combined.nii.gz'
#  'R:/preprocess_batch-002/commonspace_bold/_scan_info_subject_id083.session02_split_name_sub-083_ses-02_desc-o_T2w/_run_None/sub-083_ses-02_task-dist_desc-oa_bold_autobox_combined.nii.gz'
#  'R:/preprocess_batch-002/commonspace_bold/_scan_info_subject_id079.session02_split_name_sub-079_ses-02_desc-o_T2w/_run_None/sub-079_ses-02_task-dist_desc-oa_bold_autobox_combined.nii.gz'
#  'R:/preprocess_batch-001/commonspace_bold/_scan_info_subject_id065.session02_split_name_sub-065_ses-02_desc-o_T2w/_run_None/sub-065_ses-02_task-dist_desc-oa_bold_autobox_combined.nii.gz'
# ...
# subbatch_index: 197
#  batch_index calculado: 0
# subbatch_index: 198
#  batch_index calculado: 0
# subbatch_index: 199
#  batch_index calculado: 0
# subbatch_index: 200
#  batch_index calculado: 0
# subbatch_index: 201
#  batch_index calculado: 0
# subbatch_index: 202
#  batch_index calculado: 0
# subbatch_index: 203
#  batch_index calculado: 0
# subbatch_index: 204
#  batch_index calculado: 0
# subbatch_index: 205
#  batch_index calculado: 0
# subbatch_index: 206
#  batch_index calculado: 0
# subbatch_index: 207
#  batch_index calculado: 0
# subbatch_index: 208
#  batch_index calculado: 0
# subbatch_index: 209
#  batch_index calculado: 0
# subbatch_index: 210
#  batch_index calculado: 0
# subbatch_index: 211
#  batch_index calculado: 0
# subbatch_index: 212
#  batch_index calculado: 0
# subbatch_index: 213
#  batch_index calculado: 0
# subbatch_index: 214
#  batch_index calculado: 0
# subbatch_index: 215
#  batch_index calculado: 0
# subbatch_index: 216
#  batch_index calculado: 0
# subbatch_index: 217
#  batch_index calculado: 0
# subbatch_index: 218
#  batch_index calculado: 0
# subbatch_index: 219
#  batch_index calculado: 0
# subbatch_index: 220
#  batch_index calculado: 0
# subbatch_index: 221
#  batch_index calculado: 0
# subbatch_index: 222
#  batch_index calculado: 0
# subbatch_index: 223
#  batch_index calculado: 0
# subbatch_index: 224
#  batch_index calculado: 0
# subbatch_index: 225
#  batch_index calculado: 0
# subbatch_index: 226
#  batch_index calculado: 0
# subbatch_index: 227
#  batch_index calculado: 0
# 36/36 [==============================] - 669s 19s/step - loss: 22.4625 - Accuracy: 0.5019 - val_loss: 22.6580 - val_Accuracy: 0.6667
# Duration (CNN): 0:11:14.087661
# subbatch_index: 0
#  batch_index calculado: 0
# DEBUG tamaño total de self.df: 9
# Tamaño de batches recibido: 1
# Longitud final de path_batch: 1
# Forma final de y_batch: (30, 2)
# subbatch_index: 1
#  batch_index calculado: 0
# DEBUG tamaño total de self.df: 9
# Tamaño de batches recibido: 1
# Longitud final de path_batch: 1
# Forma final de y_batch: (30, 2)
# subbatch_index: 2
#  batch_index calculado: 1
# DEBUG tamaño total de self.df: 9
# Tamaño de batches recibido: 1
# Longitud final de path_batch: 1
# Forma final de y_batch: (30, 2)
# subbatch_index: 3
#  batch_index calculado: 1
# DEBUG tamaño total de self.df: 9
# Tamaño de batches recibido: 1
# Longitud final de path_batch: 1
# Forma final de y_batch: (30, 2)
# subbatch_index: 4
#  batch_index calculado: 2
# DEBUG tamaño total de self.df: 9
# Tamaño de batches recibido: 1
# Longitud final de path_batch: 1
# Forma final de y_batch: (30, 2)
# subbatch_index: 5
#  batch_index calculado: 2
# DEBUG tamaño total de self.df: 9
# Tamaño de batches recibido: 1
# Longitud final de path_batch: 1
# Forma final de y_batch: (30, 2)
# subbatch_index: 6
#  batch_index calculado: 3
# DEBUG tamaño total de self.df: 9
# Tamaño de batches recibido: 1
# Longitud final de path_batch: 1
# Forma final de y_batch: (30, 2)
# subbatch_index: 7
#  batch_index calculado: 3
# DEBUG tamaño total de self.df: 9
# Tamaño de batches recibido: 1
# Longitud final de path_batch: 1
# Forma final de y_batch: (30, 2)
# subbatch_index: 8
#  batch_index calculado: 4
# DEBUG tamaño total de self.df: 9
# Tamaño de batches recibido: 1
# Longitud final de path_batch: 1
# Forma final de y_batch: (30, 2)
# subbatch_index: 9
#  batch_index calculado: 4
# DEBUG tamaño total de self.df: 9
# Tamaño de batches recibido: 1
# Longitud final de path_batch: 1
# Forma final de y_batch: (30, 2)
# subbatch_index: 10
#  batch_index calculado: 5
# DEBUG tamaño total de self.df: 9
# Tamaño de batches recibido: 1
# Longitud final de path_batch: 1
# Forma final de y_batch: (30, 2)
# subbatch_index: 11
#  batch_index calculado: 5
# DEBUG tamaño total de self.df: 9
# Tamaño de batches recibido: 1
# Longitud final de path_batch: 1
# Forma final de y_batch: (30, 2)
# subbatch_index: 12
#  batch_index calculado: 6
# DEBUG tamaño total de self.df: 9
# Tamaño de batches recibido: 1
# Longitud final de path_batch: 1
# Forma final de y_batch: (30, 2)
# subbatch_index: 13
#  batch_index calculado: 6
# DEBUG tamaño total de self.df: 9
# Tamaño de batches recibido: 1
# Longitud final de path_batch: 1
# Forma final de y_batch: (30, 2)
# subbatch_index: 14
#  batch_index calculado: 7
# DEBUG tamaño total de self.df: 9
# Tamaño de batches recibido: 1
# Longitud final de path_batch: 1
# Forma final de y_batch: (30, 2)
# subbatch_index: 15
#  batch_index calculado: 7
# DEBUG tamaño total de self.df: 9
# Tamaño de batches recibido: 1
# Longitud final de path_batch: 1
# Forma final de y_batch: (30, 2)
# subbatch_index: 16
#  batch_index calculado: 8
# DEBUG tamaño total de self.df: 9
# Tamaño de batches recibido: 1
# Longitud final de path_batch: 1
# Forma final de y_batch: (30, 2)
# subbatch_index: 17
#  batch_index calculado: 8
# DEBUG tamaño total de self.df: 9
# Tamaño de batches recibido: 1
# Longitud final de path_batch: 1
# Forma final de y_batch: (30, 2)
# predicts CNN
# subbatch_index: 0
#  batch_index calculado: 0
# DEBUG tamaño total de self.df: 9
# Tamaño de batches recibido: 1
# Longitud final de path_batch: 1
# Forma final de y_batch: (30, 2)
# subbatch_index: 0
#  batch_index calculado: 0
# DEBUG tamaño total de self.df: 9
# Tamaño de batches recibido: 1
# Longitud final de path_batch: 1
# Forma final de y_batch: (30, 2)
# subbatch_index: 1
#  batch_index calculado: 0
# DEBUG tamaño total de self.df: 9
# Tamaño de batches recibido: 1
# Longitud final de path_batch: 1
# Forma final de y_batch: (30, 2)
#  1/18 [>.............................] - ETA: 1:35subbatch_index: 2
#  batch_index calculado: 1
# DEBUG tamaño total de self.df: 9
# Tamaño de batches recibido: 1
# Longitud final de path_batch: 1
# Forma final de y_batch: (30, 2)
#  2/18 [==>...........................] - ETA: 1:23subbatch_index: 3
#  batch_index calculado: 1
# DEBUG tamaño total de self.df: 9
# Tamaño de batches recibido: 1
#  3/18 [====>.........................] - ETA: 1:151
# Forma final de y_batch: (30, 2)
# subbatch_index: 4
#  batch_index calculado: 2
# DEBUG tamaño total de self.df: 9
# Tamaño de batches recibido: 1
#  4/18 [=====>........................] - ETA: 1:091
# Forma final de y_batch: (30, 2)
# subbatch_index: 5
#  batch_index calculado: 2
#  5/18 [=======>......................] - ETA: 1:03
# Tamaño de batches recibido: 1
# Longitud final de path_batch: 1
# Forma final de y_batch: (30, 2)
# subbatch_index: 6
#  batch_index calculado: 3
# DEBUG tamaño total de self.df: 9
# Tamaño de batches recibido: 1
# Longitud final de path_batch: 1
#  6/18 [=========>....................] - ETA: 59s Forma final de y_batch: (30, 2)
# subbatch_index: 7
#  batch_index calculado: 3
# DEBUG tamaño total de self.df: 9
# Tamaño de batches recibido: 1
#  7/18 [==========>...................] - ETA: 54s1
# Forma final de y_batch: (30, 2)
# subbatch_index: 8
#  batch_index calculado: 4
# DEBUG tamaño total de self.df: 9
# Tamaño de batches recibido: 1
#  8/18 [============>.................] - ETA: 49sLongitud final de path_batch: 1
# Forma final de y_batch: (30, 2)
# subbatch_index: 9
#  batch_index calculado: 4
# DEBUG tamaño total de self.df: 9
# Tamaño de batches recibido: 1
# Longitud final de path_batch: 1
#  9/18 [==============>...............] - ETA: 43sForma final de y_batch: (30, 2)
# subbatch_index: 10
#  batch_index calculado: 5
# DEBUG tamaño total de self.df: 9
# Tamaño de batches recibido: 1
# 10/18 [===============>..............] - ETA: 38sLongitud final de path_batch: 1
# Forma final de y_batch: (30, 2)
# subbatch_index: 11
#  batch_index calculado: 5
# DEBUG tamaño total de self.df: 9
# Tamaño de batches recibido: 1
# Longitud final de path_batch: 1
# 11/18 [=================>............] - ETA: 33sForma final de y_batch: (30, 2)
# subbatch_index: 12
#  batch_index calculado: 6
# DEBUG tamaño total de self.df: 9
# Tamaño de batches recibido: 1
# Longitud final de path_batch: 1
# Forma final de y_batch: (30, 2)
# 12/18 [===================>..........] - ETA: 29ssubbatch_index: 13
#  batch_index calculado: 6
# DEBUG tamaño total de self.df: 9
# Tamaño de batches recibido: 1
# 13/18 [====================>.........] - ETA: 24sLongitud final de path_batch: 1
# Forma final de y_batch: (30, 2)
# subbatch_index: 14
#  batch_index calculado: 7
# DEBUG tamaño total de self.df: 9
# Tamaño de batches recibido: 1
# Longitud final de path_batch: 1
# Forma final de y_batch: (30, 2)
# 14/18 [======================>.......] - ETA: 19ssubbatch_index: 15
#  batch_index calculado: 7
# DEBUG tamaño total de self.df: 9
# 15/18 [========================>.....] - ETA: 14sTamaño de batches recibido: 1
# Longitud final de path_batch: 1
# Forma final de y_batch: (30, 2)
# subbatch_index: 16
#  batch_index calculado: 8
# DEBUG tamaño total de self.df: 9
# Tamaño de batches recibido: 1
# 16/18 [=========================>....] - ETA: 9s  1
# Forma final de y_batch: (30, 2)
# subbatch_index: 17
#  batch_index calculado: 8
# DEBUG tamaño total de self.df: 9
# 17/18 [===========================>..] - ETA: 4sTamaño de batches recibido: 1
# Longitud final de path_batch: 1
# Forma final de y_batch: (30, 2)
# 18/18 [==============================] - 89s 5s/step
# mislabeled subjects:
#  Counter({'R:/preprocess_batch-002/commonspace_bold/_scan_info_subject_id081.session01_split_name_sub-081_ses-01_desc-o_T2w/_run_None/sub-081_ses-01_task-dist_desc-oa_bold_autobox_combined.nii.gz': 30, 'R:/preprocess_batch-002/commonspace_bold/_scan_info_subject_id077.session01_split_name_sub-077_ses-01_desc-o_T2w/_run_None/sub-077_ses-01_task-dist_desc-oa_bold_autobox_combined.nii.gz': 30, 'R:/preprocess_batch-001/commonspace_bold/_scan_info_subject_id052.session01_split_name_sub-052_ses-01_desc-o_T2w/_run_None/sub-052_ses-01_task-dist_desc-oa_bold_autobox_combined.nii.gz': 30})
# evaluating CNN
# subbatch_index: 0
#  batch_index calculado: 0
# DEBUG tamaño total de self.df: 9
# Tamaño de batches recibido: 1
# Longitud final de path_batch: 1
# Forma final de y_batch: (30, 2)
# subbatch_index: 0
#  batch_index calculado: 0
# DEBUG tamaño total de self.df: 9
# Tamaño de batches recibido: 1
# Longitud final de path_batch: 1
# Forma final de y_batch: (30, 2)
# subbatch_index: 1
#  batch_index calculado: 0
# DEBUG tamaño total de self.df: 9
# Tamaño de batches recibido: 1
# Longitud final de path_batch: 1
# Forma final de y_batch: (30, 2)
#  1/18 [>.............................] - ETA: 1:45 - loss: 25.9438 - Accuracy: 0.0000e+00subbatch_index: 2
#  batch_index calculado: 1
# DEBUG tamaño total de self.df: 9
# Tamaño de batches recibido: 1
# Longitud final de path_batch: 1
# Forma final de y_batch: (30, 2)
#  2/18 [==>...........................] - ETA: 1:20 - loss: 25.8524 - Accuracy: 0.0000e+00subbatch_index: 3
#  batch_index calculado: 1
# DEBUG tamaño total de self.df: 9
# Tamaño de batches recibido: 1
# Longitud final de path_batch: 1
# Forma final de y_batch: (30, 2)
#  3/18 [====>.........................] - ETA: 1:16 - loss: 25.0920 - Accuracy: 0.0000e+00subbatch_index: 4
#  batch_index calculado: 2
# DEBUG tamaño total de self.df: 9
# Tamaño de batches recibido: 1
# Longitud final de path_batch: 1
# Forma final de y_batch: (30, 2)
#  4/18 [=====>........................] - ETA: 1:10 - loss: 24.7739 - Accuracy: 0.0000e+00subbatch_index: 5
#  batch_index calculado: 2
# DEBUG tamaño total de self.df: 9
# Tamaño de batches recibido: 1
# Longitud final de path_batch: 1
# Forma final de y_batch: (30, 2)
#  5/18 [=======>......................] - ETA: 1:05 - loss: 24.8165 - Accuracy: 0.0000e+00subbatch_index: 6
#  batch_index calculado: 3
# DEBUG tamaño total de self.df: 9
# Tamaño de batches recibido: 1
# Longitud final de path_batch: 1
# Forma final de y_batch: (30, 2)
#  6/18 [=========>....................] - ETA: 59s - loss: 24.8354 - Accuracy: 0.0000e+00 subbatch_index: 7
#  batch_index calculado: 3
# DEBUG tamaño total de self.df: 9
# Tamaño de batches recibido: 1
# Longitud final de path_batch: 1
# Forma final de y_batch: (30, 2)
#  7/18 [==========>...................] - ETA: 54s - loss: 24.3780 - Accuracy: 0.1429    subbatch_index: 8
#  batch_index calculado: 4
# DEBUG tamaño total de self.df: 9
# Tamaño de batches recibido: 1
# Longitud final de path_batch: 1
# Forma final de y_batch: (30, 2)
#  8/18 [============>.................] - ETA: 49s - loss: 24.0348 - Accuracy: 0.2500subbatch_index: 9
#  batch_index calculado: 4
# DEBUG tamaño total de self.df: 9
# Tamaño de batches recibido: 1
# Longitud final de path_batch: 1
# Forma final de y_batch: (30, 2)
#  9/18 [==============>...............] - ETA: 44s - loss: 23.7633 - Accuracy: 0.3333subbatch_index: 10
#  batch_index calculado: 5
# DEBUG tamaño total de self.df: 9
# Tamaño de batches recibido: 1
# Longitud final de path_batch: 1
# Forma final de y_batch: (30, 2)
# 10/18 [===============>..............] - ETA: 39s - loss: 23.5461 - Accuracy: 0.4000subbatch_index: 11
#  batch_index calculado: 5
# DEBUG tamaño total de self.df: 9
# Tamaño de batches recibido: 1
# Longitud final de path_batch: 1
# Forma final de y_batch: (30, 2)
# 11/18 [=================>............] - ETA: 34s - loss: 23.3780 - Accuracy: 0.4545subbatch_index: 12
#  batch_index calculado: 6
# DEBUG tamaño total de self.df: 9
# Tamaño de batches recibido: 1
# Longitud final de path_batch: 1
# Forma final de y_batch: (30, 2)
# 12/18 [===================>..........] - ETA: 30s - loss: 23.2369 - Accuracy: 0.5000subbatch_index: 13
#  batch_index calculado: 6
# DEBUG tamaño total de self.df: 9
# Tamaño de batches recibido: 1
# Longitud final de path_batch: 1
# Forma final de y_batch: (30, 2)
# 13/18 [====================>.........] - ETA: 25s - loss: 23.1115 - Accuracy: 0.5385subbatch_index: 14
#  batch_index calculado: 7
# DEBUG tamaño total de self.df: 9
# Tamaño de batches recibido: 1
# Longitud final de path_batch: 1
# Forma final de y_batch: (30, 2)
# 14/18 [======================>.......] - ETA: 20s - loss: 23.0042 - Accuracy: 0.5714subbatch_index: 15
#  batch_index calculado: 7
# DEBUG tamaño total de self.df: 9
# Tamaño de batches recibido: 1
# Longitud final de path_batch: 1
# Forma final de y_batch: (30, 2)
# 15/18 [========================>.....] - ETA: 15s - loss: 22.9112 - Accuracy: 0.6000subbatch_index: 16
#  batch_index calculado: 8
# DEBUG tamaño total de self.df: 9
# Tamaño de batches recibido: 1
# Longitud final de path_batch: 1
# Forma final de y_batch: (30, 2)
# 16/18 [=========================>....] - ETA: 10s - loss: 22.8300 - Accuracy: 0.6250subbatch_index: 17
#  batch_index calculado: 8
# DEBUG tamaño total de self.df: 9
# Tamaño de batches recibido: 1
# Longitud final de path_batch: 1
# Forma final de y_batch: (30, 2)
# 18/18 [==============================] - 91s 5s/step - loss: 22.6929 - Accuracy: 0.6667
# GradCam All ConvLayers-female
# CM CNN
# histories and scores from VGG 16 M2D
# Accuracy: mean=66.667 std=0.000, n=5
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>Accuracy</td><td>▁</td></tr><tr><td>epoch</td><td>▁</td></tr><tr><td>loss</td><td>▁</td></tr><tr><td>test_acc</td><td>▁</td></tr><tr><td>val_Accuracy</td><td>▁</td></tr><tr><td>val_loss</td><td>▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>Accuracy</td><td>0.50185</td></tr><tr><td>best_epoch</td><td>0</td></tr><tr><td>best_val_loss</td><td>22.65799</td></tr><tr><td>epoch</td><td>0</td></tr><tr><td>loss</td><td>22.46247</td></tr><tr><td>test_acc</td><td>0.66667</td></tr><tr><td>time_running</td><td>0:11:14.087661</td></tr><tr><td>val_Accuracy</td><td>0.66667</td></tr><tr><td>val_loss</td><td>22.65799</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">faithful-wildflower-6</strong> at: <a href='https://wandb.ai/mansoor35/CPHfemale_BLvsW1W7_100epochs/runs/vfc369ko' target="_blank">https://wandb.ai/mansoor35/CPHfemale_BLvsW1W7_100epochs/runs/vfc369ko</a><br> View project at: <a href='https://wandb.ai/mansoor35/CPHfemale_BLvsW1W7_100epochs' target="_blank">https://wandb.ai/mansoor35/CPHfemale_BLvsW1W7_100epochs</a><br>Synced 5 W&B file(s), 1 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>C:\Users\L03087~1\AppData\Local\Temp\wandb\run-20251206_005940-vfc369ko\logs</code>
